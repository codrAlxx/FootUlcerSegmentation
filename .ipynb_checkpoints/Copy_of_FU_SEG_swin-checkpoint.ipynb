# %% [markdown]
# # Deep Learning for Medical Image Analysis
# ## MICCAI Grand Challenge - Foot ulcer segmentation challenge

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Mon Mar 18 19:03:41 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ### import the libraries

# %%
import os

from IPython.display import Image, display
from tensorflow.keras.preprocessing.image import load_img
from PIL import ImageOps

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras import layers

import numpy as np
import keras
import random

import matplotlib.pyplot as plt

# %%
# keras.__version__
os.environ["SM_FRAMEWORK"] = "tf.keras"
print(tf.__version__)
# Out:
# 2.13.0

# %%
import numpy as np
from glob import glob
from tensorflow import keras
import datetime
# !pip install keras-unet-collection
from keras_unet_collection import models, utils, losses
from tensorflow.keras.optimizers import Adam
# Out:
# Requirement already satisfied: keras-unet-collection in /Users/alok/anaconda3/lib/python3.11/site-packages (0.1.13)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install segmentation-models
import segmentation_models as sm
from segmentation_models import Unet
from segmentation_models import get_preprocessing
from segmentation_models.losses import bce_jaccard_loss
from segmentation_models.metrics import iou_score
# Out:
# Requirement already satisfied: segmentation-models in /Users/alok/anaconda3/lib/python3.11/site-packages (1.0.1)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /Users/alok/anaconda3/lib/python3.11/site-packages (from segmentation-models) (1.0.8)
# Requirement already satisfied: image-classifiers==1.0.0 in /Users/alok/anaconda3/lib/python3.11/site-packages (from segmentation-models) (1.0.0)
# Requirement already satisfied: efficientnet==1.0.0 in /Users/alok/anaconda3/lib/python3.11/site-packages (from segmentation-models) (1.0.0)
# Requirement already satisfied: scikit-image in /Users/alok/anaconda3/lib/python3.11/site-packages (from efficientnet==1.0.0->segmentation-models) (0.20.0)
# Requirement already satisfied: numpy>=1.9.1 in /Users/alok/anaconda3/lib/python3.11/site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.24.3)
# Requirement already satisfied: h5py in /Users/alok/anaconda3/lib/python3.11/site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (3.7.0)
# Requirement already satisfied: scipy>=1.8 in /Users/alok/anaconda3/lib/python3.11/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.10.1)
# Requirement already satisfied: networkx>=2.8 in /Users/alok/anaconda3/lib/python3.11/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.1)
# Requirement already satisfied: pillow>=9.0.1 in /Users/alok/anaconda3/lib/python3.11/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /Users/alok/anaconda3/lib/python3.11/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.31.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /Users/alok/anaconda3/lib/python3.11/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /Users/alok/anaconda3/lib/python3.11/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /Users/alok/.local/lib/python3.11/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (23.2)
# Requirement already satisfied: lazy_loader>=0.1 in /Users/alok/anaconda3/lib/python3.11/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (0.2)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Segmentation Models: using `tf.keras` framework.

# %% [markdown]
# ### clone the git repository

# %%
# !git clone https://github.com/uwm-bigdata/wound-segmentation.git
# Out:
# fatal: destination path 'wound-segmentation' already exists and is not an empty directory.

# %% [markdown]
# ### check if GPU is used

# %%
print(tf.config.list_physical_devices())
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# Num GPUs Available:  0

# %% [markdown]
# ### Core parameters used

# %%
# Resizing the images
# img_size = (160, 160) #(128, 128)
# img_size = (128, 128)
img_size = (256, 256)

# Number of classes (binary: black or white, thus one class sufficient)
num_classes = 1

# Batch size of 32
batch_size = 32

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### sort data: training images and training ground truth

# %%
# path to training data and ground truth
input_dir = "wound-segmentation/data/Foot Ulcer Segmentation Challenge/train/images/"
target_dir = "wound-segmentation/data/Foot Ulcer Segmentation Challenge/train/labels/"

# sort input images by name
input_img_paths = sorted(
    [
        os.path.join(input_dir, fname)
        for fname in os.listdir(input_dir)
        if fname.endswith(".png")
    ]
)

# sort segmentation masks by name
target_img_paths = sorted(
    [
        os.path.join(target_dir, fname)
        for fname in os.listdir(target_dir)
        if fname.endswith(".png") and not fname.startswith(".")
    ]
)

# print number of total images
print("Number of samples:", len(input_img_paths))

# verify for the first 5 images that they are correctly aligned with their segmentation masks
for input_path, target_path in zip(input_img_paths[:5], target_img_paths[:5]):
    print(input_path, "|", target_path)
# Out:
# Number of samples: 810
# wound-segmentation/data/Foot Ulcer Segmentation Challenge/train/images/0011.png | wound-segmentation/data/Foot Ulcer Segmentation Challenge/train/labels/0011.png
# wound-segmentation/data/Foot Ulcer Segmentation Challenge/train/images/0012.png | wound-segmentation/data/Foot Ulcer Segmentation Challenge/train/labels/0012.png
# wound-segmentation/data/Foot Ulcer Segmentation Challenge/train/images/0013.png | wound-segmentation/data/Foot Ulcer Segmentation Challenge/train/labels/0013.png
# wound-segmentation/data/Foot Ulcer Segmentation Challenge/train/images/0014.png | wound-segmentation/data/Foot Ulcer Segmentation Challenge/train/labels/0014.png
# wound-segmentation/data/Foot Ulcer Segmentation Challenge/train/images/0015.png | wound-segmentation/data/Foot Ulcer Segmentation Challenge/train/labels/0015.png

# %% [markdown]
# ### Displaying an example image of the dataset and its segmentation

# %%
# display example
display(load_img(input_img_paths[19], target_size=img_size))

# display mask
display(load_img(target_img_paths[19], target_size=img_size))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>
# <PIL.Image.Image image mode=RGB size=256x256>

# %% [markdown]
# ### sort data: validation images and validation ground truth

# %%
# path to validation data and ground truth
val_input_dir = "wound-segmentation/data/Foot Ulcer Segmentation Challenge/validation/images/"
val_target_dir = "wound-segmentation/data/Foot Ulcer Segmentation Challenge/validation/labels/"

# sort input images by name
val_input_img_paths = sorted(
    [
        os.path.join(val_input_dir, fname)
        for fname in os.listdir(val_input_dir)
        if fname.endswith(".png")
    ]
)

# sort segmentation masks by name
val_target_img_paths = sorted(
    [
        os.path.join(val_target_dir, fname)
        for fname in os.listdir(val_target_dir)
        if fname.endswith(".png")
    ]
)

# print number of total images
print("Number of samples:", len(val_input_img_paths))

# verify for the first 5 images that they are correctly aligned with their segmentation masks
for input_path, target_path in zip(val_input_img_paths[:5], val_target_img_paths[:5]):
    print(input_path, "|", target_path)
# Out:
# Number of samples: 200
# wound-segmentation/data/Foot Ulcer Segmentation Challenge/validation/images/0001.png | wound-segmentation/data/Foot Ulcer Segmentation Challenge/validation/labels/0001.png
# wound-segmentation/data/Foot Ulcer Segmentation Challenge/validation/images/0002.png | wound-segmentation/data/Foot Ulcer Segmentation Challenge/validation/labels/0002.png
# wound-segmentation/data/Foot Ulcer Segmentation Challenge/validation/images/0003.png | wound-segmentation/data/Foot Ulcer Segmentation Challenge/validation/labels/0003.png
# wound-segmentation/data/Foot Ulcer Segmentation Challenge/validation/images/0004.png | wound-segmentation/data/Foot Ulcer Segmentation Challenge/validation/labels/0004.png
# wound-segmentation/data/Foot Ulcer Segmentation Challenge/validation/images/0005.png | wound-segmentation/data/Foot Ulcer Segmentation Challenge/validation/labels/0005.png

# %% [markdown]
# ### load all images from file into python datastructure and already resize them

# %%
# training images
all_images = [load_img(i_path, target_size=img_size) for i_path in input_img_paths]

all_masks = [load_img(t_path, target_size=img_size, color_mode="grayscale") for t_path in target_img_paths]

#validation images
val_all_images = [load_img(i_path, target_size=img_size) for i_path in val_input_img_paths]

val_all_masks = [load_img(t_path, target_size=img_size, color_mode="grayscale") for t_path in val_target_img_paths]

# %% [markdown]
# ### convert to numpy array and normalize the data to [0,1]

# %%
# training
all_images_normalized = [np.array(image, dtype='float32')/255 for image in all_images]

all_masks_normalized = [np.array(image, dtype='float32')/255 for image in all_masks]

#validation
val_all_images_normalized = [np.array(image, dtype='float32')/255 for image in val_all_images]

val_all_masks_normalized = [np.array(image, dtype='float32')/255 for image in val_all_masks]

# %% [markdown]
# ### convert to numpy arrays

# %%
# training
all_images_normalized = np.array(all_images_normalized)

all_masks_normalized = np.array(all_masks_normalized)

# validation
val_all_images_normalized = np.array(val_all_images_normalized)

val_all_masks_normalized = np.array(val_all_masks_normalized)

# %%
print(all_images_normalized.shape)
print(val_all_images_normalized.shape)
# Out:
# (810, 128, 128, 3)
# (200, 128, 128, 3)

# %% [markdown]
# ### add new axis for adding an output channel: black or white, i.e. (900, 160, 160) -> (900, 160, 160, 1)

# %%
# training
all_masks_normalized = all_masks_normalized[..., np.newaxis]

#validation
val_all_masks_normalized = val_all_masks_normalized[..., np.newaxis]

# %% [markdown]
# ### check shapes

# %%
print(all_images_normalized.shape)
print(val_all_images_normalized.shape)
# Out:
# (810, 128, 128, 3)
# (200, 128, 128, 3)

# %%
# model = sm.Unet(BACKBONE, encoder_weights='imagenet')
# model.compile('Adam', loss=sm.losses.bce_jaccard_loss, metrics=[sm.metrics.iou_score],)

# print(model.summary())

# %% [markdown]
# ## Model architecture

# %%
#filters = [8, 16, 24, 32]
filters = [8, 16, 32, 64]
#filters = [16, 32, 64, 128]
dropout_probability = 0.2

# %% [markdown]
# ### define the U-Net model

# %%
def get_unet_model(img_size, num_classes, filters):
    inputs = keras.Input(shape=img_size + (3,))

    skips = []

    filters_backwards = filters[::-1]

    ### [ENCODER: First half of the network: downsampling inputs] ###

    # Entry block
    x = layers.Conv2D(filters[0], 3, padding="same")(inputs)
    x = layers.Activation("relu")(x)

    x = layers.Conv2D(filters[0], 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    skips.append(x)

    x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

    x = layers.Dropout(dropout_probability)(x)

    for f in filters[1:]:
        x = layers.Conv2D(f, 3, padding="same")(x)
        x = layers.Activation("relu")(x)

        x = layers.Conv2D(f, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation("relu")(x)

        skips.append(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        x = layers.Dropout(dropout_probability)(x)

    ### [DECODER: Second half of the network: upsampling inputs] ###

    f = filters_backwards[0]

    x = layers.Conv2DTranspose(f, 3, padding="same")(x)
    x = layers.Activation("relu")(x)

    x = layers.Conv2DTranspose(f, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.UpSampling2D(2)(x)

    x = layers.Dropout(dropout_probability)(x)

    for i, f in enumerate(filters_backwards[1:], start=1):
        x = layers.Concatenate()([x, skips[-i]]) # UNet skip connection with concatenation operation

        x = layers.Conv2DTranspose(f, 3, padding="same")(x)
        x = layers.Activation("relu")(x)

        x = layers.Conv2DTranspose(f, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation("relu")(x)

        x = layers.UpSampling2D(2)(x)

        x = layers.Dropout(dropout_probability)(x)

    x = layers.Concatenate()([x, skips[0]]) # UNet skip connection with concatenation operation

    # Add a per-pixel classification layer with sigmoid as non linear activation function
    outputs = layers.Conv2DTranspose(num_classes, 3, activation="sigmoid", padding="same")(x)

    # Define the model
    model = keras.Model(inputs, outputs)
    return model

# %% [markdown]
# ### define the LinkNet model

# %%
def get_linknet_model(img_size, num_classes, filters):
    inputs = keras.Input(shape=img_size + (3,))

    skips = []

    filters_backwards = filters[::-1]

    ### [ENCODER: First half of the network: downsampling inputs] ###

    # Entry block
    x = layers.Conv2D(filters[0], 3, padding="same")(inputs)
    x = layers.Activation("relu")(x)

    x = layers.Conv2D(filters[0], 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    skips.append(x)

    x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

    x = layers.Dropout(.2)(x)

    for f in filters[1:]:
        x = layers.Conv2D(f, 3, padding="same")(x)
        x = layers.Activation("relu")(x)

        x = layers.Conv2D(f, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation("relu")(x)

        skips.append(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        x = layers.Dropout(.2)(x)

    ### [DECODER: Second half of the network: upsampling inputs] ###

    f = filters_backwards[0]

    x = layers.Conv2DTranspose(f, 3, padding="same")(x)
    x = layers.Activation("relu")(x)

    x = layers.Conv2DTranspose(f, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.UpSampling2D(2)(x)

    x = layers.Dropout(.2)(x)

    for i, f in enumerate(filters_backwards[1:], start=1):
        x = layers.Add()([x, skips[-i]]) # LinkNet skip connection with adding operation

        x = layers.Conv2DTranspose(f, 3, padding="same")(x)
        x = layers.Activation("relu")(x)

        x = layers.Conv2DTranspose(f, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation("relu")(x)

        x = layers.UpSampling2D(2)(x)

        x = layers.Dropout(.2)(x)

    x = layers.Add()([x, skips[0]]) # LinkNet skip connection with adding operation

    # Add a per-pixel classification layer with sigmoid as non linear activation function
    outputs = layers.Conv2D(num_classes, 3, activation="sigmoid", padding="same")(x)

    # Define the model
    model = keras.Model(inputs, outputs)
    return model

# %% [markdown]
# ### define ensemble model (averaging unet / linknet probability masks)

# %%
def unet(inputs, filters):
    skips = []

    filters_backwards = filters[::-1]

    ### [ENCODER: First half of the network: downsampling inputs] ###

    # Entry block
    x = layers.Conv2D(filters[0], 3, padding="same")(inputs)
    x = layers.Activation("relu")(x)

    x = layers.Conv2D(filters[0], 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    skips.append(x)

    x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

    x = layers.Dropout(dropout_probability)(x)

    for f in filters[1:]:
        x = layers.Conv2D(f, 3, padding="same")(x)
        x = layers.Activation("relu")(x)

        x = layers.Conv2D(f, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation("relu")(x)

        skips.append(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        x = layers.Dropout(dropout_probability)(x)

    ### [DECODER: Second half of the network: upsampling inputs] ###

    f = filters_backwards[0]

    x = layers.Conv2DTranspose(f, 3, padding="same")(x)
    x = layers.Activation("relu")(x)

    x = layers.Conv2DTranspose(f, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.UpSampling2D(2)(x)

    x = layers.Dropout(dropout_probability)(x)

    for i, f in enumerate(filters_backwards[1:], start=1):
        x = layers.Concatenate()([x, skips[-i]]) # UNet skip connection with concatenation operation

        x = layers.Conv2DTranspose(f, 3, padding="same")(x)
        x = layers.Activation("relu")(x)

        x = layers.Conv2DTranspose(f, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation("relu")(x)

        x = layers.UpSampling2D(2)(x)

        x = layers.Dropout(dropout_probability)(x)

    x = layers.Concatenate()([x, skips[0]]) # UNet skip connection with concatenation operation

    return x

def linknet(inputs, filters):
    skips = []

    filters_backwards = filters[::-1]

    ### [ENCODER: First half of the network: downsampling inputs] ###

    # Entry block
    x = layers.Conv2D(filters[0], 3, padding="same")(inputs)
    x = layers.Activation("relu")(x)

    x = layers.Conv2D(filters[0], 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    skips.append(x)

    x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

    x = layers.Dropout(.2)(x)

    for f in filters[1:]:
        x = layers.Conv2D(f, 3, padding="same")(x)
        x = layers.Activation("relu")(x)

        x = layers.Conv2D(f, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation("relu")(x)

        skips.append(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        x = layers.Dropout(.2)(x)

    ### [DECODER: Second half of the network: upsampling inputs] ###

    f = filters_backwards[0]

    x = layers.Conv2DTranspose(f, 3, padding="same")(x)
    x = layers.Activation("relu")(x)

    x = layers.Conv2DTranspose(f, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.UpSampling2D(2)(x)

    x = layers.Dropout(.2)(x)

    for i, f in enumerate(filters_backwards[1:], start=1):
        x = layers.Add()([x, skips[-i]]) # LinkNet skip connection with adding operation

        x = layers.Conv2DTranspose(f, 3, padding="same")(x)
        x = layers.Activation("relu")(x)

        x = layers.Conv2DTranspose(f, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation("relu")(x)

        x = layers.UpSampling2D(2)(x)

        x = layers.Dropout(.2)(x)

    x = layers.Add()([x, skips[0]]) # LinkNet skip connection with adding operation

    return x

def get_ensemble_model(img_size, num_classes, filters):
    inputs = keras.Input(shape=img_size + (3,))

    results = []

    x = unet(inputs, filters)

    results.append(x)

    adapted_filters = filters[1:] + [filters[-1]*2]
    x = linknet(inputs, adapted_filters)

    results.append(x)

    # take average of unet and linknet
    sum_results = results[0]
    for r in results[1:]:
        sum_results = layers.Add()([sum_results, r])
    sum_results = sum_results / len(results)
    x = sum_results

    # Add a per-pixel classification layer with sigmoid as non linear activation function
    outputs = layers.Conv2D(num_classes, 3, activation="sigmoid", padding="same")(x)

    # Define the model
    model = keras.Model(inputs, outputs)
    return model

# %%
keras.backend.clear_session()

selected_model = "ensemble"

if selected_model == "unet":
    model = get_unet_model(img_size, num_classes, filters)
elif selected_model == "linknet":
    model = get_linknet_model(img_size, num_classes, filters)
elif selected_model == "ensemble":
    model = get_ensemble_model(img_size, num_classes, filters)
else:
    print("please specify the model")

# %%
# model.summary()

# %% [markdown]
# ### free up RAM in case the model definition cells were run multiple times and build model

# %% [markdown]
# ## Training and validation data
# ### split our img paths into a training and a validation set:

# %%
import time

# shuffle input images and corresponding masks to introduce randomness, but same random seed that shuffle keeps them aligned
random.Random(63).shuffle(all_images_normalized) #int(time.time())
random.Random(63).shuffle(all_masks_normalized)

random.Random(100).shuffle(val_all_images_normalized)
random.Random(100).shuffle(val_all_masks_normalized)

# assign training set
train_imgs = all_images_normalized
train_msks = all_masks_normalized

# assign validation set (take second half of validation set)
val_imgs = val_all_images_normalized[:len(val_all_images_normalized)//2]
val_msks = val_all_masks_normalized[:len(val_all_images_normalized)//2]

# assign test set (take second half of validation set)
test_imgs = val_all_images_normalized[len(val_all_images_normalized)//2:]
test_msks = val_all_masks_normalized[len(val_all_images_normalized)//2:]

train_gen = (train_imgs, train_msks)
val_gen = (val_imgs, val_msks)

test_gen = (test_imgs, test_msks)

# %% [markdown]
# ### check lengths and shapes

# %%
print("Lengths Train, Val, Test: ", len(train_imgs), len(val_imgs), len(test_imgs))


print("Train Shapes: ", train_imgs.shape, train_msks.shape)
print("Val Shapes: ", val_imgs.shape, val_msks.shape)
print("Test Shapes: ", test_imgs.shape, test_msks.shape)
# Out:
# Lengths Train, Val, Test:  810 100 100
# Train Shapes:  (810, 128, 128, 3) (810, 128, 128, 1)
# Val Shapes:  (100, 128, 128, 3) (100, 128, 128, 1)
# Test Shapes:  (100, 128, 128, 3) (100, 128, 128, 1)

# %% [markdown]
# ## Data augmentation:
# ### execute the next 4 cells only if data augmentation should be applied

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_imgs, train_msks))
val_dataset = tf.data.Dataset.from_tensor_slices((val_imgs, val_msks))

# %% [markdown]
# ### check if shapes are correct: for input: (img_size1, img_size2, 3), for mask: (img_size1, img_size2, 1)

# %%
for x,y in train_dataset:
    print(x.shape, y.shape)
    break
# Out:
# (128, 128, 3) (128, 128, 1)

# %% [markdown]
# ### Augmentations: Flippings and Rotations

# %%
class Augment(tf.keras.layers.Layer):
  def __init__(self, seed=42):
    super().__init__()
    # both use the same seed, so they'll make the same random changes.
    # augmentations that dont move the image can be added here
    self.augment_inputs = tf.keras.Sequential([
      layers.RandomFlip("horizontal_and_vertical", seed=seed),
      layers.RandomRotation(0.25, seed=seed+1),
    ])

    self.augment_labels = tf.keras.Sequential([
      layers.RandomFlip("horizontal_and_vertical", seed=seed),
      layers.RandomRotation(0.25, seed=seed+1),
    ])

  def call(self, inputs, labels):
    inputs = self.augment_inputs(inputs)
    labels = self.augment_labels(labels)
    return inputs, labels

# %% [markdown]
# ### map augmentations to training set

# %%
train_batches = (
    train_dataset
    .cache()
    .shuffle(1000)
    .batch(batch_size)
    .map(Augment())
    .prefetch(buffer_size=tf.data.AUTOTUNE))

val_batches = val_dataset.batch(batch_size)

# %% [markdown]
# ### Configure the model for training.
# ### use the binary cross entropy as the model segments into 0 (black) or 1 (white)

# %%
import keras.backend as K

def dice_loss(y_true, y_pred):
    smooth = 1.0
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return 1.0 - (2.0 * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# different options for loss:
dice = 80.22
# 1. loss="binary_crossentropy"
# 2. loss="binary_focal_crossentropy"
# 3. loss=dice_loss

model.compile(optimizer="adam", loss="binary_crossentropy", # optimizer=opt for SGD optimizer
              metrics=['accuracy',
                       keras.metrics.Recall(), # is same as sensitivity
                       keras.metrics.FalseNegatives(),
                       keras.metrics.FalsePositives(),
                       keras.metrics.TrueNegatives(),
                       keras.metrics.TruePositives(),
                       keras.metrics.AUC()]) # area under roc curve

callbacks = [
    keras.callbacks.ModelCheckpoint("checkpoint_best_validation.h5", save_best_only=True)
]

# %% [markdown]
# ## Training phase (with data augmentation)
# ### Train the model, doing validation at the end of each epoch.

# %%
epochs = 50
model_history = model.fit(train_batches, epochs=epochs, validation_data=val_batches, callbacks=callbacks)
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-78413afefe2c> in <cell line: 2>()
#       1 epochs = 50
# ----> 2 model_history = model.fit(train_batches, epochs=epochs, validation_data=val_batches, callbacks=callbacks)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1805                         ):
#    1806                             callbacks.on_train_batch_begin(step)
# -> 1807                             tmp_logs = self.train_function(iterator)
#    1808                             if data_handler.should_sync:
#    1809                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     830
#     831       with OptionalXlaContext(self._jit_compile):
# --> 832         result = self._call(*args, **kwds)
#     833
#     834       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     903         # Lifting succeeded, so variables are initialized and we can run the
#     904         # no_variable_creation function.
# --> 905         return tracing_compilation.call_function(
#     906             args, kwds, self._no_variable_creation_config
#     907         )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     130   args = args if args else ()
#     131   kwargs = kwargs if kwargs else {}
# --> 132   function = trace_function(
#     133       args=args, kwargs=kwargs, tracing_options=tracing_options
#     134   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in trace_function(args, kwargs, tracing_options)
#     176       kwargs = {}
#     177
# --> 178     concrete_function = _maybe_define_function(
#     179         args, kwargs, tracing_options
#     180     )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _maybe_define_function(args, kwargs, tracing_options)
#     281         else:
#     282           target_func_type = lookup_func_type
# --> 283         concrete_function = _create_concrete_function(
#     284             target_func_type, lookup_func_context, func_graph, tracing_options
#     285         )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     338   )
#     339
# --> 340   concrete_function = concrete_function_lib.ConcreteFunction.from_func_graph(
#     341       traced_func_graph,
#     342       traced_func_type,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in from_func_graph(cls, graph, function_type, attrs, shared_func_graph)
#    1074   @classmethod
#    1075   def from_func_graph(cls, graph, function_type, attrs, shared_func_graph=True):
# -> 1076     atomic_fn = atomic_function.from_func_graph(
#    1077         _inference_name(graph.name), graph, attrs, function_type
#    1078     )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in from_func_graph(name, graph, attrs, function_type, overwrite)
#     535     output_names = []
#     536   with graph._c_graph.get() as c_graph:  # pylint: disable=protected-access
# --> 537     fn = pywrap_tf_session.TF_GraphToFunction_wrapper(
#     538         c_graph,
#     539         compat.as_str(name),
#
# KeyboardInterrupt:

# %%
# summarize history for accuracy
history = model_history

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# summarize history for Dice
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('model dice')
plt.ylabel('dice')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['recall'])
plt.title('model dice')
plt.ylabel('value')
plt.xlabel('epoch')
plt.legend(['dice', 'loss'], loc='upper right')
plt.show()

plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('model dice')
plt.ylabel('auc')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
model = model
import random
test_img_number = random.randint(0, X_test.shape[0]-1)  #Test with 119

test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
prediction = (model.predict(test_img_input)[0,:,:,0] > 0.5).astype(np.uint8)

plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img, cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(prediction, cmap='gray')

plt.show()

# %%
dice = history.history['dice']
acc = history.history['accuracy']
val_dice = history.history['val_dice_coef']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']


epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Validation loss')
plt.plot(epochs, dice, 'r', label='Validation Dice')
plt.title('Validation Loss and Training Dice')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()

epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.plot(epochs, acc, 'y', label='Training Dice')
plt.plot(epochs, val_acc, 'r', label='Validation Dice')
plt.title('Training and validation Dice')
plt.xlabel('Epochs')
plt.ylabel('Dice')
plt.legend()
plt.show()

plt.plot(epochs, acc, 'y', label='Training Acc')
plt.plot(epochs, val_acc, 'r', label='Validation Acc')
plt.title('Training and validation Acc')
plt.xlabel('Epochs')
plt.ylabel('Acc')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-1e3adf56b962> in <cell line: 1>()
# ----> 1 dice = history.history['dice']
#       2 acc = history.history['accuracy']
#       3 val_dice = history.history['val_dice_coef']
#       4 val_acc = history.history['val_accuracy']
#       5 loss = history.history['loss']
#
# KeyError: 'dice'

# %% [markdown]
# # Segmentation Models Library

# %%
X_train=train_imgs
y_train=train_msks
X_test=val_imgs
y_test=val_msks

# %%
BACKBONE = 'mobilenetv2'
preprocess_input = sm.get_preprocessing(BACKBONE)
metric = sm.metrics.FScore()
sm_model_LinkNet = sm.Linknet(BACKBONE, encoder_weights='imagenet')
sm_model_LinkNet.compile(optimizer='adam', loss='binary_crossentropy',
                        metrics=[tf.keras.metrics.Precision(), 'accuracy',
                      tf.keras.metrics.Recall(),
                        losses.dice_coef,
                       keras.metrics.IoU(num_classes=2, target_class_ids=[0]),
                        keras.metrics.IoU(num_classes=2, target_class_ids=[1]),
                       keras.metrics.BinaryIoU(  target_class_ids=(0, 1), threshold=0.5, name=None, dtype=None),
                       tf.keras.metrics.MeanIoU(num_classes=2)]
                         )
csv_logger=tf.keras.callbacks.CSVLogger('LinkNetmobilenetv2.csv', separator=',', append=True)

# %%
start1 = datetime.datetime.now()

LinkNet_history= sm_model_LinkNet.fit(
    x=X_train,
    y=y_train,
    batch_size=16,
    epochs=50,
    validation_data=(X_test, y_test),
    callbacks=[csv_logger]
)

stop1 = datetime.datetime.now()


execution_time_Unet = stop1-start1
print("UNet execution time is: ", execution_time_Unet)
# Out:
# Epoch 1/50
# 51/51 [==============================] - 47s 198ms/step - loss: 0.1754 - precision_10: 0.0253 - accuracy: 0.9613 - recall_10: 0.0535 - dice_coef: 0.0737 - io_u_20: 0.9871 - io_u_21: 0.0000e+00 - binary_io_u_10: 0.4894 - mean_io_u_10: 0.4936 - val_loss: 0.2584 - val_precision_10: 2.1363e-04 - val_accuracy: 0.9859 - val_recall_10: 5.4192e-05 - val_dice_coef: 0.0108 - val_io_u_20: 0.9887 - val_io_u_21: 0.0000e+00 - val_binary_io_u_10: 0.4930 - val_mean_io_u_10: 0.4944
# Epoch 2/50
# 51/51 [==============================] - 4s 74ms/step - loss: 0.0388 - precision_10: 0.8275 - accuracy: 0.9874 - recall_10: 0.0233 - dice_coef: 0.2419 - io_u_20: 0.9871 - io_u_21: 0.0000e+00 - binary_io_u_10: 0.5053 - mean_io_u_10: 0.4936 - val_loss: 0.2833 - val_precision_10: 0.0211 - val_accuracy: 0.9882 - val_recall_10: 9.7545e-04 - val_dice_coef: 0.0251 - val_io_u_20: 0.9887 - val_io_u_21: 0.0000e+00 - val_binary_io_u_10: 0.4946 - val_mean_io_u_10: 0.4944
# Epoch 3/50
# 51/51 [==============================] - 4s 74ms/step - loss: 0.0245 - precision_10: 0.8789 - accuracy: 0.9875 - recall_10: 0.0357 - dice_coef: 0.3563 - io_u_20: 0.9871 - io_u_21: 0.0000e+00 - binary_io_u_10: 0
- val_io_u_20: 0.9887 - val_io_u_21: 0.0000e+00 - val_binary_io_u_10: 0.6232 - val_mean_io_u_10: 0.4944
# Epoch 49/50
# 51/51 [==============================] - 4s 79ms/step - loss: 0.0019 - precision_10: 0.9728 - accuracy: 0.9993 - recall_10: 0.9711 - dice_coef: 0.9530 - io_u_20: 0.9871 - io_u_21: 3.5176e-05 - binary_io_u_10: 0.9723 - mean_io_u_10: 0.4936 - val_loss: 0.0601 - val_precision_10: 0.9409 - val_accuracy: 0.9917 - val_recall_10: 0.2768 - val_dice_coef: 0.4238 - val_io_u_20: 0.9887 - val_io_u_21: 0.0000e+00 - val_binary_io_u_10: 0.6318 - val_mean_io_u_10: 0.4944
# Epoch 50/50
# 51/51 [==============================] - 4s 83ms/step - loss: 0.0019 - precision_10: 0.9727 - accuracy: 0.9993 - recall_10: 0.9717 - dice_coef: 0.9524 - io_u_20: 0.9871 - io_u_21: 1.2898e-04 - binary_io_u_10: 0.9726 - mean_io_u_10: 0.4936 - val_loss: 0.0464 - val_precision_10: 0.8929 - val_accuracy: 0.9924 - val_recall_10: 0.3738 - val_dice_coef: 0.5162 - val_io_u_20: 0.9887 - val_io_u_21: 0.0000e+00 - val_binary_io_u_10: 0.6751 - val_mean_io_u_10: 0.4944
# UNet execution time is:  0:04:40.216733

# %%
model = sm_model_LinkNet
# 2 3 4 18 20 27 40 48
import random
test_img_number = random.randint(0, X_pred.shape[0]-1)  #Test with 119

test_img_number = 27
print(test_img_number)
test_img = X_pred[test_img_number]
ground_truth=y_pred[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
prediction = (model.predict(test_img_input)[0,:,:,0] > 0.5).astype(np.uint8)

plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img, cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(prediction, cmap='gray')

plt.show()
# Out:
# 27
# 1/1 [==============================] - 0s 25ms/step

# %%
# print(sm_model_LinkNet.summary())

# %%
# sm_model_UNet.save('/content/UnetEpoch50.h5')
sm_model_LinkNet.save('LinkNetEB2.kearas')

# %%
# from tensorflow import keras
# model = keras.models.load_model('/content/drive/My Drive/Colab Notebooks/data/membrane3000.h5', compile=False)

# %%
history = sm_model_UNet
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
BACKBONE = 'efficientnetb2'
preprocess_input = sm.get_preprocessing(BACKBONE)

# define model
sm_model_LinkNet = sm.Linknet(BACKBONE, encoder_weights='imagenet')
sm_model_LinkNet.compile('Adam', loss=bce_jaccard_loss, metrics=[iou_score])
# print(model2.summary())

# %% [markdown]
# # Keras-UNet Models

# %% [markdown]
# ## unet-backbone

# %%
# help(models.att_unet_2d)
X_train=train_imgs
y_train=train_msks
X_test=val_imgs
y_test=val_msks

X_pred=test_imgs
y_pred=test_msks

# %%
from datetime import datetime
num_labels = 1
batch_size = 8

# %%
model_Unet = models.unet_2d((128, 128, 3), filter_num=[64, 128, 256, 512, 1024],
                           n_labels=num_labels,
                           stack_num_down=2, stack_num_up=2,
                           activation='ReLU',
                           output_activation='Sigmoid',
                           batch_norm=True, pool=False, unpool=False,
                           backbone='VGG19', weights='imagenet',
                           freeze_backbone=True, freeze_batch_norm=True,
                           name='unet')
# model_Unet = models.unet_2d((128, 128, 3), filter_num=[64, 128, 256, 512, 1024],
#                            n_labels=num_labels,
#                            stack_num_down=2, stack_num_up=2,
#                            activation='GELU',
#                            output_activation='Softmax',
#                            batch_norm=True, pool='max', unpool='nearest',
#                            name='unet')
# print(model_Unet.summary())
# Out:
# /usr/local/lib/python3.10/dist-packages/keras_unet_collection/_backbone_zoo.py:45: UserWarning:
#
# Backbone VGG19 does not use batch norm, but other layers received batch_norm=True
#   warnings.warn(param_mismatch);
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 1s 0us/step

# %%
model_Unet.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate = 1e-3),
               metrics=[tf.keras.metrics.Precision(), 'accuracy',
                      tf.keras.metrics.Recall(),
                        losses.dice_coef,
                       keras.metrics.IoU(num_classes=2, target_class_ids=[0]),
                        keras.metrics.IoU(num_classes=2, target_class_ids=[1]),
                       keras.metrics.BinaryIoU(  target_class_ids=(0, 1), threshold=0.5, name=None, dtype=None),
                       tf.keras.metrics.MeanIoU(num_classes=2)]
                       )
csv_logger=tf.keras.callbacks.CSVLogger('UnetVGG19.csv', separator=',', append=True)
# print(model_Unet.summary())

# %%
start1 = datetime.now()
Unet_history = model_Unet.fit(X_train, y_train,
                    verbose=1,
                    batch_size = batch_size,
                    validation_data=(X_test, y_test ),
                    shuffle=False,
                    epochs=50,
                    callbacks=[csv_logger]
                    )

stop1 = datetime.now()
#Execution time of the model
execution_time_Unet = stop1-start1
print("UNet execution time is: ", execution_time_Unet)
# Out:
# Epoch 1/50
# 102/102 [==============================] - 53s 297ms/step - loss: 0.0820 - precision: 0.5949 - accuracy: 0.9895 - recall: 0.5828 - dice_coef: 0.2371 - io_u: 0.9871 - io_u_1: 0.0000e+00 - binary_io_u: 0.7034 - mean_io_u: 0.4936 - val_loss: 5.9499 - val_precision: 0.0168 - val_accuracy: 0.3428 - val_recall: 0.9999 - val_dice_coef: 0.0343 - val_io_u: 0.8631 - val_io_u_1: 0.0696 - val_binary_io_u: 0.1761 - val_mean_io_u: 0.4664
# Epoch 2/50
# 102/102 [==============================] - 16s 156ms/step - loss: 0.0240 - precision: 0.8308 - accuracy: 0.9948 - recall: 0.7518 - dice_coef: 0.4883 - io_u: 0.9871 - io_u_1: 0.0000e+00 - binary_io_u: 0.8234 - mean_io_u: 0.4936 - val_loss: 1.5290 - val_precision: 0.0374 - val_accuracy: 0.7099 - val_recall: 0.9995 - val_dice_coef: 0.0744 - val_io_u: 0.9900 - val_io_u_1: 0.4538 - val_binary_io_u: 0.3720 - val_mean_io_u: 0.7219
# Epoch 3/50
# 102/102 [==============================] - 16s 155ms/step - loss: 0.0145 - precision: 0.8742 - accuracy: 0.9964 - recall: 0.8404 - dice_coef: 0.6431 - io_u: 0.9871 - io_u_1: 0.0000e+00 - binary_io_u: 0.8731 - mean_io_u: 0.4936 - val_loss: 0.0347 - val_precision: 0.4859 - val_accuracy: 0.9881 - val_recall: 0.9174 - val_dice_coef: 0.5198 - val_io_u: 0.9887 - val_io_u_1: 0.0000e+00 - val_binary_io_u: 0.7268 - val_mean_io_u: 0.4944
# Epoch 4/50
# 102/102 [==============================] - 15s 150ms/step - loss: 0.0106 - precision: 0.8976 - accuracy: 0.9971 - recall: 0.8751 - dice_coef: 0.7269 - io_u: 0.9871 - io_u_1: 0.0000e+00 - binary_io_u: 0.8964 - mean_io_u: 0.4936 - val_loss: 0.0172 - val_precision: 0.7542 - val_accuracy: 0.9946 - val_recall: 0.7691 - val_dice_coef: 0.6490 - val_io_u: 0.9887 - val_io_u_1: 0.0000e+00 - val_binary_io_u: 0.8047 - val_mean_io_u: 0.4944
# 102/102 [==============================] - 16s 154ms/step - loss: 0.0022 - precision: 0.9694 - accuracy: 0.9992 - recall: 0.9676 - dice_coef: 0.9399 - io_u: 0.9878 - io_u_1: 0.0533 - binary_io_u: 0.9690 - mean_io_u: 0.5205 - val_loss: 0.0172 - val_precision: 0.8288 - val_accuracy: 0.9955 - val_recall: 0.7526 - val_dice_coef: 0.7558 - val_io_u: 0.9890 - val_io_u_1: 0.0205 - val_binary_io_u: 0.8234 - val_mean_io_u: 0.5048
# Epoch 17/50
# 102/102 [==============================] - 15s 150ms/step - loss: 0.0020 - precision: 0.9722 - accuracy: 0.9993 - recall: 0.9713 - dice_coef: 0.9458 - io_u: 0.9880 - io_u_1: 0.0680 - binary_io_u: 0.9722 - mean_io_u: 0.5280 - val_loss: 0.0177 - val_precision: 0.8443 - val_accuracy: 0.9955 - val_recall: 0.7347 - val_dice_coef: 0.7503 - val_io_u: 0.9890 - val_io_u_1: 0.0250 - val_binary_io_u: 0.8212 - val_mean_io_u: 0.5070
# Epoch 18/50
# 102/102 [==============================] - 16s 155ms/step - loss: 0.0023 - precision: 0.9693 - accuracy: 0.9992 - recall: 0.9653 - dice_coef: 0.9408 - io_u: 0.9880 - io_u_1: 0.0669 - binary_io_u: 0.9679 - mean_io_u: 0.5274 - val_loss: 0.0179 - val_precision: 0.7647 - val_accuracy: 0.9953 - val_recall: 0.8382 - val_dice_coef: 0.7638 - val_io_u: 0.9895 - val_io_u_1: 0.0676 - val_binary_io_u: 0.8308 - val_mean_io_u: 0.5286
# Epoch 19/50
# 102/102 [==============================] - 16s 155ms/step - loss: 0.0036 - precision: 0.9499 - accuracy: 0.9987 - recall: 0.9449 - dice_coef: 0.9108 - io_u: 0.9874 - io_u_1: 0.0213 - binary_io_u: 0.9494 - mean_io_u: 0.5043 - val_loss: 0.0176 - val_precision: 0.7785 - val_accuracy: 0.9954 - val_recall: 0.8257 - val_dice_coef: 0.7680 - val_io_u: 0.9897 - val_io_u_1: 0.0895 - val_binary_io_u: 0.8320 - val_mean_io_u: 0.5396
# Epoch 20/50
# 102/102 [==============================] - 15s 150ms/step - loss: 0.0021 - precision: 0.9702 - accuracy: 0.9992 - recall: 0.9689 - dice_coef: 0.9442 - io_u: 0.9877 - io_u_1: 0.0407 - binary_io_u: 0.9700 - mean_io_u: 0.5142 - val_loss: 0.0174 - val_precision: 0.8368 - val_accuracy: 0.9957 - val_recall: 0.7677 - val_dice_coef: 0.7731 - val_io_u: 0.9891 - val_io_u_1: 0.0365 - val_binary_io_u: 0.8317 - val_mean_io_u: 0.5128
# Epoch 21/50
# 102/102 [==============================] - 16s 154ms/step - loss: 0.0016 - precision: 0.9780 - accuracy: 0.9994 - recall: 0.9763 - dice_coef: 0.9570 - io_u: 0.9881 - io_u_1: 0.0712 - binary_io_u: 0.9774 - mean_io_u: 0.5296 - val_loss: 0.0186 - val_precision: 0.8639 - val_accuracy: 0.9958 - val_recall: 0.7438 - val_dice_coef: 0.7733 - val_io_u: 0.9890 - val_io_u_1: 0.0273 - val_binary_io_u: 0.8308 - val_mean_io_u: 0.5082
# Epoch 22/50
# Epoch 34/50
# 102/102 [==============================] - 15s 150ms/step - loss: 3.9496e-04 - precision: 0.9956 - accuracy: 0.9999 - recall: 0.9953 - dice_coef: 0.9891 - io_u: 0.9898 - io_u_1: 0.2124 - binary_io_u: 0.9954 - mean_io_u: 0.6011 - val_loss: 0.0230 - val_precision: 0.8941 - val_accuracy: 0.9959 - val_recall: 0.7207 - val_dice_coef: 0.7869 - val_io_u: 0.9896 - val_io_u_1: 0.0802 - val_binary_io_u: 0.8299 - val_mean_io_u: 0.5349
# Epoch 35/50
# 102/102 [==============================] - 15s 150ms/step - loss: 3.7205e-04 - precision: 0.9957 - accuracy: 0.9999 - recall: 0.9957 - dice_coef: 0.9899 - io_u: 0.9901 - io_u_1: 0.2353 - binary_io_u: 0.9957 - mean_io_u: 0.6127 - val_loss: 0.0287 - val_precision: 0.9218 - val_accuracy: 0.9956 - val_recall: 0.6698 - val_dice_coef: 0.7657 - val_io_u: 0.9895 - val_io_u_1: 0.0721 - val_binary_io_u: 0.8147 - val_mean_io_u: 0.5308
# Epoch 36/50
# 102/102 [==============================] - 16s 155ms/step - loss: 4.0238e-04 - precision: 0.9951 - accuracy: 0.9999 - recall: 0.9950 - dice_coef: 0.9896 - io_u: 0.9901 - io_u_1: 0.2319 - binary_io_u: 0.9950 - mean_io_u: 0.6110 - val_loss: 0.0236 - val_precision: 0.8748 - val_accuracy: 0.9959 - val_recall: 0.7450 - val_dice_coef: 0.7910 - val_io_u: 0.9901 - val_io_u_1: 0.1190 - val_binary_io_u: 0.8346 - val_mean_io_u: 0.5545
# Epoch 37/50
# 102/102 [==============================] - 16s 154ms/step - loss: 3.9844e-04 - precision: 0.9952 - accuracy: 0.9999 - recall: 0.9948 - dice_coef: 0.9901 - io_u: 0.9902 - io_u_1: 0.2361 - binary_io_u: 0.9950 - mean_io_u: 0.6131 - val_loss: 0.0230 - val_precision: 0.8305 - val_accuracy: 0.9958 - val_recall: 0.7837 - val_dice_coef: 0.7910 - val_io_u: 0.9905 - val_io_u_1: 0.1576 - val_binary_io_u: 0.8357 - val_mean_io_u: 0.5740
# Epoch 38/50
# 102/102 [==============================] - 15s 151ms/step - loss: 3.7267e-04 - precision: 0.9955 - accuracy: 0.9999 - recall: 0.9956 - dice_coef: 0.9902 - io_u: 0.9901 - io_u_1: 0.2332 - binary_io_u: 0.9955 - mean_io_u: 0.6117 - val_loss: 0.0269 - val_precision: 0.8482 - val_accuracy: 0.9956 - val_recall: 0.7419 - val_dice_coef: 0.7791 - val_io_u: 0.9904 - val_io_u_1: 0.1494 - val_binary_io_u: 0.8253 - val_mean_io_u: 0.5699
# Epoch 39/50
# UNet execution time is:  0:14:27.554700

# %%
# sm_model_UNet.save('/content/UnetEpoch50.h5')
model_Unet.save('KerasUnetEpoch50')

# %%
model = model_Unet
import random
test_img_number = random.randint(0, X_pred.shape[0]-1)  #Test with 119

test_img_number = 50
test_img = X_pred[test_img_number]
ground_truth=y_pred[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
prediction = (model.predict(test_img_input)[0,:,:,0] > 0.5).astype(np.uint8)

plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img, cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(prediction, cmap='gray')

plt.show()
# Out:
# 1/1 [==============================] - 0s 66ms/step

# %%
# history = Unet_history
# dice = history.history['dice_coef']
# acc = history.history['accuracy']
# val_dice = history.history['val_dice_coef']
# val_acc = history.history['val_accuracy']
# loss = history.history['loss']
# val_loss = history.history['val_loss']


# epochs = range(1, len(loss) + 1)
# plt.plot(epochs, loss, 'y', label='Training loss')
# plt.plot(epochs, val_loss, 'r', label='Validation Loss ')
# plt.title('Validation Loss and Training Loss')
# plt.xlabel('Epochs')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# epochs = range(1, len(loss) + 1)
# plt.plot(epochs, loss, 'y', label='Training loss')
# plt.plot(epochs, val_loss, 'r', label='Validation loss')
# plt.title('Training and Validation Loss')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# plt.plot(epochs, acc, 'y', label='Training Dice')
# plt.plot(epochs, val_acc, 'r', label='Validation Dice')
# plt.title('Training and validation Dice')
# plt.xlabel('Epochs')
# plt.ylabel('Dice')
# plt.legend()
# plt.show()

# plt.plot(epochs, acc, 'y', label='Training Acc')
# plt.plot(epochs, val_acc, 'r', label='Validation Acc')
# plt.title('Training and validation Acc')
# plt.xlabel('Epochs')
# plt.ylabel('Acc')
# plt.legend()
# plt.show()

# %%
history = Unet_history
dice = history.history['dice_coef']
acc = history.history['accuracy']
val_dice = history.history['val_dice_coef']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']


epochs = range(1, len(loss) + 1)
plt.plot(epochs, dice, 'y', label='Validation loss')
plt.plot(epochs, val_dice, 'r', label='Loss Dice')
plt.title('Validation Loss and Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()

# %% [markdown]
# ## model_Unet_plus

# %%
# help(models.unet_plus_2d)

model_Unet_plus = models.unet_plus_2d((256, 256, 3), filter_num=[64, 128, 256, 512, 1024],
                           n_labels=1,
                           stack_num_down=2, stack_num_up=2,
                           activation='ReLU',
                           output_activation='Sigmoid',
                           batch_norm=True, pool=False, unpool=False,
                           backbone='VGG19', weights='imagenet',
                           freeze_backbone=True, freeze_batch_norm=True,
                           name='unet_plus')

csv_logger=tf.keras.callbacks.CSVLogger('UnetPlusVGG19.csv', separator=',', append=True)
model_Unet_plus.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate = 1e-3),
              metrics=['accuracy', losses.dice_coef])

# print(model_Unet_plus.summary())
# Out:
# /usr/local/lib/python3.10/dist-packages/keras_unet_collection/_backbone_zoo.py:45: UserWarning:
#
# Backbone VGG19 does not use batch norm, but other layers received batch_norm=True
#   warnings.warn(param_mismatch);
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 1s 0us/step

# %%
start2 = datetime.datetime.now()

Unet_plus_history = model_Unet_plus.fit(X_train, y_train,
                    verbose=1,
                    batch_size = batch_size,
                    validation_data=(X_test, y_test ),
                    shuffle=False,
                    epochs=50,
                    callbacks=[csv_logger])


stop2 = datetime.datetime.now()
#Execution time of the model
execution_time_Unet_plus = stop2-start2
print("UNet plus execution time is: ", execution_time_Unet_plus)
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-2feab68cc37c> in <cell line: 3>()
#       1 start2 = datetime.datetime.now()
#       2
# ----> 3 Unet_plus_history = model_Unet_plus.fit(X_train, y_train,
#       4                     verbose=1,
#       5                     batch_size = batch_size,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1401, in train_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1384, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1373, in run_step  **
#         outputs = model.train_step(data)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1150, in train_step
#         y_pred = self(x, training=True)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/input_spec.py", line 298, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "unet_plus_model" is incompatible with the layer: expected shape=(None, 256, 256, 3), found shape=(None, 128, 128, 3)

# %% [markdown]
# ##  model_att_unet

# %%
model_att_unet = models.att_unet_2d((128, 128, 3), filter_num=[64, 128, 256, 512, 1024],
                           n_labels=num_labels,
                           stack_num_down=2, stack_num_up=2,
                           activation='ReLU',
                           atten_activation='ReLU', attention='add',
                           output_activation='Sigmoid',
                           batch_norm=True, pool=False, unpool=False,
                           backbone='VGG19', weights='imagenet',
                           freeze_backbone=True, freeze_batch_norm=True,
                           name='attunet')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras_unet_collection/_backbone_zoo.py:45: UserWarning:
#
# Backbone VGG19 does not use batch norm, but other layers received batch_norm=True
#   warnings.warn(param_mismatch);
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 4s 0us/step

# %%
model_att_unet.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate = 1e-3),
                                       metrics=[tf.keras.metrics.Precision(), 'accuracy',
                      tf.keras.metrics.Recall(),
                        losses.dice_coef,
                       keras.metrics.IoU(num_classes=2, target_class_ids=[0]),
                        keras.metrics.IoU(num_classes=2, target_class_ids=[1]),
                       keras.metrics.BinaryIoU(  target_class_ids=(0, 1), threshold=0.5, name=None, dtype=None),
                       tf.keras.metrics.MeanIoU(num_classes=2)]
                       )
csv_logger=tf.keras.callbacks.CSVLogger('AttUnetVGG19.csv', separator=',', append=True)

# print(model_att_unet.summary())

# %%
# model_att_unet.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate = 1e-3),
#                        metrics=[tf.keras.metrics.Precision(), 'accuracy',
#                         tf.keras.metrics.Recall(),
#                        keras.metrics.IoU(num_classes=2, target_class_ids=[0]),
#                         keras.metrics.IoU(num_classes=2, target_class_ids=[1]),
#                        keras.metrics.BinaryIoU(  target_class_ids=(0, 1), threshold=0.5, name=None, dtype=None),
#                        tf.keras.metrics.MeanIoU(num_classes=2),
#                        losses.dice_coef])


# csv_logger=tf.keras.callbacks.CSVLogger('KerasAttUnetEpoch50V2.csv', separator=',', append=True)

# print(model_att_unet.summary())

# %%
start_att = datetime.now()

att_unet_history = model_att_unet.fit(X_train, y_train,
                    verbose=1,
                    batch_size = batch_size,
                    validation_data=(X_test, y_test ),
                    shuffle=False,
                    epochs=50,
                    callbacks=[csv_logger])

stop_att = datetime.now()
#Execution time of the model
execution_time_att_Unet = stop_att-start_att
# Out:
# Epoch 1/50
# 102/102 [==============================] - 1364s 13s/step - loss: 0.1059 - precision: 0.4052 - accuracy: 0.9849 - recall: 0.3791 - dice_coef: 0.1642 - io_u: 0.9871 - io_u_1: 0.0000e+00 - binary_io_u: 0.6142 - mean_io_u: 0.4936 - val_loss: 0.2242 - val_precision: 0.1942 - val_accuracy: 0.9542 - val_recall: 0.9730 - val_dice_coef: 0.1419 - val_io_u: 0.9889 - val_io_u_1: 0.0115 - val_binary_io_u: 0.5735 - val_mean_io_u: 0.5002
# Epoch 2/50
# 102/102 [==============================] - 1314s 13s/step - loss: 0.0051 - precision: 0.9418 - accuracy: 0.9984 - recall: 0.9339 - dice_coef: 0.8587 - io_u: 0.9871 - io_u_1: 0.0000e+00 - binary_io_u: 0.9407 - mean_io_u: 0.4936 - val_loss: 0.0142 - val_precision: 0.7920 - val_accuracy: 0.9953 - val_recall: 0.7871 - val_dice_coef: 0.6973 - val_io_u: 0.9887 - val_io_u_1: 0.0000e+00 - val_binary_io_u: 0.8237 - val_mean_io_u: 0.4944
# Epoch 9/50
#   9/102 [=>............................] - ETA: 19:02 - loss: 0.0053 - precision: 0.9540 - accuracy: 0.9983 - recall: 0.9470 - dice_coef: 0.8821 - io_u: 0.9825 - io_u_1: 0.0000e+00 - binary_io_u: 0.9519 - mean_io_u: 0.4912

# %%
print(execution_time_att_Unet)
# Out:
# 0:11:22.971647

# %%
model = model_att_unet
# 2 3 4 18 20 27 40 48
import random
test_img_number = random.randint(0, X_pred.shape[0]-1)  #Test with 119

test_img_number = 27
print(test_img_number)
test_img = X_pred[test_img_number]
ground_truth=y_pred[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
prediction = (model.predict(test_img_input)[0,:,:,0] > 0.5).astype(np.uint8)

plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img, cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(prediction, cmap='gray')

plt.show()
# Out:
# 27
# 1/1 [==============================] - 0s 49ms/step
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-3598e60ef5ca> in <cell line: 12>()
#      10 #test_img_norm=test_img[:,:,0][:,:,None]
#      11 test_img_input=np.expand_dims(test_img, 0)
# ---> 12 prediction = (model.predict(test_img_input)[0,:,:,0] > 0.5).astype(np.uint8)
#      13
#      14 plt.figure(figsize=(16, 8))
#
# TypeError: list indices must be integers or slices, not tuple

# %% [markdown]
# ## Swin Net

# %%
y_train.shape
# Out:
# (810, 256, 256, 1)

# %%
swin_unet_2d_model = models.swin_unet_2d((256, 256, 3), filter_num_begin=64, n_labels=1, depth=4, stack_num_down=2, stack_num_up=2,
                            patch_size=(2, 2), num_heads=[4, 8, 8, 8], window_size=[4, 2, 2, 2], num_mlp=512,
                            output_activation='Softmax', shift_window=True, name='swin_unet')

# %%
swin_unet_2d_model.compile(loss='binary_crossentropy', optimizer=Adam(lr = 1e-3),
              metrics=['accuracy', losses.dice_coef])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
start1 = datetime.datetime.now()
swin_unet_2d_model_history = swin_unet_2d_model.fit(X_train, y_train,
                    verbose=1,
                    batch_size = batch_size,
                    validation_data=(X_test, y_test ),
                    shuffle=False,
                    epochs=50)

stop1 = datetime.datetime.now()
#Execution time of the model
execution_time_Unet = stop1-start1
print("UNet execution time is: ", execution_time_Unet)
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-495bba0c2ddc> in <cell line: 2>()
#       1 start1 = datetime.datetime.now()
# ----> 2 swin_unet_2d_model_history = swin_unet_2d_model.fit(X_train, y_train,
#       3                     verbose=1,
#       4                     batch_size = batch_size,
#       5                     validation_data=(X_test, y_test ),
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1401, in train_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1384, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1373, in run_step  **
#         outputs = model.train_step(data)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1150, in train_step
#         y_pred = self(x, training=True)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/input_spec.py", line 298, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "swin_unet_model" is incompatible with the layer: expected shape=(None, 256, 256, 3), found shape=(None, 128, 128, 3)

# %%
from glob import glob
import numpy as np
from sklearn.model_selection import train_test_split
import cv2
import torch
import torch.nn as nn
import torch.nn.functional
import torchvision
from torch.utils.data import TensorDataset
import math

# %%
X_train = train_imgs
Y_train = train_msks
X_valid = val_imgs
Y_valid = val_msks
X_test = test_imgs
Y_test = test_msks

X_train.shape, X_valid.shape, X_test.shape, Y_train.shape, Y_valid.shape, Y_test.shape
# Out:
# ((810, 128, 128, 3),
#  (100, 128, 128, 3),
#  (100, 128, 128, 3),
#  (810, 128, 128, 1),
#  (100, 128, 128, 1),
#  (100, 128, 128, 1))

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-5ad52488ebe2> in <cell line: 3>()
#       1 BATCH_SIZE = 32
#       2
# ----> 3 train_loader = torch.utils.data.DataLoader(TensorDataset(X_train,Y_train), batch_size=BATCH_SIZE,
#       4                                         shuffle=True)
#       5
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataset.py in __init__(self, *tensors)
#     200
#     201     def __init__(self, *tensors: Tensor) -> None:
# --> 202         assert all(tensors[0].size(0) == tensor.size(0) for tensor in tensors), "Size mismatch between tensors"
#     203         self.tensors = tensors
#     204
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataset.py in <genexpr>(.0)
#     200
#     201     def __init__(self, *tensors: Tensor) -> None:
# --> 202         assert all(tensors[0].size(0) == tensor.size(0) for tensor in tensors), "Size mismatch between tensors"
#     203         self.tensors = tensors
#     204
#
# TypeError: 'int' object is not callable

# %% [markdown]
# ## Model: Recurrent Residual (R2) U-Net

# %%
# help(models.r2_unet_2d)
model_r2_unet = models.r2_unet_2d((128, 128, 3), [64, 128, 256, 512], n_labels=1,
                          stack_num_down=2, stack_num_up=1, recur_num=2,
                          activation='ReLU', output_activation='Softmax',
                          batch_norm=True, pool='max', unpool='nearest', name='r2unet')


model_r2_unet.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate = 1e-3),
              metrics=['accuracy', losses.dice_coef])
csv_logger=tf.keras.callbacks.CSVLogger('R2Unet.csv', separator=',', append=True)
# print(model_r2_Unet_from_scratch.summary())

# model_r2_Unet_from_scratch.save('r2_UNet_from_scratch_50epochs.hdf5')

# %%
# print(model_r2_unet.summary())

# %%
start5 = datetime.now()

model_r2_unet_history =  model_r2_unet.fit(X_train, y_train,
                    verbose=1,
                    batch_size = batch_size,
                    validation_data=(X_test, y_test ),
                    shuffle=False,
                    epochs=50,
                    callbacks=[csv_logger])

stop5 = datetime.now()
#Execution time of the model
execution_time_r2_Unet = stop5-start5
print("R2 UNet from scratch execution time is: ", execution_time_r2_Unet)
# Out:
# Epoch 1/50
# 102/102 [==============================] - 54s 291ms/step - loss: 0.0589 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 9.0886 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 2/50
# 102/102 [==============================] - 29s 284ms/step - loss: 0.0297 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0439 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 3/50
# 102/102 [==============================] - 28s 278ms/step - loss: 0.0253 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0480 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 4/50
# 102/102 [==============================] - 29s 281ms/step - loss: 0.0239 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0457 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 5/50
# 102/102 [==============================] - 29s 281ms/step - loss: 0.0208 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0340 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 6/50
# 102/102 [==============================] - 29s 281ms/step - loss: 0.0208 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0374 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 7/50
# 102/102 [==============================] - 28s 279ms/step - loss: 0.0194 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0217 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 8/50
# 102/102 [==============================] - 28s 279ms/step - loss: 0.0177 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0226 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 9/50
# 102/102 [==============================] - 29s 281ms/step - loss: 0.0152 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0172 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 10/50
# 102/102 [==============================] - 28s 279ms/step - loss: 0.0136 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0314 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 11/50
# 102/102 [==============================] - 29s 281ms/step - loss: 0.0128 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0247 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 12/50
# 102/102 [==============================] - 29s 281ms/step - loss: 0.0117 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0294 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 13/50
# 102/102 [==============================] - 28s 279ms/step - loss: 0.0105 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0285 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 14/50
# 102/102 [==============================] - 29s 281ms/step - loss: 0.0095 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0323 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 15/50
# 102/102 [==============================] - 29s 281ms/step - loss: 0.0085 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0202 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 16/50
# 102/102 [==============================] - 29s 280ms/step - loss: 0.0082 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0293 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 17/50
# 102/102 [==============================] - 29s 280ms/step - loss: 0.0079 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0189 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 18/50
# 102/102 [==============================] - 29s 280ms/step - loss: 0.0073 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0177 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 19/50
# 102/102 [==============================] - 29s 280ms/step - loss: 0.0067 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0215 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 20/50
# 102/102 [==============================] - 29s 280ms/step - loss: 0.0060 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0168 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 21/50
# 102/102 [==============================] - 29s 280ms/step - loss: 0.0056 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0184 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 22/50
# 102/102 [==============================] - 29s 281ms/step - loss: 0.0051 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0132 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 23/50
# 102/102 [==============================] - 29s 280ms/step - loss: 0.0049 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0161 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 24/50
# 102/102 [==============================] - 29s 280ms/step - loss: 0.0047 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0184 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 25/50
# 102/102 [==============================] - 29s 282ms/step - loss: 0.0041 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0221 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 26/50
# 102/102 [==============================] - 29s 280ms/step - loss: 0.0039 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0380 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 27/50
# 102/102 [==============================] - 29s 280ms/step - loss: 0.0040 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0176 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 28/50
# 102/102 [==============================] - 29s 281ms/step - loss: 0.0096 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 1.2054 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 29/50
# 102/102 [==============================] - 29s 280ms/step - loss: 0.0098 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0416 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 30/50
# 102/102 [==============================] - 29s 281ms/step - loss: 0.0057 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0134 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 31/50
# 102/102 [==============================] - 29s 280ms/step - loss: 0.0042 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0163 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 32/50
# 102/102 [==============================] - 29s 280ms/step - loss: 0.0036 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0173 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 33/50
# 102/102 [==============================] - 29s 280ms/step - loss: 0.0033 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0150 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 34/50
# 102/102 [==============================] - 29s 281ms/step - loss: 0.0031 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0209 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 35/50
# 102/102 [==============================] - 29s 280ms/step - loss: 0.0030 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0167 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 36/50
# 102/102 [==============================] - 29s 280ms/step - loss: 0.0029 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0225 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 37/50
# 102/102 [==============================] - 29s 280ms/step - loss: 0.0027 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0192 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 38/50
# 102/102 [==============================] - 29s 280ms/step - loss: 0.0026 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0208 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 39/50
# 102/102 [==============================] - 29s 280ms/step - loss: 0.0050 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 13.3594 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 40/50
# 102/102 [==============================] - 29s 280ms/step - loss: 0.0125 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0201 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 41/50
# 102/102 [==============================] - 29s 281ms/step - loss: 0.0075 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0191 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 42/50
# 102/102 [==============================] - 29s 281ms/step - loss: 0.0052 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0243 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 43/50
# 102/102 [==============================] - 29s 280ms/step - loss: 0.0038 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0225 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 44/50
# 102/102 [==============================] - 29s 281ms/step - loss: 0.0031 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0268 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 45/50
# 102/102 [==============================] - 29s 281ms/step - loss: 0.0027 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0259 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 46/50
# 102/102 [==============================] - 29s 280ms/step - loss: 0.0024 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0255 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 47/50
# 102/102 [==============================] - 29s 281ms/step - loss: 0.0023 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0213 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 48/50
# 102/102 [==============================] - 29s 280ms/step - loss: 0.0023 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0275 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 49/50
# 102/102 [==============================] - 29s 281ms/step - loss: 0.0024 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0309 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# Epoch 50/50
# 102/102 [==============================] - 29s 280ms/step - loss: 0.0023 - accuracy: 0.0129 - dice_coef: 0.0254 - val_loss: 0.0262 - val_accuracy: 0.0113 - val_dice_coef: 0.0237
# R2 UNet from scratch execution time is:  0:24:15.681019

# %%
model = model_att_unet
import random
test_img_number = random.randint(0, X_test.shape[0]-1)  #Test with 119

test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
prediction = (model.predict(test_img_input)[0,:,:,0] > 0.5).astype(np.uint8)

plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img, cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(prediction, cmap='gray')

plt.show()

# %%
history = att_unet_history


#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['dice_coef']
#acc = history.history['accuracy']
val_acc = history.history['val_dice_coef']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training Dice')
plt.plot(epochs, val_acc, 'r', label='Validation Dice')
plt.title('Training and validation Dice')
plt.xlabel('Epochs')
plt.ylabel('Dice')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 history = Unet_history
#       3 loss = history.history['loss']
#       4 val_loss = history.history['val_loss']
#
# NameError: name 'Unet_history' is not defined

# %% [markdown]
# #Unet3+ Unet

# %%
model = models.unet_3plus_2d((128, 128, 3), n_labels=1, filter_num_down=[64, 128, 256, 512],
                             filter_num_skip='auto', filter_num_aggregate='auto',
                             backbone='VGG19', weights='imagenet',
                             stack_num_down=2, stack_num_up=1, activation='ReLU', output_activation='Sigmoid',
                             batch_norm=True, pool='max', unpool=False, deep_supervision=True, name='u3p')
# Out:
# Automated hyper-parameter determination is applied with the following details:
# ----------
# 	Number of convolution filters after each full-scale skip connection: filter_num_skip = [64, 64, 64]
# 	Number of channels of full-scale aggregated feature maps: filter_num_aggregate = 256
# /usr/local/lib/python3.10/dist-packages/keras_unet_collection/_backbone_zoo.py:45: UserWarning:
#
# Backbone VGG19 does not use batch norm, but other layers received batch_norm=True
#   warnings.warn(param_mismatch);
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 2s 0us/step
# ----------
# deep_supervision = True
# names of output tensors are listed as follows ("sup0" is the shallowest supervision layer;
# "final" is the final output layer):
#
# 	u3p_output_sup0_activation
# 	u3p_output_sup1_activation
# 	u3p_output_sup2_activation
# 	u3p_output_final_activation

# %%
model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate = 1e-3),
                      metrics=[tf.keras.metrics.Precision(), 'accuracy',
                      tf.keras.metrics.Recall(),
                        losses.dice_coef,
                       keras.metrics.IoU(num_classes=2, target_class_ids=[0]),
                        keras.metrics.IoU(num_classes=2, target_class_ids=[1]),
                       keras.metrics.BinaryIoU(  target_class_ids=(0, 1), threshold=0.5, name=None, dtype=None),
                       tf.keras.metrics.MeanIoU(num_classes=2)]
              )

# print(model.summary())

# %%
csv_logger=tf.keras.callbacks.CSVLogger('UNet3plusVGG19.csv', separator=',', append=True)
start1 = datetime.now()
Unet3plus_history = model.fit(X_train, y_train,
                    verbose=1,
                    batch_size = batch_size,
                    validation_data=(X_test, y_test ),
                    shuffle=False,
                    epochs=50,
                    callbacks=[csv_logger]
                    )

stop1 = datetime.now()
#Execution time of the model
execution_time_Unet = stop1-start1
print("UNet execution time is: ", execution_time_Unet)
# print(model_Unet.summary())
# Out:
# Epoch 1/50
# 102/102 [==============================] - 21s 203ms/step - loss: 1.1065 - u3p_output_sup0_activation_loss: 0.0167 - u3p_output_sup1_activation_loss: 0.4885 - u3p_output_sup2_activation_loss: 0.5922 - u3p_output_final_activation_loss: 0.0091 - u3p_output_sup0_activation_precision: 0.6464 - u3p_output_sup0_activation_accuracy: 0.9919 - u3p_output_sup0_activation_recall: 0.8188 - u3p_output_sup0_activation_dice_coef: 0.6249 - u3p_output_sup0_activation_io_u: 0.9871 - u3p_output_sup0_activation_io_u_1: 0.0000e+00 - u3p_output_sup0_activation_binary_io_u: 0.7787 - u3p_output_sup0_activation_mean_io_u: 0.4936 - u3p_output_sup1_activation_precision: 0.0432 - u3p_output_sup1_activation_accuracy: 0.9079 - u3p_output_sup1_activation_recall: 0.2915 - u3p_output_sup1_activation_dice_coef: 0.0359 - u3p_output_sup1_activation_io_u: 0.9871 - u3p_output_sup1_activation_io_u_1: 0.0000e+00 - u3p_output_sup1_activation_binary_io_u: 0.4733 - u3p_output_sup1_activation_mean_io_u: 0.4936 - u3p_output_sup2_activation_precision: 0.0375 - u3p_output_sup2_activation_accuracy: 0.9723 - u3p_output_sup2_activation_recall: 0.0469 - u3p_output_sup2_activation_dice_coef: 0.0263 - u3p_output_sup2_activation_io_u: 0.9871 - u3p_output_sup2_activation_io_u_1: 0.0000e+00 - u3p_output_sup2_activation_binary_io_u: 0.4968 - u3p_output_sup2_activation_mean_io_u: 0.4936 - u3p_output_final_activation_precision: 0.8756 - u3p_output_final_activation_accuracy: 0.9964 - u3p_output_final_activation_recall: 0.8436 - u3p_output_final_activation_dice_coef: 0.7813 - u3p_output_final_activation_io_u: 0.9871 - u3p_output_final_activation_io_u_1: 0.0000e+00 - u3p_output_final_activation_binary_io_u: 0.8749 - u3p_output_final_activation_mean_io_u: 0.4936 - val_loss: 1.0210 - val_u3p_output_sup0_activation_loss: 0.0220 - val_u3p_output_sup1_activation_loss: 0.4242 - val_u3p_output_sup2_activation_loss: 0.5589 - val_u3p_output_final_activation_loss: 0.0158 - val_u3p_output_sup0_activation_precision: 0.5132 - val_u3p_output_sup0_activation_accuracy: 0.9892 - val_u3p_output_sup0_activation_recall: 0.7799 - val_u3p_output_sup0_activation_dice_coef: 0.5299 - val_u3p_output_sup0_activation_io_u: 0.9887 - val_u3p_output_sup0_activation_io_u_1: 0.0000e+00 - val_u3p_output_sup0_activation_binary_io_u: 0.7187 - val_u3p_output_sup0_activation_mean_io_u: 0.4944 - val_u3p_output_sup1_activation_precision: 0.0624 - val_u3p_output_sup1_activation_accuracy: 0.9291 - val_u3p_output_sup1_activation_recall: 0.3771 - val_u3p_output_sup1_activation_dice_coef: 0.0406 - val_u3p_output_sup1_activation_io_u: 0.9887 - val_u3p_output_sup1_activation_io_u_1: 0.0000e+00 - val_u3p_output_sup1_activation_binary_io_u: 0.4927 - val_u3p_output_sup1_activation_mean_io_u: 0.4944 - val_u3p_output_sup2_activation_precision: 0.0314 - val_u3p_output_sup2_activation_accuracy: 0.9737 - val_u3p_output_sup2_activation_recall: 0.0449 - val_u3p_output_sup2_activation_dice_coef: 0.0249 - val_u3p_output_sup2_activation_io_u: 0.9887 - val_u3p_output_sup2_activation_io_u_1: 0.0000e+00 - val_u3p_output_sup2_activation_binary_io_u: 0.4962 - val_u3p_output_sup2_activation_mean_io_u: 0.4944 - val_u3p_output_final_activation_precision: 0.6940 - val_u3p_output_final_activation_accuracy: 0.9936 - val_u3p_output_final_activation_recall: 0.7749 - val_u3p_output_final_activation_dice_coef: 0.6455 - val_u3p_output_final_activation_io_u: 0.9887 - val_u3p_output_final_activation_io_u_1: 0.0000e+00 - val_u3p_output_final_activation_binary_io_u: 0.7856 - val_u3p_output_final_activation_mean_io_u: 0.4944
# Epoch 2/50
# 102/102 [==============================] - 21s 208ms/step - loss: 0.9114 - u3p_output_sup0_activation_loss: 0.0111 - u3p_output_sup1_activation_loss: 0.3638 - u3p_output_sup2_activation_loss: 0.5308 - u3p_output_final_activation_loss: 0.0058 - u3p_output_sup0_activation_precision: 0.7604 - u3p_output_sup0_activation_accuracy: 0.9949 - u3p_output_sup0_activation_recall: 0.8759 - u3p_output_sup0_activation_dice_coef: 0.7299 - u3p_output_sup0_activation_io_u: 0.9871 - u3p_output_sup0_activation_io_u_1: 0.0000e+00 - u3p_output_sup0_activation_binary_io_u: 0.8406 - u3p_output_sup0_activation_mean_io_u: 0.4936 - u3p_output_sup1_activation_precision: 0.0730 - u3p_output_sup1_activation_accuracy: 0.9300 - u3p_output_sup1_activation_recall: 0.3803 - u3p_output_sup1_activation_dice_coef: 0.0511 - u3p_output_sup1_activation_io_u: 0.9871 - u3p_output_sup1_activation_io_u_1: 0.0000e+00 - u3p_output_sup1_activation_binary_io_u: 0.4975 - u3p_output_sup1_activation_mean_io_u: 0.4936 - u3p_output_sup2_activation_precision: 0.0509 - u3p_output_sup2_activation_accuracy: 0.9725 - u3p_output_sup2_activation_recall: 0.0646 - u3p_output_sup2_activation_dice_coef: 0.0277 - u3p_output_sup2_activation_io_u: 0.9871 - u3p_output_sup2_activation_io_u_1: 0.0000e+00 - u3p_output_sup2_activation_binary_io_u: 0.5009 - u3p_output_sup2_activation_mean_io_u: 0.4936 - u3p_output_final_activation_precision: 0.9162 - u3p_output_final_activation_accuracy: 0.9977 - u3p_output_final_activation_recall: 0.9032 - u3p_output_final_activation_dice_coef: 0.8593 - u3p_output_final_activation_io_u: 0.9871 - u3p_output_final_activation_io_u_1: 0.0000e+00 - u3p_output_final_activation_binary_io_u: 0.9160 - u3p_output_final_activation_mean_io_u: 0.4936 - val_loss: 0.8556 - val_u3p_output_sup0_activation_loss: 0.0205 - val_u3p_output_sup1_activation_loss: 0.3144 - val_u3p_output_sup2_activation_loss: 0.5031 - val_u3p_output_final_activation_loss: 0.0176 - val_u3p_output_sup0_activation_precision: 0.7610 - val_u3p_output_sup0_activation_accuracy: 0.9940 - val_u3p_output_sup0_activation_recall: 0.6800 - val_u3p_output_sup0_activation_dice_coef: 0.5945 - val_u3p_output_sup0_activation_io_u: 0.9887 - val_u3p_output_sup0_activation_io_u_1: 0.0000e+00 - val_u3p_output_sup0_activation_binary_io_u: 0.7771 - val_u3p_output_sup0_activation_mean_io_u: 0.4944 - val_u3p_output_sup1_activation_precision: 0.0620 - val_u3p_output_sup1_activation_accuracy: 0.9320 - val_u3p_output_sup1_activation_recall: 0.3565 - val_u3p_output_sup1_activation_dice_coef: 0.0522 - val_u3p_output_sup1_activation_io_u: 0.9887 - val_u3p_output_sup1_activation_io_u_1: 0.0000e+00 - val_u3p_output_sup1_activation_binary_io_u: 0.4937 - val_u3p_output_sup1_activation_mean_io_u: 0.4944 - val_u3p_output_sup2_activation_precision: 0.0361 - val_u3p_output_sup2_activation_accuracy: 0.9738 - val_u3p_output_sup2_activation_recall: 0.0516 - val_u3p_output_sup2_activation_dice_coef: 0.0259 - val_u3p_output_sup2_activation_io_u: 0.9887 - val_u3p_output_sup2_activation_io_u_1: 0.0000e+00 - val_u3p_output_sup2_activation_binary_io_u: 0.4977 - val_u3p_output_sup2_activation_mean_io_u: 0.4944 - val_u3p_output_final_activation_precision: 0.8177 - val_u3p_output_final_activation_accuracy: 0.9944 - val_u3p_output_final_activation_recall: 0.6450 - val_u3p_output_final_activation_dice_coef: 0.6771 - val_u3p_output_final_activation_io_u: 0.9887 - val_u3p_output_final_activation_io_u_1: 0.0000e+00 - val_u3p_output_final_activation_binary_io_u: 0.7791 - val_u3p_output_final_activation_mean_io_u: 0.4944
# Epoch 3/50
04 - val_u3p_output_sup2_activation_binary_io_u: 0.5240 - val_u3p_output_sup2_activation_mean_io_u: 0.4944 - val_u3p_output_final_activation_precision: 0.8146 - val_u3p_output_final_activation_accuracy: 0.9945 - val_u3p_output_final_activation_recall: 0.6654 - val_u3p_output_final_activation_dice_coef: 0.6936 - val_u3p_output_final_activation_io_u: 0.9887 - val_u3p_output_final_activation_io_u_1: 0.0000e+00 - val_u3p_output_final_activation_binary_io_u: 0.7862 - val_u3p_output_final_activation_mean_io_u: 0.4944
# Epoch 4/50
# 102/102 [==============================] - 21s 205ms/step - loss: 0.6888 - u3p_output_sup0_activation_loss: 0.0057 - u3p_output_sup1_activation_loss: 0.2403 - u3p_output_sup2_activation_loss: 0.4396 - u3p_output_final_activation_loss: 0.0032 - u3p_output_sup0_activation_precision: 0.9156 - u3p_output_sup0_activation_accuracy: 0.9978 - u3p_output_sup0_activation_recall: 0.9133 - u3p_output_sup0_activation_dice_coef: 0.8516 - u3p_output_sup0_activation_io_u: 0.9871 - u3p_output_sup0_activation_io_u_1: 1.3484e-04 - u3p_output_sup0_activation_binary_io_u: 0.9201 - u3p_output_sup0_activation_mean_io_u: 0.4936 - u3p_output_sup1_activation_precision: 0.8843 - u3p_output_sup1_activation_accuracy: 0.9925 - u3p_output_sup1_activation_recall: 0.4750 - u3p_output_sup1_activation_dice_coef: 0.0788 - u3p_output_sup1_activation_io_u: 0.9871 - u3p_output_sup1_activation_io_u_1: 1.7002e-04 - u3p_output_sup1_activation_binary_io_u: 0.7198 - u3p_output_sup1_activation_mean_io_u: 0.4937 - u3p_output_sup2_activation_precision: 0.8317 - u3p_output_sup2_activation_accuracy: 0.9881 - u3p_output_sup2_activation_recall: 0.0902 - u3p_output_sup2_activation_dice_coef: 0.0307 - u3p_output_sup2_activation_io_u: 0.9871 - u3p_output_sup2_activation_io_u_1: 1.2312e-04 - u3p_output_sup2_activation_binary_io_u: 0.5383 - u3p_output_sup2_activation_mean_io_u: 0.4936 - u3p_output_final_activation_precision: 0.9524 - u3p_output_final_activation_accuracy: 0.9987 - u3p_output_final_activation_recall: 0.9478 - u3p_output_final_activation_dice_coef: 0.9193 - u3p_output_final_activation_io_u: 0.9871 - u3p_output_final_activation_io_u_1: 0.0000e+00 - u3p_output_final_activation_binary_io_u: 0.9518 - u3p_output_final_activation_mean_io_u: 0.4936 - val_loss: 0.7067 - val_u3p_output_sup0_activation_loss: 0.0200 - val_u3p_output_sup1_activation_loss: 0.2408 - val_u3p_output_sup2_activation_loss: 0.4255 - val_u3p_output_final_activation_loss: 0.0204 - val_u3p_output_sup0_activation_precision: 0.7751 - val_u3p_output_sup0_activation_accuracy: 0.9944 - val_u3p_output_sup0_activation_recall: 0.7108 - val_u3p_output_sup0_activation_dice_coef: 0.6897 - val_u3p_output_sup0_activation_io_u: 0.9888 - val_u3p_output_sup0_activation_io_u_1: 0.0026 - val_u3p_output_sup0_activation_binary_io_u: 0.7918 - val_u3p_output_sup0_activation_mean_io_u: 0.4957 - val_u3p_output_sup1_activation_precision: 0.7809 - val_u3p_output_sup1_activation_accuracy: 0.9915 - val_u3p_output_sup1_activation_recall: 0.3447 - val_u3p_output_sup1_activation_dice_coef: 0.0616 - val_u3p_output_sup1_activation_io_u: 0.9887 - val_u3p_output_sup1_activation_io_u_1: 4.3353e-04 - val_u3p_output_sup1_activation_binary_io_u: 0.6529 - val_u3p_output_sup1_activation_mean_io_u: 0.4946 - val_u3p_output_sup2_activation_precision: 0.6965 - val_u3p_output_sup2_activation_accuracy: 0.9892 - val_u3p_output_sup2_activation_recall: 0.0695 - val_u3p_output_sup2_activation_dice_coef: 0.0278 - val_u3p_output_sup2_activation_io_u: 0.9887 - val_u3p_output_sup2_activation_io_u_1: 2.1677e-04 - val_u3p_output_sup2_activation_binary_io_u: 0.5283 - val_u3p_output_sup2_activation_mean_io_u: 0.4945 - val_u3p_output_final_activation_precision: 0.7814 - val_u3p_output_final_activation_accuracy: 0.9946 - val_u3p_output_final_activation_recall: 0.7192 - val_u3p_output_final_activation_dice_coef: 0.7229 - val_u3p_output_final_activation_io_u: 0.9887 - val_u3p_output_final_activation_io_u_1: 0.0000e+00 - val_u3p_output_final_activation_binary_io_u: 0.7967 - val_u3p_output_final_activation_mean_io_u: 0.4944
# Epoch 5/50
# 102/102 [==============================] - 21s 205ms/step - loss: 0.6484 - u3p_output_sup0_activation_loss: 0.0050 - u3p_output_sup1_activation_loss: 0.2290 - u3p_output_sup2_activation_loss: 0.4117 - u3p_output_final_activation_loss: 0.0027 - u3p_output_sup0_activation_precision: 0.9211 - u3p_output_sup0_activation_accuracy: 0.9980 - u3p_output_sup0_activation_recall: 0.9223 - u3p_output_sup0_activation_dice_coef: 0.8696 - u3p_output_sup0_activation_io_u: 0.9872 - u3p_output_sup0_activation_io_u_1: 8.0319e-04 - u3p_output_sup0_activation_binary_io_u: 0.9264 - u3p_output_sup0_activation_mean_io_u: 0.4940 - u3p_output_sup1_activation_precision: 0.8886 - u3p_output_sup1_activation_accuracy: 0.9926 - u3p_output_sup1_activation_recall: 0.4810 - u3p_output_sup1_activation_dice_coef: 0.0817 - u3p_output_sup1_activation_io_u: 0.9872 - u3p_output_sup1_activation_io_u_1: 3.4590e-04 - u3p_output_sup1_activation_binary_io_u: 0.7231 - u3p_output_sup1_activation_mean_io_u: 0.4937 - u3p_output_sup2_activation_precision: 0.8542 - u3p_output_sup2_activation_accuracy: 0.9882 - u3p_output_sup2_activation_recall: 0.0989 - u3p_output_sup2_activation_dice_coef: 0.0315 - u3p_output_sup2_activation_io_u: 0.9871 - u3p_output_sup2_activation_io_u_1: 1.5243e-04 - u3p_output_sup2_activation_binary_io_u: 0.5427 - u3p_output_sup2_activation_mean_io_u: 0.4937 - u3p_output_final_activation_precision: 0.9600 - u3p_output_final_activation_accuracy: 0.9990 - u3p_output_final_activation_recall: 0.9584 - u3p_output_final_activation_dice_coef: 0.9321 - u3p_output_final_activation_io_u: 0.9871 - u3p_output_final_activation_io_u_1: 1.4071e-04 
_u: 0.7240 - u3p_output_sup1_activation_mean_io_u: 0.4938 - u3p_output_sup2_activation_precision: 0.8685 - u3p_output_sup2_activation_accuracy: 0.9883 - u3p_output_sup2_activation_recall: 0.1025 - u3p_output_sup2_activation_dice_coef: 0.0321 - u3p_output_sup2_activation_io_u: 0.9871 - u3p_output_sup2_activation_io_u_1: 1.5829e-04 - u3p_output_sup2_activation_binary_io_u: 0.5446 - u3p_output_sup2_activation_mean_io_u: 0.4937 - u3p_output_final_activation_precision: 0.9662 - u3p_output_final_activation_accuracy: 0.9991 - u3p_output_final_activation_recall: 0.9622 - u3p_output_final_activation_dice_coef: 0.9390 - u3p_output_final_activation_io_u: 0.9871 - u3p_output_final_activation_io_u_1: 1.0553e-04 - u3p_output_final_activation_binary_io_u: 0.9649 - u3p_output_final_activation_mean_io_u: 0.4936 - val_loss: 0.6349 - val_u3p_output_sup0_activation_loss: 0.0194 - val_u3p_output_sup1_activation_loss: 0.2172 - val_u3p_output_sup2_activation_loss: 0.3747 - val_u3p_output_final_activation_loss: 0.0236 - val_u3p_output_sup0_activation_precision: 0.6434 - val_u3p_output_sup0_activation_accuracy: 0.9930 - val_u3p_output_sup0_activation_recall: 0.8419 - val_u3p_output_sup0_activation_dice_coef: 0.6655 - val_u3p_output_sup0_activation_io_u: 0.9888 - val_u3p_output_sup0_activation_io_u_1: 0.0040 - val_u3p_output_sup0_activation_binary_io_u: 0.7835 - val_u3p_output_sup0_activation_mean_io_u: 0.4964 - val_u3p_output_sup1_activation_precision: 0.7703 - val_u3p_output_sup1_activation_accuracy: 0.9919 - val_u3p_output_sup1_activation_recall: 0.4003 - val_u3p_output_sup1_activation_dice_coef: 0.0692 - val_u3p_output_sup1_activation_io_u: 0.9887 - val_u3p_output_sup1_activation_io_u_1: 2.1677e-04 - val_u3p_output_sup1_activation_binary_io_u: 0.6747 - val_u3p_output_sup1_activation_mean_io_u: 0.4945 - val_u3p_output_sup2_activation_precision: 0.7231 - val_u3p_output_sup2_activation_accuracy: 0.9893 - val_u3p_output_sup2_activation_recall: 0.0754 - val_u3p_output_sup2_activation_dice_coef: 0.0284 - val_u3p_output_sup2_activation_io_u: 0.9887 - val_u3p_output_sup2_activation_io_u_1: 3.2515e-04 - val_u3p_output_sup2_activation_binary_io_u: 0.5313 - val_u3p_output_sup2_activation_mean_io_u: 0.4945 - val_u3p_output_final_activation_precision: 0.6396 - val_u3p_output_final_activation_accuracy: 0.9929 - val_u3p_output_final_activation_recall: 0.8422 - val_u3p_output_final_activation_dice_coef: 0.6913 - val_u3p_output_final_activation_io_u: 0.9888 - val_u3p_output_final_activation_io_u_1: 0.0039 - val_u3p_output_final_activation_binary_io_u: 0.7820 - val_u3p_output_final_activation_mean_io_u: 0.4963
# Epoch 7/50
activation_binary_io_u: 0.5318 - val_u3p_output_sup2_activation_mean_io_u: 0.4946 - val_u3p_output_final_activation_precision: 0.7477 - val_u3p_output_final_activation_accuracy: 0.9945 - val_u3p_output_final_activation_recall: 0.7710 - val_u3p_output_final_activation_dice_coef: 0.7366 - val_u3p_output_final_activation_io_u: 0.9889 - val_u3p_output_final_activation_io_u_1: 0.0130 - val_u3p_output_final_activation_binary_io_u: 0.8032 - val_u3p_output_final_activation_mean_io_u: 0.5009
# Epoch 8/50
# 102/102 [==============================] - 21s 204ms/step - loss: 0.5442 - u3p_output_sup0_activation_loss: 0.0040 - u3p_output_sup1_activation_loss: 0.1976 - u3p_output_sup2_activation_loss: 0.3408 - u3p_output_final_activation_loss: 0.0018 - u3p_output_sup0_activation_precision: 0.9353 - u3p_output_sup0_activation_accuracy: 0.9983 - u3p_output_sup0_activation_recall: 0.9341 - u3p_output_sup0_activation_dice_coef: 0.8965 - u3p_output_sup0_activation_io_u: 0.9872 - u3p_output_sup0_activation_io_u_1: 9.9080e-04 - u3p_output_sup0_activation_binary_io_u: 0.9379 - u3p_output_sup0_activation_mean_io_u: 0.4941 - u3p_output_sup1_activation_precision: 0.8961 - u3p_output_sup1_activation_accuracy: 0.9927 - u3p_output_sup1_activation_recall: 0.4855 - u3p_output_sup1_activation_dice_coef: 0.0892 - u3p_output_sup1_activation_io_u: 0.9872 - u3p_output_sup1_activation_io_u_1: 6.1559e-04 - u3p_output_sup1_activation_binary_io_u: 0.7261 - u3p_output_sup1_activation_mean_io_u: 0.4939 - u3p_output_sup2_activation_precision: 0.8832 - u3p_output_sup2_activation_accuracy: 0.9883 - u3p_output_sup2_activation_recall: 0.1070 - u3p_output_sup2_activation_dice_coef: 0.0331 - u3p_output_sup2_activation_io_u: 0.9871 - u3p_output_sup2_activation_io_u_1: 1.4657e-04 - u3p_output_sup2_activation_binary_io_u: 0.5469 - u3p_output_sup2_activation_mean_io_u: 0.4936 - u3p_output_final_activation_precision: 0.9757 - u3p_output_final_activation_accuracy: 0.9993 - u3p_output_final_activation_recall: 0.9724 - u3p_output_final_activation_dice_coef: 0.9556 - u3p_output_final_activation_io_u: 0.9872 - u3p_output_final_activation_io_u_1: 0.0046 - u3p_output_final_activation_binary_io_u: 0.9743 - u3p_output_final_activation_mean_io_u: 0.4959 - val_loss: 0.5874 - val_u3p_output_sup0_activation_loss: 0.0244 - val_u3p_output_sup1_activation_loss: 0.2010 - val_u3p_output_sup2_activation_loss: 0.3311 - val_u3p_output_final_activation_loss: 0.0309 - val_u3p_output_sup0_activation_precision: 0.6988 - val_u3p_output_sup0_activation_accuracy: 0.9938 - val_u3p_output_sup0_activation_recall: 0.7960 - val_u3p_output_sup0_activation_dice_coef: 0.7106 - val_u3p_output_sup0_activation_io_u: 0.9889 - val_u3p_output_sup0_activation_io_u_1: 0.0118 - val_u3p_output_sup0_activation_binary_io_u: 0.7932 - val_u3p_output_sup0_activation_mean_io_u: 0.5003 - val_u3p_output_sup1_activation_precision: 0.8190 - val_u3p_output_sup1_activation_accuracy: 0.9917 - val_u3p_output_sup1_activation_recall: 0.3357 - val_u3p_output_sup1_activation_dice_coef: 0.0668 - val_u3p_output_sup1_activation_io_u: 0.9887 - val_u3p_output_sup1_activation_io_u_1: 6.5030e-04 - val_u3p_output_sup1_activation_binary_io_u: 0.6521 - val_u3p_output_sup1_activation_mean_io_u: 0.4947 - val_u3p_output_sup2_activation_precision: 0.7310 - val_u3p_output_sup2_activation_accuracy: 0.9893 - val_u3p_output_sup2_activation_recall: 0.0770 - val_u3p_output_sup2_activation_dice_coef: 0.0289 - val_u3p_output_sup2_activation_io_u: 0.9887 - val_u3p_output_sup2_activation_io_u_1: 4.3353e-04 - val_u3p_output_sup2_activation_binary_io_u: 0.5321 - val_u3p_output_sup2_activation_mean_io_u: 0.4946 - val_u3p_output_final_activation_precision: 0.7150 - val_u3p_output_final_activation_accuracy: 0.9942 - val_u3p_output_final_activation_recall: 0.8030 - val_u3p_output_final_activation_dice_coef: 0.7370 - val_u3p_output_final_activation_io_u: 0.9891 - val_u3p_output_final_activation_io_u_1: 0.0307 - val_u3p_output_final_activation_binary_io_u: 0.8012 - val_u3p_output_final_activation_mean_io_u: 0.5099
# Epoch 9/50
# 102/102 [==============================] - 21s 202ms/step - loss: 0.5137 - u3p_output_sup0_activation_loss: 0.0037 - u3p_output_sup1_activation_loss: 0.1879 - u3p_output_sup2_activation_loss: 0.3207 - u3p_output_final_activation_loss: 0.0014 - u3p_output_sup0_activation_precision: 0.9380 - u3p_output_sup0_activation_accuracy: 0.9984 - u3p_output_sup0_activation_recall: 0.9411 - u3p_output_sup0_activation_dice_coef: 0.9036 - u3p_output_sup0_activation_io_u: 0.9872 - u3p_output_sup0_activation_io_u_1: 8.6182e-04 - u3p_output_sup0_activation_binary_io_u: 0.9422 - u3p_output_sup0_activation_mean_io_u: 0.4940 - u3p_output_sup1_activation_precision: 0.8963 - u3p_output_sup1_activation_accuracy: 0.9927 - u3p_output_sup1_activation_recall: 0.4877 - u3p_output_sup1_activation_dice_coef: 0.0920 - u3p_output_sup1_activation_io_u: 0.9872 - u3p_output_sup1_activation_io_u_1: 8.9700e-04 - u3p_output_sup1_activation_binary_io_u: 0.7272 - u3p_output_sup1_activation_mean_io_u: 0.4940 - u3p_output_sup2_activation_precision: 0.8891 - u3p_output_sup2_activation_accuracy: 0.9884 - u3p_output_sup2_activation_recall: 0.1084 - u3p_output_sup2_activation_dice_coef: 0.0336 - u3p_output_sup2_activation_io_u: 0.9871 - u3p_output_sup2_activation_io_u_1: 1.5829e-04 - u3p_output_sup2_activation_binary_io_u: 0.5476 - u3p_output_sup2_activation_mean_io_u: 0.4937 - u3p_output_final_activation_precision: 0.9796 - u3p_output_final_activation_accuracy: 0.9995 - u3p_output_final_activation_recall: 0.9801 - u3p_output_final_activation_dice_coef: 0.9643 - u3p_output_final_activation_io_u: 0.9872 - u3p_output_final_activation_io_u_1: 0.0061 - u3p_output_final_activation_binary_io_u: 0.9800 - u3p_output_final_activation_mean_io_u: 0.4966 - val_loss: 0.5564 - val_u3p_output_sup0_activation_loss: 0.0247 - val_u3p_output_sup1_activation_loss: 0.1932 - val_u3p_output_sup2_activation_loss: 0.3117 - val_u3p_output_final_activation_loss: 0.0268 - val_u3p_output_sup0_activation_precision: 0.8496 - val_u3p_output_sup0_activation_accuracy: 0.9945 - val_u3p_output_sup0_activation_recall: 0.6185 - val_u3p_output_sup0_activation_dice_coef: 0.6925 - val_u3p_output_sup0_activation_io_u: 0.9888 - val_u3p_output_sup0_activation_io_u_1: 0.0017 - val_u3p_output_sup0_activation_binary_io_u: 0.7760 - val_u3p_output_sup0_activation_mean_io_u: 0.4952 - val_u3p_output_sup1_activation_precision: 0.8862 - val_u3p_output_sup1_activation_accuracy: 0.9914 - val_u3p_output_sup1_activation_recall: 0.2675 - val_u3p_output_sup1_activation_dice_coef: 0.0612 - val_u3p_output_sup1_activation_io_u: 0.9887 - val_u3p_output_sup1_activation_io_u_1: 7.0449e-04 - val_u3p_output_sup1_activation_binary_io_u: 0.6250 - val_u3p_output_sup1_activation_mean_io_u: 0.4947 - val_u3p_output_sup2_activation_precision: 0.7383 - val_u3p_output_sup2_activation_accuracy: 0.9893 - val_u3p_output_sup2_activation_recall: 0.0772 - val_u3p_output_sup2_activation_dice_coef: 0.0292 - val_u3p_output_sup2_activation_io_u: 0.9887 - val_u3p_output_sup2_activation_io_u_1: 4.3353e-04 - val_u3p_output_sup2_activation_binary_io_u: 0.5322 - val_u3p_output_sup2_activation_mean_io_u: 0.4946 - val_u3p_output_final_activation_precision: 0.8508 - val_u3p_output_final_activation_accuracy: 0.9948 - val_u3p_output_final_activation_recall: 0.6502 - val_u3p_output_final_activation_dice_coef: 0.7278 - val_u3p_output_final_activation_io_u: 0.9888 - val_u3p_output_final_activation_io_u_1: 0.0083 - val_u3p_output_final_activation_binary_io_u: 0.7892 - val_u3p_output_final_activation_mean_io_u: 0.4986
# Epoch 10/50
# 102/102 [==============================] - 20s 200ms/step - loss: 0.4849 - u3p_output_sup0_activation_loss: 0.0034 - u3p_output_sup1_activation_loss: 0.1785 - u3p_output_sup2_activation_loss: 0.3020 - u3p_output_final_activation_loss: 0.0010 - u3p_output_sup0_activation_precision: 0.9408 - u3p_output_sup0_activation_accuracy: 0.9986 - u3p_output_sup0_activation_recall: 0.9472 - u3p_output_sup0_activation_dice_coef: 0.9108 - u3p_output_sup0_activation_io_u: 0.9872 - u3p_output_sup0_activation_io_u_1: 0.0011 - u3p_output_sup0_activation_binary_io_u: 0.9462 - u3p_output_sup0_activation_mean_io_u: 0.4941 - u3p_output_sup1_activation_precision: 0.9002 - u3p_output_sup1_activation_accuracy: 0.9928 - u3p_output_sup1_activation_recall: 0.4903 - u3p_output_sup1_activation_dice_coef: 0.0952 - u3p_output_sup1_activation_io_u: 0.9872 - u3p_output_sup1_activation_io_u_1: 0.0014 - u3p_output_sup1_activation_binary_io_u: 0.7289 - u3p_output_sup1_activation_mean_io_u: 0.4943 - u3p_output_sup2_activation_precision: 0.8942 - u3p_output_sup2_activation_accuracy: 0.9884 - u3p_output_sup2_activation_recall: 0.1093 - u3p_output_sup2_activation_dice_coef: 0.0342 - u3p_output_sup2_activation_io_u: 0.9871 - u3p_output_sup2_activation_io_u_1: 1.8174e-04 - u3p_output_sup2_activation_binary_io_u: 0.5482 - u3p_output_sup2_activation_mean_io_u: 0.4937 - u3p_output_final_activation_precision: 0.9855 - u3p_output_final_activation_accuracy: 0.9996 - u3p_output_final_activation_recall: 0.9866 - u3p_output_final_activation_dice_coef: 0.9725 - u3p_output_final_activation_io_u: 0.9874 - u3p_output_final_activation_io_u_1: 0.0173 - u3p_output_final_activation_binary_io_u: 0.9861 - u3p_output_final_activation_mean_io_u: 0.5023 - val_loss: 0.5297 - val_u3p_output_sup0_activation_loss: 0.0250 - val_u3p_output_sup1_activation_loss: 0.1833 - val_u3p_output_sup2_activation_loss: 0.2937 - val_u3p_output_final_activation_loss: 0.0277 - val_u3p_output_sup0_activation_precision: 0.8581 - val_u3p_output_sup0_activation_accuracy: 0.9949 - val_u3p_output_sup0_activation_recall: 0.6607 - val_u3p_output_sup0_activation_dice_coef: 0.7198 - val_u3p_output_sup0_activation_io_u: 0.9888 - val_u3p_output_sup0_activation_io_u_1: 0.0028 - val_u3p_output_sup0_activation_binary_io_u: 0.7952 - val_u3p_output_sup0_activation_mean_io_u: 0.4958 - val_u3p_output_sup1_activation_precision: 0.8686 - val_u3p_output_sup1_activation_accuracy: 0.9916 - val_u3p_output_sup1_activation_recall: 0.2985 - val_u3p_output_sup1_activation_dice_coef: 0.0664 - val_u3p_output_sup1_activation_io_u: 0.9887 - val_u3p_output_sup1_activation_io_u_1: 8.1288e-04 - val_u3p_output_sup1_activation_binary_io_u: 0.6386 - val_u3p_output_sup1_activation_mean_io_u: 0.4948 - val_u3p_output_sup2_activation_precision: 0.7384 - val_u3p_output_sup2_activation_accuracy: 0.9893 - val_u3p_output_sup2_activation_recall: 0.0775 - val_u3p_output_sup2_activation_dice_coef: 0.0295 - val_u3p_output_sup2_activation_io_u: 0.9887 - val_u3p_output_sup2_activation_io_u_1: 4.3353e-04 - val_u3p_output_sup2_activation_binary_io_u: 0.5324 - val_u3p_output_sup2_activation_mean_io_u: 0.4946 - val_u3p_output_final_activation_precision: 0.8695 - val_u3p_output_final_activation_accuracy: 0.9951 - val_u3p_output_final_activation_recall: 0.6664 - val_u3p_output_final_activation_dice_coef: 0.7436 - val_u3p_output_final_activation_io_u: 0.9889 - val_u3p_output_final_activation_io_u_1: 0.0144 - val_u3p_output_final_activation_binary_io_u: 0.8005 - val_u3p_output_final_activation_mean_io_u: 0.5016
# Epoch 11/50
# 102/102 [==============================] - 20s 201ms/step - loss: 0.4578 - u3p_output_sup0_activation_loss: 0.0029 - u3p_output_sup1_activation_loss: 0.1696 - u3p_output_sup2_activation_loss: 0.2848 - u3p_output_final_activation_loss: 5.5862e-04 - u3p_output_sup0_activation_precision: 0.9517 - u3p_output_sup0_activation_accuracy: 0.9988 - u3p_output_sup0_activation_recall: 0.9526 - u3p_output_sup0_activation_dice_coef: 0.9215 - u3p_output_sup0_activation_io_u: 0.9872 - u3p_output_sup0_activation_io_u_1: 0.0023 - u3p_output_sup0_activation_binary_io_u: 0.9537 - u3p_output_sup0_activation_mean_io_u: 0.4947 - u3p_output_sup1_activation_precision: 0.9058 - u3p_output_sup1_activation_accuracy: 0.9928 - u3p_output_sup1_activation_recall: 0.4893 - u3p_output_sup1_activation_dice_coef: 0.0984 - u3p_output_sup1_activation_io_u: 0.9872 - u3p_output_sup1_activation_io_u_1: 0.0027 - u3p_output_sup1_activation_binary_io_u: 0.7292 - u3p_output_sup1_activation_mean_io_u: 0.4949 - u3p_output_sup2_activation_precision: 0.8981 - u3p_output_sup2_activation_accuracy: 0.9884 - u3p_output_sup2_activation_recall: 0.1103 - u3p_output_sup2_activation_dice_coef: 0.0347 - u3p_output_sup2_activation_io_u: 0.9871 - u3p_output_sup2_activation_io_u_1: 1.7588e-04 - u3p_output_sup2_activation_binary_io_u: 0.5486 - u3p_output_sup2_activation_mean_io_u: 0.4937 - u3p_output_final_activation_precision: 0.9937 - u3p_output_final_activation_accuracy: 0.9998 - u3p_output_final_activation_recall: 0.9931 - u3p_output_final_activation_dice_coef: 0.9847 - u3p_output_final_activation_io_u: 0.9877 - u3p_output_final_activation_io_u_1: 0.0424 - u3p_output_final_activation_binary_io_u: 0.9933 - u3p_output_final_activation_mean_io_u: 0.5151 - val_loss: 0.5029 - val_u3p_output_sup0_activation_loss: 0.0254 - val_u3p_output_sup1_activation_loss: 0.1723 - val_u3p_output_sup2_activation_loss: 0.2772 - val_u3p_output_final_activation_loss: 0.0281 - val_u3p_output_sup0_activation_precision: 0.8310 - val_u3p_output_sup0_activation_accuracy: 0.9948 - val_u3p_output_sup0_activation_recall: 0.6739 - val_u3p_output_sup0_activation_dice_coef: 0.7221 - val_u3p_output_sup0_activation_io_u: 0.9888 - val_u3p_output_sup0_activation_io_u_1: 0.0031 - val_u3p_output_sup0_activation_binary_io_u: 0.7937 - val_u3p_output_sup0_activation_mean_io_u: 0.4960 - val_u3p_output_sup1_activation_precision: 0.8117 - val_u3p_output_sup1_activation_accuracy: 0.9919 - val_u3p_output_sup1_activation_recall: 0.3701 - val_u3p_output_sup1_activation_dice_coef: 0.0761 - val_u3p_output_sup1_activation_io_u: 0.9888 - val_u3p_output_sup1_activation_io_u_1: 0.0014 - val_u3p_output_sup1_activation_binary_io_u: 0.6664 - val_u3p_output_sup1_activation_mean_io_u: 0.4951 - val_u3p_output_sup2_activation_precision: 0.7408 - val_u3p_output_sup2_activation_accuracy: 0.9893 - val_u3p_output_sup2_activation_recall: 0.0776 - val_u3p_output_sup2_activation_dice_coef: 0.0298 - val_u3p_output_sup2_activation_io_u: 0.9887 - val_u3p_output_sup2_activation_io_u_1: 4.3353e-04 - val_u3p_output_sup2_activation_binary_io_u: 0.5324 - val_u3p_output_sup2_activation_mean_io_u: 0.4946 - val_u3p_output_final_activation_precision: 0.8424 - val_u3p_output_final_activation_accuracy: 0.9949 - val_u3p_output_final_activation_recall: 0.6691 - val_u3p_output_final_activation_dice_coef: 0.7385 - val_u3p_output_final_activation_io_u: 0.9889 - val_u3p_output_final_activation_io_u_1: 0.0140 - val_u3p_output_final_activation_binary_io_u: 0.7947 - val_u3p_output_final_activation_mean_io_u: 0.5014
# Epoch 12/50
# 102/102 [==============================] - 20s 201ms/step - loss: 0.4329 - u3p_output_sup0_activation_loss: 0.0026 - u3p_output_sup1_activation_loss: 0.1611 - u3p_output_sup2_activation_loss: 0.2689 - u3p_output_final_activation_loss: 3.7493e-04 - u3p_output_sup0_activation_precision: 0.9563 - u3p_output_sup0_activation_accuracy: 0.9989 - u3p_output_sup0_activation_recall: 0.9592 - u3p_output_sup0_activation_dice_coef: 0.9296 - u3p_output_sup0_activation_io_u: 0.9872 - u3p_output_sup0_activation_io_u_1: 0.0057 - u3p_output_sup0_activation_binary_io_u: 0.9589 - u3p_output_sup0_activation_mean_io_u: 0.4965 - u3p_output_sup1_activation_precision: 0.9098 - u3p_output_sup1_activation_accuracy: 0.9928 - u3p_output_sup1_activation_recall: 0.4890 - u3p_output_sup1_activation_dice_coef: 0.1016 - u3p_output_sup1_activation_io_u: 0.9872 - u3p_output_sup1_activation_io_u_1: 0.0045 - u3p_output_sup1_activation_binary_io_u: 0.7296 - u3p_output_sup1_activation_mean_io_u: 0.4959 - u3p_output_sup2_activation_precision: 0.9014 - u3p_output_sup2_activation_accuracy: 0.9884 - u3p_output_sup2_activation_recall: 0.1111 - u3p_output_sup2_activation_dice_coef: 0.0353 - u3p_output_sup2_activation_io_u: 0.9871 - u3p_output_sup2_activation_io_u_1: 1.8761e-04 - u3p_output_sup2_activation_binary_io_u: 0.5491 - u3p_output_sup2_activation_mean_io_u: 0.4937 - u3p_output_final_activation_precision: 0.9960 - u3p_output_final_activation_accuracy: 0.9999 - u3p_output_final_activation_recall: 0.9960 - u3p_output_final_activation_dice_coef: 0.9895 - u3p_output_final_activation_io_u: 0.9880 - u3p_output_final_activation_io_u_1: 0.0658 - u3p_output_final_activation_binary_io_u: 0.9959 - u3p_output_final_activation_mean_io_u: 0.5269 - val_loss: 0.4774 - val_u3p_output_sup0_activation_loss: 0.0230 - val_u3p_output_sup1_activation_loss: 0.1639 - val_u3p_output_sup2_activation_loss: 0.2618 - val_u3p_output_final_activation_loss: 0.0287 - val_u3p_output_sup0_activation_precision: 0.8002 - val_u3p_output_sup0_activation_accuracy: 0.9950 - val_u3p_output_sup0_activation_recall: 0.7420 - val_u3p_output_sup0_activation_dice_coef: 0.7451 - val_u3p_output_sup0_activation_io_u: 0.9888 - val_u3p_output_sup0_activation_io_u_1: 0.0086 - val_u3p_output_sup0_activation_binary_io_u: 0.8105 - val_u3p_output_sup0_activation_mean_io_u: 0.4987 - val_u3p_output_sup1_activation_precision: 0.7718 - val_u3p_output_sup1_activation_accuracy: 0.9920 - val_u3p_output_sup1_activation_recall: 0.4051 - val_u3p_output_sup1_activation_dice_coef: 0.0833 - val_u3p_output_sup1_activation_io_u: 0.9888 - val_u3p_output_sup1_activation_io_u_1: 0.0030 - val_u3p_output_sup1_activation_binary_io_u: 0.6769 - val_u3p_output_sup1_activation_mean_io_u: 0.4959 - val_u3p_output_sup2_activation_precision: 0.7422 - val_u3p_output_sup2_activation_accuracy: 0.9893 - val_u3p_output_sup2_activation_recall: 0.0774 - val_u3p_output_sup2_activation_dice_coef: 0.0301 - val_u3p_output_sup2_activation_io_u: 0.9887 - val_u3p_output_sup2_activation_io_u_1: 5.4192e-04 - val_u3p_output_sup2_activation_binary_io_u: 0.5323 - val_u3p_output_sup2_activation_mean_io_u: 0.4946 - val_u3p_output_final_activation_precision: 0.8258 - val_u3p_output_final_activation_accuracy: 0.9952 - val_u3p_output_final_activation_recall: 0.7252 - val_u3p_output_final_activation_dice_coef: 0.7599 - val_u3p_output_final_activation_io_u: 0.9891 - val_u3p_output_final_activation_io_u_1: 0.0361 - val_u3p_output_final_activation_binary_io_u: 0.8121 - val_u3p_output_final_activation_mean_io_u: 0.5126
# Epoch 13/50
# 102/102 [==============================] - 21s 202ms/step - loss: 0.4100 - u3p_output_sup0_activation_loss: 0.0023 - u3p_output_sup1_activation_loss: 0.1532 - u3p_output_sup2_activation_loss: 0.2541 - u3p_output_final_activation_loss: 3.1175e-04 - u3p_output_sup0_activation_precision: 0.9606 - u3p_output_sup0_activation_accuracy: 0.9990 - u3p_output_sup0_activation_recall: 0.9620 - u3p_output_sup0_activation_dice_coef: 0.9355 - u3p_output_sup0_activation_io_u: 0.9873 - u3p_output_sup0_activation_io_u_1: 0.0098 - u3p_output_sup0_activation_binary_io_u: 0.9623 - u3p_output_sup0_activation_mean_io_u: 0.4985 - u3p_output_sup1_activation_precision: 0.9095 - u3p_output_sup1_activation_accuracy: 0.9928 - u3p_output_sup1_activation_recall: 0.4893 - u3p_output_sup1_activation_dice_coef: 0.1050 - u3p_output_sup1_activation_io_u: 0.9872 - u3p_output_sup1_activation_io_u_1: 0.0059 - u3p_output_sup1_activation_binary_io_u: 0.7296 - u3p_output_sup1_activation_mean_io_u: 0.4966 - u3p_output_sup2_activation_precision: 0.9045 - u3p_output_sup2_activation_accuracy: 0.9884 - u3p_output_sup2_activation_recall: 0.1119 - u3p_output_sup2_activation_dice_coef: 0.0359 - u3p_output_sup2_activation_io_u: 0.9871 - u3p_output_sup2_activation_io_u_1: 2.0520e-04 - u3p_output_sup2_activation_binary_io_u: 0.5495 - u3p_output_sup2_activation_mean_io_u: 0.4937 - u3p_output_final_activation_precision: 0.9968 - u3p_output_final_activation_accuracy: 0.9999 - u3p_output_final_activation_recall: 0.9966 - u3p_output_final_activation_dice_coef: 0.9916 - u3p_output_final_activation_io_u: 0.9882 - u3p_output_final_activation_io_u_1: 0.0831 - u3p_output_final_activation_binary_io_u: 0.9967 - u3p_output_final_activation_mean_io_u: 0.5357 - val_loss: 0.4594 - val_u3p_output_sup0_activation_loss: 0.0240 - val_u3p_output_sup1_activation_loss: 0.1570 - val_u3p_output_sup2_activation_loss: 0.2477 - val_u3p_output_final_activation_loss: 0.0307 - val_u3p_output_sup0_activation_precision: 0.7947 - val_u3p_output_sup0_activation_accuracy: 0.9949 - val_u3p_output_sup0_activation_recall: 0.7357 - val_u3p_output_sup0_activation_dice_coef: 0.7377 - val_u3p_output_sup0_activation_io_u: 0.9888 - val_u3p_output_sup0_activation_io_u_1: 0.0098 - val_u3p_output_sup0_activation_binary_io_u: 0.8065 - val_u3p_output_sup0_activation_mean_io_u: 0.4993 - val_u3p_output_sup1_activation_precision: 0.8066 - val_u3p_output_sup1_activation_accuracy: 0.9919 - val_u3p_output_sup1_activation_recall: 0.3708 - val_u3p_output_sup1_activation_dice_coef: 0.0814 - val_u3p_output_sup1_activation_io_u: 0.9888 - val_u3p_output_sup1_activation_io_u_1: 0.0025 - val_u3p_output_sup1_activation_binary_io_u: 0.6662 - val_u3p_output_sup1_activation_mean_io_u: 0.4956 - val_u3p_output_sup2_activation_precision: 0.7405 - val_u3p_output_sup2_activation_accuracy: 0.9893 - val_u3p_output_sup2_activation_recall: 0.0770 - val_u3p_output_sup2_activation_dice_coef: 0.0304 - val_u3p_output_sup2_activation_io_u: 0.9887 - val_u3p_output_sup2_activation_io_u_1: 5.4192e-04 - val_u3p_output_sup2_activation_binary_io_u: 0.5321 - val_u3p_output_sup2_activation_mean_io_u: 0.4946 - val_u3p_output_final_activation_precision: 0.8166 - val_u3p_output_final_activation_accuracy: 0.9950 - val_u3p_output_final_activation_recall: 0.7119 - val_u3p_output_final_activation_dice_coef: 0.7517 - val_u3p_output_final_activation_io_u: 0.9892 - val_u3p_output_final_activation_io_u_1: 0.0437 - val_u3p_output_final_activation_binary_io_u: 0.8044 - val_u3p_output_final_activation_mean_io_u: 0.5164
# Epoch 14/50
# ...
# Epoch 47/50
# 102/102 [==============================] - 21s 202ms/step - loss: 0.1230 - u3p_output_sup0_activation_loss: 5.4410e-04 - u3p_output_sup1_activation_loss: 0.0454 - u3p_output_sup2_activation_loss: 0.0769 - u3p_output_final_activation_loss: 6.4665e-05 - u3p_output_sup0_activation_precision: 0.9923 - u3p_output_sup0_activation_accuracy: 0.9998 - u3p_output_sup0_activation_recall: 0.9919 - u3p_output_sup0_activation_dice_coef: 0.9858 - u3p_output_sup0_activation_io_u: 0.9940 - u3p_output_sup0_activation_io_u_1: 0.5392 - u3p_output_sup0_activation_binary_io_u: 0.9921 - u3p_output_sup0_activation_mean_io_u: 0.7666 - u3p_output_sup1_activation_precision: 0.9099 - u3p_output_sup1_activation_accuracy: 0.9929 - u3p_output_sup1_activation_recall: 0.4988 - u3p_output_sup1_activation_dice_coef: 0.2731 - u3p_output_sup1_activation_io_u: 0.9871 - u3p_output_sup1_activation_io_u_1: 6.4490e-05 - u3p_output_sup1_activation_binary_io_u: 0.7341 - u3p_output_sup1_activation_mean_io_u: 0.4936 - u3p_output_sup2_activation_precision: 0.9118 - u3p_output_sup2_activation_accuracy: 0.9886 - u3p_output_sup2_activation_recall: 0.1220 - u3p_output_sup2_activation_dice_coef: 0.0703 - u3p_output_sup2_activation_io_u: 0.9872 - u3p_output_sup2_activation_io_u_1: 6.3904e-04 - u3p_output_sup2_activation_binary_io_u: 0.5546 - u3p_output_sup2_activation_mean_io_u: 0.4939 - u3p_output_final_activation_precision: 0.9991 - u3p_output_final_activation_accuracy: 1.0000 - u3p_output_final_activation_recall: 0.9991 - u3p_output_final_activation_dice_coef: 0.9985 - u3p_output_final_activation_io_u: 0.9924 - u3p_output_final_activation_io_u_1: 0.4150 - u3p_output_final_activation_binary_io_u: 0.9991 - u3p_output_final_activation_mean_io_u: 0.7037 - val_loss: 0.2048 - val_u3p_output_sup0_activation_loss: 0.0395 - val_u3p_output_sup1_activation_loss: 0.0513 - val_u3p_output_sup2_activation_loss: 0.0765 - val_u3p_output_final_activation_loss: 0.0375 - val_u3p_output_sup0_activation_precision: 0.8199 - val_u3p_output_sup0_activation_accuracy: 0.9953 - val_u3p_output_sup0_activation_recall: 0.7411 - val_u3p_output_sup0_activation_dice_coef: 0.7714 - val_u3p_output_sup0_activation_io_u: 0.9914 - val_u3p_output_sup0_activation_io_u_1: 0.2457 - val_u3p_output_sup0_activation_binary_io_u: 0.8163 - val_u3p_output_sup0_activation_mean_io_u: 0.6186 - val_u3p_output_sup1_activation_precision: 0.8269 - val_u3p_output_sup1_activation_accuracy: 0.9922 - val_u3p_output_sup1_activation_recall: 0.3834 - val_u3p_output_sup1_activation_dice_coef: 0.2083 - val_u3p_output_sup1_activation_io_u: 0.9887 - val_u3p_output_sup1_activation_io_u_1: 2.1677e-04 - val_u3p_output_sup1_activation_binary_io_u: 0.6735 - val_u3p_output_sup1_activation_mean_io_u: 0.4945 - val_u3p_output_sup2_activation_precision: 0.6513 - val_u3p_output_sup2_activation_accuracy: 0.9891 - val_u3p_output_sup2_activation_recall: 0.0744 - val_u3p_output_sup2_activation_dice_coef: 0.0491 - val_u3p_output_sup2_activation_io_u: 0.9888 - val_u3p_output_sup2_activation_io_u_1: 0.0013 - val_u3p_output_sup2_activation_binary_io_u: 0.5303 - val_u3p_output_sup2_activation_mean_io_u: 0.4950 - val_u3p_output_final_activation_precision: 0.8396 - val_u3p_output_final_activation_accuracy: 0.9955 - val_u3p_output_final_activation_recall: 0.7387 - val_u3p_output_final_activation_dice_coef: 0.7813 - val_u3p_output_final_activation_io_u: 0.9909 - val_u3p_output_final_activation_io_u_1: 0.1981 - val_u3p_output_final_activation_binary_io_u: 0.8214 - val_u3p_output_final_activation_mean_io_u: 0.5945
# Epoch 48/50
# 102/102 [==============================] - 21s 202ms/step - loss: 0.1208 - u3p_output_sup0_activation_loss: 5.3507e-04 - u3p_output_sup1_activation_loss: 0.0445 - u3p_output_sup2_activation_loss: 0.0757 - u3p_output_final_activation_loss: 6.1727e-05 - u3p_output_sup0_activation_precision: 0.9926 - u3p_output_sup0_activation_accuracy: 0.9998 - u3p_output_sup0_activation_recall: 0.9924 - u3p_output_sup0_activation_dice_coef: 0.9864 - u3p_output_sup0_activation_io_u: 0.9943 - u3p_output_sup0_activation_io_u_1: 0.5600 - u3p_output_sup0_activation_binary_io_u: 0.9924 - u3p_output_sup0_activation_mean_io_u: 0.7772 - u3p_output_sup1_activation_precision: 0.9095 - u3p_output_sup1_activation_accuracy: 0.9929 - u3p_output_sup1_activation_recall: 0.4994 - u3p_output_sup1_activation_dice_coef: 0.2790 - u3p_output_sup1_activation_io_u: 0.9871 - u3p_output_sup1_activation_io_u_1: 7.0353e-05 - u3p_output_sup1_activation_binary_io_u: 0.7343 - u3p_output_sup1_activation_mean_io_u: 0.4936 - u3p_output_sup2_activation_precision: 0.9115 - u3p_output_sup2_activation_accuracy: 0.9886 - u3p_output_sup2_activation_recall: 0.1221 - u3p_output_sup2_activation_dice_coef: 0.0717 - u3p_output_sup2_activation_io_u: 0.9872 - u3p_output_sup2_activation_io_u_1: 7.2112e-04 - u3p_output_sup2_activation_binary_io_u: 0.5546 - u3p_output_sup2_activation_mean_io_u: 0.4939 - u3p_output_final_activation_precision: 0.9991 - u3p_output_final_activation_accuracy: 1.0000 - u3p_output_final_activation_recall: 0.9992 - u3p_output_final_activation_dice_coef: 0.9986 - u3p_output_final_activation_io_u: 0.9925 - u3p_output_final_activation_io_u_1: 0.4192 - u3p_output_final_activation_binary_io_u: 0.9991 - u3p_output_final_activation_mean_io_u: 0.7059 - val_loss: 0.2129 - val_u3p_output_sup0_activation_loss: 0.0462 - val_u3p_output_sup1_activation_loss: 0.0506 - val_u3p_output_sup2_activation_loss: 0.0753 - val_u3p_output_final_activation_loss: 0.0409 - val_u3p_output_sup0_activation_precision: 0.8710 - val_u3p_output_sup0_activation_accuracy: 0.9952 - val_u3p_output_sup0_activation_recall: 0.6694 - val_u3p_output_sup0_activation_dice_coef: 0.7544 - val_u3p_output_sup0_activation_io_u: 0.9906 - val_u3p_output_sup0_activation_io_u_1: 0.1709 - val_u3p_output_sup0_activation_binary_io_u: 0.8021 - val_u3p_output_sup0_activation_mean_io_u: 0.5808 - val_u3p_output_sup1_activation_precision: 0.8501 - val_u3p_output_sup1_activation_accuracy: 0.9922 - val_u3p_output_sup1_activation_recall: 0.3733 - val_u3p_output_sup1_activation_dice_coef: 0.2063 - val_u3p_output_sup1_activation_io_u: 0.9887 - val_u3p_output_sup1_activation_io_u_1: 2.1677e-04 - val_u3p_output_sup1_activation_binary_io_u: 0.6712 - val_u3p_output_sup1_activation_mean_io_u: 0.4945 - val_u3p_output_sup2_activation_precision: 0.6482 - val_u3p_output_sup2_activation_accuracy: 0.9891 - val_u3p_output_sup2_activation_recall: 0.0734 - val_u3p_output_sup2_activation_dice_coef: 0.0497 - val_u3p_output_sup2_activation_io_u: 0.9888 - val_u3p_output_sup2_activation_io_u_1: 0.0014 - val_u3p_output_sup2_activation_binary_io_u: 0.5298 - val_u3p_output_sup2_activation_mean_io_u: 0.4951 - val_u3p_output_final_activation_precision: 0.8783 - val_u3p_output_final_activation_accuracy: 0.9952 - val_u3p_output_final_activation_recall: 0.6681 - val_u3p_output_final_activation_dice_coef: 0.7597 - val_u3p_output_final_activation_io_u: 0.9902 - val_u3p_output_final_activation_io_u_1: 0.1348 - val_u3p_output_final_activation_binary_io_u: 0.8033 - val_u3p_output_final_activation_mean_io_u: 0.5625
# Epoch 49/50
# 102/102 [==============================] - 20s 199ms/step - loss: 0.1188 - u3p_output_sup0_activation_loss: 5.3286e-04 - u3p_output_sup1_activation_loss: 0.0437 - u3p_output_sup2_activation_loss: 0.0745 - u3p_output_final_activation_loss: 6.2757e-05 - u3p_output_sup0_activation_precision: 0.9927 - u3p_output_sup0_activation_accuracy: 0.9998 - u3p_output_sup0_activation_recall: 0.9919 - u3p_output_sup0_activation_dice_coef: 0.9864 - u3p_output_sup0_activation_io_u: 0.9943 - u3p_output_sup0_activation_io_u_1: 0.5615 - u3p_output_sup0_activation_binary_io_u: 0.9922 - u3p_output_sup0_activation_mean_io_u: 0.7779 - u3p_output_sup1_activation_precision: 0.9081 - u3p_output_sup1_activation_accuracy: 0.9929 - u3p_output_sup1_activation_recall: 0.4996 - u3p_output_sup1_activation_dice_coef: 0.2846 - u3p_output_sup1_activation_io_u: 0.9871 - u3p_output_sup1_activation_io_u_1: 2.9314e-05 - u3p_output_sup1_activation_binary_io_u: 0.7342 - u3p_output_sup1_activation_mean_io_u: 0.4936 - u3p_output_sup2_activation_precision: 0.9115 - u3p_output_sup2_activation_accuracy: 0.9886 - u3p_output_sup2_activation_recall: 0.1223 - u3p_output_sup2_activation_dice_coef: 0.0731 - u3p_output_sup2_activation_io_u: 0.9872 - u3p_output_sup2_activation_io_u_1: 7.7974e-04 - u3p_output_sup2_activation_binary_io_u: 0.5547 - u3p_output_sup2_activation_mean_io_u: 0.4940 - u3p_output_final_activation_precision: 0.9991 - u3p_output_final_activation_accuracy: 1.0000 - u3p_output_final_activation_recall: 0.9991 - u3p_output_final_activation_dice_coef: 0.9986 - u3p_output_final_activation_io_u: 0.9926 - u3p_output_final_activation_io_u_1: 0.4282 - u3p_output_final_activation_binary_io_u: 0.9991 - u3p_output_final_activation_mean_io_u: 0.7104 - val_loss: 0.2009 - val_u3p_output_sup0_activation_loss: 0.0397 - val_u3p_output_sup1_activation_loss: 0.0494 - val_u3p_output_sup2_activation_loss: 0.0741 - val_u3p_output_final_activation_loss: 0.0377 - val_u3p_output_sup0_activation_precision: 0.8313 - val_u3p_output_sup0_activation_accuracy: 0.9954 - val_u3p_output_sup0_activation_recall: 0.7370 - val_u3p_output_sup0_activation_dice_coef: 0.7755 - val_u3p_output_sup0_activation_io_u: 0.9914 - val_u3p_output_sup0_activation_io_u_1: 0.2418 - val_u3p_output_sup0_activation_binary_io_u: 0.8182 - val_u3p_output_sup0_activation_mean_io_u: 0.6166 - val_u3p_output_sup1_activation_precision: 0.8451 - val_u3p_output_sup1_activation_accuracy: 0.9921 - val_u3p_output_sup1_activation_recall: 0.3705 - val_u3p_output_sup1_activation_dice_coef: 0.2119 - val_u3p_output_sup1_activation_io_u: 0.9887 - val_u3p_output_sup1_activation_io_u_1: 1.0838e-04 - val_u3p_output_sup1_activation_binary_io_u: 0.6695 - val_u3p_output_sup1_activation_mean_io_u: 0.4944 - val_u3p_output_sup2_activation_precision: 0.6473 - val_u3p_output_sup2_activation_accuracy: 0.9891 - val_u3p_output_sup2_activation_recall: 0.0730 - val_u3p_output_sup2_activation_dice_coef: 0.0503 - val_u3p_output_sup2_activation_io_u: 0.9888 - val_u3p_output_sup2_activation_io_u_1: 0.0014 - val_u3p_output_sup2_activation_binary_io_u: 0.5297 - val_u3p_output_sup2_activation_mean_io_u: 0.4951 - val_u3p_output_final_activation_precision: 0.8510 - val_u3p_output_final_activation_accuracy: 0.9955 - val_u3p_output_final_activation_recall: 0.7250 - val_u3p_output_final_activation_dice_coef: 0.7804 - val_u3p_output_final_activation_io_u: 0.9908 - val_u3p_output_final_activation_io_u_1: 0.1905 - val_u3p_output_final_activation_binary_io_u: 0.8194 - val_u3p_output_final_activation_mean_io_u: 0.5907
# Epoch 50/50
# 102/102 [==============================] - 21s 201ms/step - loss: 0.1169 - u3p_output_sup0_activation_loss: 5.4408e-04 - u3p_output_sup1_activation_loss: 0.0430 - u3p_output_sup2_activation_loss: 0.0733 - u3p_output_final_activation_loss: 6.2087e-05 - u3p_output_sup0_activation_precision: 0.9925 - u3p_output_sup0_activation_accuracy: 0.9998 - u3p_output_sup0_activation_recall: 0.9918 - u3p_output_sup0_activation_dice_coef: 0.9863 - u3p_output_sup0_activation_io_u: 0.9945 - u3p_output_sup0_activation_io_u_1: 0.5716 - u3p_output_sup0_activation_binary_io_u: 0.9921 - u3p_output_sup0_activation_mean_io_u: 0.7830 - u3p_output_sup1_activation_precision: 0.9091 - u3p_output_sup1_activation_accuracy: 0.9929 - u3p_output_sup1_activation_recall: 0.4991 - u3p_output_sup1_activation_dice_coef: 0.2900 - u3p_output_sup1_activation_io_u: 0.9871 - u3p_output_sup1_activation_io_u_1: 2.9314e-05 - u3p_output_sup1_activation_binary_io_u: 0.7341 - u3p_output_sup1_activation_mean_io_u: 0.4936 - u3p_output_sup2_activation_precision: 0.9114 - u3p_output_sup2_activation_accuracy: 0.9886 - u3p_output_sup2_activation_recall: 0.1224 - u3p_output_sup2_activation_dice_coef: 0.0744 - u3p_output_sup2_activation_io_u: 0.9872 - u3p_output_sup2_activation_io_u_1: 8.3251e-04 - u3p_output_sup2_activation_binary_io_u: 0.5547 - u3p_output_sup2_activation_mean_io_u: 0.4940 - u3p_output_final_activation_precision: 0.9992 - u3p_output_final_activation_accuracy: 1.0000 - u3p_output_final_activation_recall: 0.9991 - u3p_output_final_activation_dice_coef: 0.9986 - u3p_output_final_activation_io_u: 0.9928 - u3p_output_final_activation_io_u_1: 0.4456 - u3p_output_final_activation_binary_io_u: 0.9991 - u3p_output_final_activation_mean_io_u: 0.7192 - val_loss: 0.2021 - val_u3p_output_sup0_activation_loss: 0.0421 - val_u3p_output_sup1_activation_loss: 0.0486 - val_u3p_output_sup2_activation_loss: 0.0730 - val_u3p_output_final_activation_loss: 0.0383 - val_u3p_output_sup0_activation_precision: 0.8368 - val_u3p_output_sup0_activation_accuracy: 0.9952 - val_u3p_output_sup0_activation_recall: 0.7181 - val_u3p_output_sup0_activation_dice_coef: 0.7665 - val_u3p_output_sup0_activation_io_u: 0.9911 - val_u3p_output_sup0_activation_io_u_1: 0.2198 - val_u3p_output_sup0_activation_binary_io_u: 0.8126 - val_u3p_output_sup0_activation_mean_io_u: 0.6055 - val_u3p_output_sup1_activation_precision: 0.8282 - val_u3p_output_sup1_activation_accuracy: 0.9922 - val_u3p_output_sup1_activation_recall: 0.3870 - val_u3p_output_sup1_activation_dice_coef: 0.2216 - val_u3p_output_sup1_activation_io_u: 0.9887 - val_u3p_output_sup1_activation_io_u_1: 2.1677e-04 - val_u3p_output_sup1_activation_binary_io_u: 0.6752 - val_u3p_output_sup1_activation_mean_io_u: 0.4945 - val_u3p_output_sup2_activation_precision: 0.6467 - val_u3p_output_sup2_activation_accuracy: 0.9891 - val_u3p_output_sup2_activation_recall: 0.0724 - val_u3p_output_sup2_activation_dice_coef: 0.0509 - val_u3p_output_sup2_activation_io_u: 0.9888 - val_u3p_output_sup2_activation_io_u_1: 0.0014 - val_u3p_output_sup2_activation_binary_io_u: 0.5294 - val_u3p_output_sup2_activation_mean_io_u: 0.4951 - val_u3p_output_final_activation_precision: 0.8469 - val_u3p_output_final_activation_accuracy: 0.9954 - val_u3p_output_final_activation_recall: 0.7174 - val_u3p_output_final_activation_dice_coef: 0.7718 - val_u3p_output_final_activation_io_u: 0.9907 - val_u3p_output_final_activation_io_u_1: 0.1767 - val_u3p_output_final_activation_binary_io_u: 0.8152 - val_u3p_output_final_activation_mean_io_u: 0.5837
# UNet execution time is:  0:17:22.452131

# %%
print("UNet3+ execution time is: ", execution_time_Unet)
model.save('UNet3plus.keras')
# Out:
# UNet3+ execution time is:  0:17:22.452131

# %%
# model = model
import random
test_img_number = random.randint(0, X_pred.shape[0]-1)  #Test with 119

test_img_number = 50
test_img = X_pred[test_img_number]
ground_truth=y_pred[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
prediction = (model.predict(test_img_input)[0,:,:,0] > 0.5).astype(np.uint8)

plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img, cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(prediction, cmap='gray')

plt.show()

# %% [markdown]
# #ResUnet-a

# %%
model_resunet_a_2d = models.resunet_a_2d((128, 128, 3), [32, 64, 128, 256, 512, 1024],
                            dilation_num=[1, 3, 15, 31],
                            n_labels=16, aspp_num_down=256, aspp_num_up=128,
                            activation='ReLU', output_activation='Sigmoid',
                            batch_norm=True, pool=False, unpool='nearest', name='resunet',)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-163-aadd8e7ba9eb> in <cell line: 1>()
# ----> 1 model_resunet_a_2d = models.resunet_a_2d((128, 128, 3), [32, 64, 128, 256, 512, 1024],
#       2                             dilation_num=[1, 3, 15, 31],
#       3                             n_labels=16, aspp_num_down=256, aspp_num_up=128,
#       4                             activation='ReLU', output_activation='Sigmoid',
#       5                             batch_norm=True, pool=False, unpool='nearest', name='resunet',
#
# TypeError: resunet_a_2d() got an unexpected keyword argument 'backbone'

# %% [markdown]
# ## Training and Validation Performance
# ### get the history of the model to access the metrics

# %%
history_dict = model_history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'recall', 'false_negatives', 'false_positives', 'true_negatives', 'true_positives', 'auc', 'val_loss', 'val_accuracy', 'val_recall', 'val_false_negatives', 'val_false_positives', 'val_true_negatives', 'val_true_positives', 'val_auc'])

# %%
ep = range(1, epochs + 1)

# %% [markdown]
# ### get training and validation loss

# %%
loss = history_dict['loss']
val_loss = history_dict['val_loss']

# %% [markdown]
# ### plot training and validation loss

# %%
# plot training loss
plt.plot(ep, loss, 'b', label='Training Loss')
# plot validation loss
plt.plot(ep, val_loss, 'r', label='Validation Loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# ### get accuracy scores

# %%
accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']

# %% [markdown]
# ### plot training and validation accuracy

# %%
# plot training accuracy
plt.plot(ep, accuracy, 'b', label='Training Accuracy')
# plot validation accuracy
plt.plot(ep, val_accuracy, 'r', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %% [markdown]
# ## compute and print all relevant metrics

# %%
# get "best" epoch
from operator import itemgetter
best_epoch, _ = max(enumerate(val_accuracy), key=itemgetter(1))

# compute all metrics (dict key names might need to be adapted)
val_TN = history_dict['val_true_negatives']

val_FP = history_dict['val_false_positives']

val_TP = history_dict['val_true_positives']

val_FN = history_dict['val_false_negatives']

val_sensitivity = history_dict['val_recall']

val_specificity = [x/(x+y) for x,y in zip(val_TN, val_FP)]

val_accuracy = history_dict['val_accuracy']

val_jaccard = [x/(x+y+z) for x,y,z in zip(val_TP, val_FP, val_FN)]

val_auc = history_dict['val_auc']

# print all relevant metrics for the best epoch of one model

print("Sensitivity: ", val_sensitivity[best_epoch])
print("Specificity: ", val_specificity[best_epoch])
print("Accuracy: ", val_accuracy[best_epoch])
print("Jaccard index: ", val_jaccard[best_epoch])
print("Dice coefficient: ", dice)
print("AUC: ", val_auc[best_epoch])

print(val_sensitivity[best_epoch], "&", val_specificity[best_epoch], "&", val_accuracy[best_epoch], "&", val_jaccard[best_epoch], "&", val_dice[best_epoch], "&", val_auc[best_epoch])
# Out:
# Sensitivity:  0.6727291941642761
# Specificity:  0.9983407007536774
# Accuracy:  0.9946761727333069
# Jaccard index:  0.587137620793069
# Dice coefficient:  80.23
# AUC:  0.978805422782898
# 0.6727291941642761 & 0.9983407007536774 & 0.9946761727333069 & 0.587137620793069 & 0.739869829939114 & 0.978805422782898

# %% [markdown]
# ### get values for ROC curve

# %%
from sklearn.metrics import roc_curve, auc

val_preds = model.predict(val_imgs)

fpr, tpr, _ = roc_curve(val_msks.ravel(), val_preds.ravel())
roc_auc = auc(fpr,tpr)
# Out:
# 4/4 [==============================] - 1s 165ms/step

# %% [markdown]
# ### plot ROC curve

# %%
# draw y = x
plt.plot([0,1], [0,1], 'k--')
# draw roc curve
plt.plot(fpr, tpr, 'r', label='ROC curve (area = %0.2f)' % roc_auc)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.title('Receiver operating characteristic curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")

plt.show()

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### (if wanted) Save the weights of current model

# %%
model.save_weights('./checkpoints/current_model.h5')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 model.save_weights('./checkpoints/current_model.h5')
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/anaconda3/lib/python3.11/site-packages/h5py/_hl/files.py:533, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, **kwds)
#     525     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     526                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     527                      alignment_threshold=alignment_threshold,
#     528                      alignment_interval=alignment_interval,
#     529                      **kwds)
#     530     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     531                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     532                      fs_page_size=fs_page_size)
# --> 533     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     535 if isinstance(libver, tuple):
#     536     self._libver = libver
#
# File ~/anaconda3/lib/python3.11/site-packages/h5py/_hl/files.py:232, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     230     fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#     231 elif mode == 'w':
# --> 232     fid = h5f.create(name, h5f.ACC_TRUNC, fapl=fapl, fcpl=fcpl)
#     233 elif mode == 'a':
#     234     # Open in append mode (read/write).
#     235     # If that fails, create a new file only if it won't clobber an
#     236     # existing one (ACC_EXCL)
#     237     try:
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:126, in h5py.h5f.create()
#
# FileNotFoundError: [Errno 2] Unable to create file (unable to open file: name = './checkpoints/current_model.h5', errno = 2, error message = 'No such file or directory', flags = 13, o_flags = 602)

# %% [markdown]
# ### Loads the weights of the model in epoch with best validation performance

# %%
checkpoint_path = "unet_1.h5"
model.load_weights(checkpoint_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 checkpoint_path = "unet_1.h5"
# ----> 2 model.load_weights(checkpoint_path)
#
# NameError: name 'model' is not defined

# %% [markdown]
# ### evaluating the model based on its performance on the test set

# %%
# Evaluate the model on the test data using `evaluate`
# test_imgs = X_test
# tests_msks = y_test
test_imgs = X_train
tests_msks = y_train

model_performance = model_Unet.evaluate(X_train, y_train, batch_size=batch_size)
print("test metrics:", model_performance)
# Out:
# 102/102 [==============================] - 6s 61ms/step - loss: 1.8566e-04 - accuracy: 1.0000 - dice_coef: 0.9954
# test metrics: [0.00018566368089523166, 0.9999563097953796, 0.9953979253768921]

# %% [markdown]
# ## compute and print all relevant metrics

# %%
# compute all metrics
TN = model_performance[5]

FP = model_performance[4]

TP = model_performance[6]

FN = model_performance[3]

sensitivity = model_performance[2]

specificity = TN/(TN+FP)

accuracy = model_performance[1]

jaccard = TP/(TP + FP + FN)

auc = model_performance[7]

# print all relevant metrics for the best epoch of one model

print("Sensitivity: ", sensitivity)
print("Specificity: ", specificity)
print("Accuracy: ", accuracy)
print("Jaccard index: ", jaccard)
print("Dice coefficient: ", dice)
print("AUC: ", auc)

# for Latex
print(sensitivity, "&", specificity, "&", accuracy, "&", jaccard, "&", dice, "&", auc)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-61-8f2e9431b9ff> in <cell line: 2>()
#       1 # compute all metrics
# ----> 2 TN = model_performance[5]
#       3
#       4 FP = model_performance[4]
#       5
#
# IndexError: list index out of range

# %% [markdown]
# ### get values for ROC curve

# %%
from sklearn.metrics import roc_curve, auc

test_preds = model_Unet.predict(test_imgs)

fpr, tpr, _ = roc_curve(test_msks.ravel(), test_preds.ravel())
roc_auc = auc(fpr,tpr)
# Out:
# 26/26 [==============================] - 22s 396ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-a3e273f6a15b> in <cell line: 5>()
#       3 test_preds = model_Unet.predict(test_imgs)
#       4
# ----> 5 fpr, tpr, _ = roc_curve(test_msks.ravel(), test_preds.ravel())
#       6 roc_auc = auc(fpr,tpr)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     990     array([1.8 , 0.8 , 0.4 , 0.35, 0.1 ])
#     991     """
# --> 992     fps, tps, thresholds = _binary_clf_curve(
#     993         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight
#     994     )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     749         raise ValueError("{0} format is not supported".format(y_type))
#     750
# --> 751     check_consistent_length(y_true, y_score, sample_weight)
#     752     y_true = column_or_1d(y_true)
#     753     y_score = column_or_1d(y_score)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     395     uniques = np.unique(lengths)
#     396     if len(uniques) > 1:
# --> 397         raise ValueError(
#     398             "Found input variables with inconsistent numbers of samples: %r"
#     399             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [1638400, 13271040]

# %% [markdown]
# ### plot ROC curve

# %%
# draw y = x
plt.plot([0,1], [0,1], 'k--')
# draw roc curve
plt.plot(fpr, tpr, 'r', label='ROC curve (area = %0.2f)' % roc_auc)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.title('Receiver operating characteristic curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")

plt.show()

# %% [markdown]
# ## Make predictions

# %% [markdown]
# ### Load unlabeled test data (only used for random predictions)

# %%
# path to validation data and ground truth
unlabeled_test_input_dir = "wound-segmentation/data/Foot Ulcer Segmentation Challenge/test/images/"

# sort input images by name
unlabeled_test_input_img_paths = sorted(
    [
        os.path.join(unlabeled_test_input_dir, fname)
        for fname in os.listdir(unlabeled_test_input_dir)
        if fname.endswith(".png")
    ]
)

# print number of total images
print("Number of samples:", len(unlabeled_test_input_img_paths))

# verify for the first 5 images that they are correctly aligned with their segmentation masks
for input_path in unlabeled_test_input_img_paths[:5]:
    print(input_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-40-2b00d38b9e57> in <cell line: 5>()
#       6     [
#       7         os.path.join(unlabeled_test_input_dir, fname)
# ----> 8         for fname in os.listdir(unlabeled_test_input_dir)
#       9         if fname.endswith(".png")
#      10     ]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'wound-segmentation/data/Foot Ulcer Segmentation Challenge/test/images/'

# %% [markdown]
# ### Preprocessing

# %%
unlabeled_test_all_images = [load_img(i_path, target_size=img_size) for i_path in unlabeled_test_input_img_paths]

unlabeled_test_all_images_normalized = [np.array(image, dtype='float32')/255 for image in unlabeled_test_all_images]

unlabeled_test_all_images_normalized = np.array(unlabeled_test_all_images_normalized)

#test_all_images_normalized = test_all_images_normalized[..., np.newaxis]

print(unlabeled_test_all_images_normalized.shape)

unlabeled_test_imgs = unlabeled_test_all_images_normalized
# Out:
# (200, 160, 160, 3)

# %% [markdown]
# ### Generate prediction for one image
# As can be seen, the prediction mask is already very good

# %%
# # specify image here
# pred = model.predict(unlabeled_test_imgs[0:1])

# # Display input image
# display(keras.preprocessing.image.array_to_img(unlabeled_test_imgs[0]))

# # Display prediction mask
# display(ImageOps.autocontrast(keras.preprocessing.image.array_to_img(pred[0])))

# model = model
import random
test_img_number = random.randint(0, X_pred.shape[0]-1)  #Test with 119

test_img_number = 50
test_img = X_pred[test_img_number]
ground_truth=y_pred[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
# test_img_input=np.expand_dims(test_img, 0)
pred = model.predict(test_img_input)

# Display input image
display(keras.preprocessing.image.array_to_img(test_img_input[0]))

# Display prediction mask
display(ImageOps.autocontrast(keras.preprocessing.image.array_to_img(pred[0])))

# prediction = (model.predict(test_img_input)[0,:,:,0] > 0.5).astype(np.uint8)

# plt.figure(figsize=(16, 8))
# plt.subplot(231)
# plt.title('Testing Image')
# plt.imshow(test_img, cmap='gray')
# plt.subplot(232)
# plt.title('Testing Label')
# plt.imshow(ground_truth[:,:,0], cmap='gray')
# plt.subplot(233)
# plt.title('Prediction on test image')
# plt.imshow(prediction, cmap='gray')

# plt.show()
# Out:
# 1/1 [==============================] - 0s 25ms/step
# <PIL.Image.Image image mode=RGB size=128x128>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-119-dfeb0c56914a> in <cell line: 25>()
#      23
#      24 # Display prediction mask
# ---> 25 display(ImageOps.autocontrast(keras.preprocessing.image.array_to_img(pred[0])))
#      26
#      27 # prediction = (model.predict(test_img_input)[0,:,:,0] > 0.5).astype(np.uint8)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/image_utils.py in array_to_img(x, data_format, scale, dtype)
#     245     x = np.asarray(x, dtype=dtype)
#     246     if x.ndim != 3:
# --> 247         raise ValueError(
#     248             "Expected image array to have rank 3 (single image). "
#     249             f"Got array with shape: {x.shape}"
#
# ValueError: Expected image array to have rank 3 (single image). Got array with shape: (1, 128, 128, 1)
