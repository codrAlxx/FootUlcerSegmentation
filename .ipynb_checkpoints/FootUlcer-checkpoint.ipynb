# %% [markdown]
# # Deep Learning for Medical Image Analysis
# ## Grand Challenge - Foot ulcer segmentation challenge 2021
# ## Author: Hasan Evci, Date: 27/12/2022

# %% [markdown]
# ### Note:
# #### The report about the project itself, including results and implementation details, is in a separate PDF file

# %% [markdown]
# ### import the libraries

# %%
import os

from IPython.display import Image, display
from tensorflow.keras.preprocessing.image import load_img
from PIL import ImageOps

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras import layers

import numpy as np

import random

import matplotlib.pyplot as plt

# %% [markdown]
# ### clone the git repository

# %%
# !git clone https://github.com/uwm-bigdata/wound-segmentation.git
# Out:
# 'C:\\Users\\Hasan\\Desktop\\Barcelona_Data\\FIB_Courses\\DLMIA\\Grand Challenge\\wound-segmentation\\data\\Foot Ulcer Segmentation Challenge'

# %% [markdown]
# ### check if GPU is used

# %%
print(tf.config.list_physical_devices())
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# Num GPUs Available:  0

# %% [markdown]
# ### Core parameters used

# %%
# Resizing the images
img_size = (160, 160) #(128, 128)

# Number of classes (binary: black or white, thus one class sufficient)
num_classes = 1

# Batch size of 32 
batch_size = 32

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### sort data: training images and training ground truth

# %%
# path to training data and ground truth
input_dir = "wound-segmentation/data/Foot Ulcer Segmentation Challenge/train/images/"
target_dir = "wound-segmentation/data/Foot Ulcer Segmentation Challenge/train/labels/"

# sort input images by name
input_img_paths = sorted(
    [
        os.path.join(input_dir, fname)
        for fname in os.listdir(input_dir)
        if fname.endswith(".png")
    ]
)

# sort segmentation masks by name
target_img_paths = sorted(
    [
        os.path.join(target_dir, fname)
        for fname in os.listdir(target_dir)
        if fname.endswith(".png") and not fname.startswith(".")
    ]
)

# print number of total images
print("Number of samples:", len(input_img_paths))

# verify for the first 5 images that they are correctly aligned with their segmentation masks
for input_path, target_path in zip(input_img_paths[:5], target_img_paths[:5]):
    print(input_path, "|", target_path)
# Out:
# Number of samples: 810
# wound-segmentation/data/Foot Ulcer Segmentation Challenge/train/images/0011.png | wound-segmentation/data/Foot Ulcer Segmentation Challenge/train/labels/0011.png
# wound-segmentation/data/Foot Ulcer Segmentation Challenge/train/images/0012.png | wound-segmentation/data/Foot Ulcer Segmentation Challenge/train/labels/0012.png
# wound-segmentation/data/Foot Ulcer Segmentation Challenge/train/images/0013.png | wound-segmentation/data/Foot Ulcer Segmentation Challenge/train/labels/0013.png
# wound-segmentation/data/Foot Ulcer Segmentation Challenge/train/images/0014.png | wound-segmentation/data/Foot Ulcer Segmentation Challenge/train/labels/0014.png
# wound-segmentation/data/Foot Ulcer Segmentation Challenge/train/images/0015.png | wound-segmentation/data/Foot Ulcer Segmentation Challenge/train/labels/0015.png

# %% [markdown]
# ### Displaying an example image of the dataset and its segmentation

# %%
# display example
display(load_img(input_img_paths[10], target_size=img_size))

# display mask
display(load_img(target_img_paths[10], target_size=img_size))
# Out:
# <PIL.Image.Image image mode=RGB size=160x160 at 0x1ABA78730D0>
# <PIL.Image.Image image mode=RGB size=160x160 at 0x1ABA78730A0>

# %% [markdown]
# ### sort data: validation images and validation ground truth

# %%
# path to validation data and ground truth
val_input_dir = "wound-segmentation/data/Foot Ulcer Segmentation Challenge/validation/images/"
val_target_dir = "wound-segmentation/data/Foot Ulcer Segmentation Challenge/validation/labels/"

# sort input images by name
val_input_img_paths = sorted(
    [
        os.path.join(val_input_dir, fname)
        for fname in os.listdir(val_input_dir)
        if fname.endswith(".png")
    ]
)

# sort segmentation masks by name
val_target_img_paths = sorted(
    [
        os.path.join(val_target_dir, fname)
        for fname in os.listdir(val_target_dir)
        if fname.endswith(".png")
    ]
)

# print number of total images
print("Number of samples:", len(val_input_img_paths))

# verify for the first 5 images that they are correctly aligned with their segmentation masks
for input_path, target_path in zip(val_input_img_paths[:5], val_target_img_paths[:5]):
    print(input_path, "|", target_path)
# Out:
# Number of samples: 200
# wound-segmentation/data/Foot Ulcer Segmentation Challenge/validation/images/0001.png | wound-segmentation/data/Foot Ulcer Segmentation Challenge/validation/labels/0001.png
# wound-segmentation/data/Foot Ulcer Segmentation Challenge/validation/images/0002.png | wound-segmentation/data/Foot Ulcer Segmentation Challenge/validation/labels/0002.png
# wound-segmentation/data/Foot Ulcer Segmentation Challenge/validation/images/0003.png | wound-segmentation/data/Foot Ulcer Segmentation Challenge/validation/labels/0003.png
# wound-segmentation/data/Foot Ulcer Segmentation Challenge/validation/images/0004.png | wound-segmentation/data/Foot Ulcer Segmentation Challenge/validation/labels/0004.png
# wound-segmentation/data/Foot Ulcer Segmentation Challenge/validation/images/0005.png | wound-segmentation/data/Foot Ulcer Segmentation Challenge/validation/labels/0005.png

# %% [markdown]
# ### load all images from file into python datastructure and already resize them

# %%
# training images
all_images = [load_img(i_path, target_size=img_size) for i_path in input_img_paths]

all_masks = [load_img(t_path, target_size=img_size, color_mode="grayscale") for t_path in target_img_paths]

#validation images
val_all_images = [load_img(i_path, target_size=img_size) for i_path in val_input_img_paths]

val_all_masks = [load_img(t_path, target_size=img_size, color_mode="grayscale") for t_path in val_target_img_paths]

# %% [markdown]
# ### convert to numpy array and normalize the data to [0,1]

# %%
# training
all_images_normalized = [np.array(image, dtype='float32')/255 for image in all_images]

all_masks_normalized = [np.array(image, dtype='float32')/255 for image in all_masks]

#validation
val_all_images_normalized = [np.array(image, dtype='float32')/255 for image in val_all_images]

val_all_masks_normalized = [np.array(image, dtype='float32')/255 for image in val_all_masks]

# %% [markdown]
# ### convert to numpy arrays

# %%
# training
all_images_normalized = np.array(all_images_normalized)

all_masks_normalized = np.array(all_masks_normalized)

# validation
val_all_images_normalized = np.array(val_all_images_normalized)

val_all_masks_normalized = np.array(val_all_masks_normalized)

# %% [markdown]
# ### add new axis for adding an output channel: black or white, i.e. (900, 160, 160) -> (900, 160, 160, 1)

# %%
# training
all_masks_normalized = all_masks_normalized[..., np.newaxis]

#validation
val_all_masks_normalized = val_all_masks_normalized[..., np.newaxis]

# %% [markdown]
# ### check shapes

# %%
print(all_images_normalized.shape)
print(val_all_images_normalized.shape)
# Out:
# (810, 160, 160, 3)
# (200, 160, 160, 3)

# %% [markdown]
# ## Model architecture

# %%
#filters = [8, 16, 24, 32]
filters = [8, 16, 32, 64]
#filters = [16, 32, 64, 128]
dropout_probability = 0.2

# %% [markdown]
# ### define the U-Net model

# %%
def get_unet_model(img_size, num_classes, filters):
    inputs = keras.Input(shape=img_size + (3,))

    skips = []
    
    filters_backwards = filters[::-1]
    
    ### [ENCODER: First half of the network: downsampling inputs] ###

    # Entry block
    x = layers.Conv2D(filters[0], 3, padding="same")(inputs)
    x = layers.Activation("relu")(x)
        
    x = layers.Conv2D(filters[0], 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    skips.append(x)

    x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

    x = layers.Dropout(dropout_probability)(x)

    for f in filters[1:]:
        x = layers.Conv2D(f, 3, padding="same")(x)
        x = layers.Activation("relu")(x)

        x = layers.Conv2D(f, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation("relu")(x)

        skips.append(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        x = layers.Dropout(dropout_probability)(x)

    ### [DECODER: Second half of the network: upsampling inputs] ###

    f = filters_backwards[0]
    
    x = layers.Conv2DTranspose(f, 3, padding="same")(x)
    x = layers.Activation("relu")(x)
    
    x = layers.Conv2DTranspose(f, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.UpSampling2D(2)(x)

    x = layers.Dropout(dropout_probability)(x)

    for i, f in enumerate(filters_backwards[1:], start=1):
        x = layers.Concatenate()([x, skips[-i]]) # UNet skip connection with concatenation operation

        x = layers.Conv2DTranspose(f, 3, padding="same")(x)
        x = layers.Activation("relu")(x)

        x = layers.Conv2DTranspose(f, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation("relu")(x)

        x = layers.UpSampling2D(2)(x)

        x = layers.Dropout(dropout_probability)(x)

    x = layers.Concatenate()([x, skips[0]]) # UNet skip connection with concatenation operation

    # Add a per-pixel classification layer with sigmoid as non linear activation function
    outputs = layers.Conv2DTranspose(num_classes, 3, activation="sigmoid", padding="same")(x) 

    # Define the model
    model = keras.Model(inputs, outputs)
    return model

# %% [markdown]
# ### define the LinkNet model

# %%
def get_linknet_model(img_size, num_classes, filters):
    inputs = keras.Input(shape=img_size + (3,))

    skips = []
    
    filters_backwards = filters[::-1]
    
    ### [ENCODER: First half of the network: downsampling inputs] ###

    # Entry block
    x = layers.Conv2D(filters[0], 3, padding="same")(inputs)
    x = layers.Activation("relu")(x)
    
    x = layers.Conv2D(filters[0], 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    skips.append(x)

    x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

    x = layers.Dropout(.2)(x)

    for f in filters[1:]:
        x = layers.Conv2D(f, 3, padding="same")(x)
        x = layers.Activation("relu")(x)

        x = layers.Conv2D(f, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation("relu")(x)

        skips.append(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        x = layers.Dropout(.2)(x)

    ### [DECODER: Second half of the network: upsampling inputs] ###

    f = filters_backwards[0]
    
    x = layers.Conv2DTranspose(f, 3, padding="same")(x)
    x = layers.Activation("relu")(x)
    
    x = layers.Conv2DTranspose(f, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.UpSampling2D(2)(x)

    x = layers.Dropout(.2)(x)

    for i, f in enumerate(filters_backwards[1:], start=1):
        x = layers.Add()([x, skips[-i]]) # LinkNet skip connection with adding operation

        x = layers.Conv2DTranspose(f, 3, padding="same")(x)
        x = layers.Activation("relu")(x)

        x = layers.Conv2DTranspose(f, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation("relu")(x)

        x = layers.UpSampling2D(2)(x)

        x = layers.Dropout(.2)(x)

    x = layers.Add()([x, skips[0]]) # LinkNet skip connection with adding operation

    # Add a per-pixel classification layer with sigmoid as non linear activation function
    outputs = layers.Conv2D(num_classes, 3, activation="sigmoid", padding="same")(x) 

    # Define the model
    model = keras.Model(inputs, outputs)
    return model

# %% [markdown]
# ### define ensemble model (averaging unet / linknet probability masks)

# %%
def unet(inputs, filters):
    skips = []
    
    filters_backwards = filters[::-1]
    
    ### [ENCODER: First half of the network: downsampling inputs] ###

    # Entry block
    x = layers.Conv2D(filters[0], 3, padding="same")(inputs)
    x = layers.Activation("relu")(x)
        
    x = layers.Conv2D(filters[0], 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    skips.append(x)

    x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

    x = layers.Dropout(dropout_probability)(x)

    for f in filters[1:]:
        x = layers.Conv2D(f, 3, padding="same")(x)
        x = layers.Activation("relu")(x)

        x = layers.Conv2D(f, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation("relu")(x)

        skips.append(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        x = layers.Dropout(dropout_probability)(x)

    ### [DECODER: Second half of the network: upsampling inputs] ###

    f = filters_backwards[0]
    
    x = layers.Conv2DTranspose(f, 3, padding="same")(x)
    x = layers.Activation("relu")(x)
    
    x = layers.Conv2DTranspose(f, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.UpSampling2D(2)(x)

    x = layers.Dropout(dropout_probability)(x)

    for i, f in enumerate(filters_backwards[1:], start=1):
        x = layers.Concatenate()([x, skips[-i]]) # UNet skip connection with concatenation operation

        x = layers.Conv2DTranspose(f, 3, padding="same")(x)
        x = layers.Activation("relu")(x)

        x = layers.Conv2DTranspose(f, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation("relu")(x)

        x = layers.UpSampling2D(2)(x)

        x = layers.Dropout(dropout_probability)(x)

    x = layers.Concatenate()([x, skips[0]]) # UNet skip connection with concatenation operation
    
    return x

def linknet(inputs, filters):
    skips = []
    
    filters_backwards = filters[::-1]
    
    ### [ENCODER: First half of the network: downsampling inputs] ###

    # Entry block
    x = layers.Conv2D(filters[0], 3, padding="same")(inputs)
    x = layers.Activation("relu")(x)
    
    x = layers.Conv2D(filters[0], 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    skips.append(x)

    x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

    x = layers.Dropout(.2)(x)

    for f in filters[1:]:
        x = layers.Conv2D(f, 3, padding="same")(x)
        x = layers.Activation("relu")(x)

        x = layers.Conv2D(f, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation("relu")(x)

        skips.append(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        x = layers.Dropout(.2)(x)

    ### [DECODER: Second half of the network: upsampling inputs] ###

    f = filters_backwards[0]
    
    x = layers.Conv2DTranspose(f, 3, padding="same")(x)
    x = layers.Activation("relu")(x)
    
    x = layers.Conv2DTranspose(f, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.UpSampling2D(2)(x)

    x = layers.Dropout(.2)(x)

    for i, f in enumerate(filters_backwards[1:], start=1):
        x = layers.Add()([x, skips[-i]]) # LinkNet skip connection with adding operation

        x = layers.Conv2DTranspose(f, 3, padding="same")(x)
        x = layers.Activation("relu")(x)

        x = layers.Conv2DTranspose(f, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation("relu")(x)

        x = layers.UpSampling2D(2)(x)

        x = layers.Dropout(.2)(x)

    x = layers.Add()([x, skips[0]]) # LinkNet skip connection with adding operation

    return x

def get_ensemble_model(img_size, num_classes, filters):
    inputs = keras.Input(shape=img_size + (3,))
    
    results = []

    x = unet(inputs, filters)
    
    results.append(x)
    
    adapted_filters = filters[1:] + [filters[-1]*2]
    x = linknet(inputs, adapted_filters)
    
    results.append(x)
    
    # take average of unet and linknet
    sum_results = results[0]
    for r in results[1:]:
        sum_results = layers.Add()([sum_results, r])
    sum_results = sum_results / len(results)
    x = sum_results

    # Add a per-pixel classification layer with sigmoid as non linear activation function
    outputs = layers.Conv2D(num_classes, 3, activation="sigmoid", padding="same")(x) 

    # Define the model
    model = keras.Model(inputs, outputs)
    return model

# %% [markdown]
# ### free up RAM in case the model definition cells were run multiple times and build model

# %%
keras.backend.clear_session()

selected_model = "ensemble" # unet / linknet / ensemble

if selected_model == "unet":
    model = get_unet_model(img_size, num_classes, filters)
elif selected_model == "linknet":
    model = get_linknet_model(img_size, num_classes, filters)
elif selected_model == "ensemble":
    model = get_ensemble_model(img_size, num_classes, filters)
else:
    print("please specify the model")
    
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 160, 160, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 160, 160, 8)  224         ['input_1[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 160, 160, 16  448         ['input_1[0][0]']
#                                 )
#
#  activation (Activation)        (None, 160, 160, 8)  0           ['conv2d[0][0]']
#
#  activation_16 (Activation)     (None, 160, 160, 16  0           ['conv2d_8[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 160, 160, 8)  584         ['activation[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 160, 160, 16  2320        ['activation_16[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 160, 160, 8)  32         ['conv2d_1[0][0]']
#  alization)
#
#  batch_normalization_8 (BatchNo  (None, 160, 160, 16  64         ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 160, 160, 8)  0           ['batch_normalization[0][0]']
#
#  activation_17 (Activation)     (None, 160, 160, 16  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 80, 80, 8)    0           ['activation_1[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 80, 80, 16)  0           ['activation_17[0][0]']
#
#  dropout (Dropout)              (None, 80, 80, 8)    0           ['max_pooling2d[0][0]']
#
#  dropout_8 (Dropout)            (None, 80, 80, 16)   0           ['max_pooling2d_4[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 80, 80, 16)   1168        ['dropout[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 80, 80, 32)   4640        ['dropout_8[0][0]']
#
#  activation_2 (Activation)      (None, 80, 80, 16)   0           ['conv2d_2[0][0]']
#
#  activation_18 (Activation)     (None, 80, 80, 32)   0           ['conv2d_10[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 80, 80, 16)   2320        ['activation_2[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 80, 80, 32)   9248        ['activation_18[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 80, 80, 16)  64          ['conv2d_3[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 80, 80, 32)  128         ['conv2d_11[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 80, 80, 16)   0           ['batch_normalization_1[0][0]']
#
#  activation_19 (Activation)     (None, 80, 80, 32)   0           ['batch_normalization_9[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 40, 40, 16)  0           ['activation_3[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 40, 40, 32)  0           ['activation_19[0][0]']
#
#  dropout_1 (Dropout)            (None, 40, 40, 16)   0           ['max_pooling2d_1[0][0]']
#
#  dropout_9 (Dropout)            (None, 40, 40, 32)   0           ['max_pooling2d_5[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 40, 40, 32)   4640        ['dropout_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 40, 40, 64)   18496       ['dropout_9[0][0]']
#
#  activation_4 (Activation)      (None, 40, 40, 32)   0           ['conv2d_4[0][0]']
#
#  activation_20 (Activation)     (None, 40, 40, 64)   0           ['conv2d_12[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 40, 40, 32)   9248        ['activation_4[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 40, 40, 64)   36928       ['activation_20[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 40, 40, 32)  128         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 40, 40, 64)  256         ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 40, 40, 32)   0           ['batch_normalization_2[0][0]']
#
#  activation_21 (Activation)     (None, 40, 40, 64)   0           ['batch_normalization_10[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 20, 20, 32)  0           ['activation_5[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 20, 20, 64)  0           ['activation_21[0][0]']
#
#  dropout_2 (Dropout)            (None, 20, 20, 32)   0           ['max_pooling2d_2[0][0]']
#
#  dropout_10 (Dropout)           (None, 20, 20, 64)   0           ['max_pooling2d_6[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 20, 20, 64)   18496       ['dropout_2[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 20, 20, 128)  73856       ['dropout_10[0][0]']
#
#  activation_6 (Activation)      (None, 20, 20, 64)   0           ['conv2d_6[0][0]']
#
#  activation_22 (Activation)     (None, 20, 20, 128)  0           ['conv2d_14[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 20, 20, 64)   36928       ['activation_6[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 20, 20, 128)  147584      ['activation_22[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 20, 20, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_11 (BatchN  (None, 20, 20, 128)  512        ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_7 (Activation)      (None, 20, 20, 64)   0           ['batch_normalization_3[0][0]']
#
#  activation_23 (Activation)     (None, 20, 20, 128)  0           ['batch_normalization_11[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 10, 10, 64)  0           ['activation_7[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 10, 10, 128)  0          ['activation_23[0][0]']
#
#  dropout_3 (Dropout)            (None, 10, 10, 64)   0           ['max_pooling2d_3[0][0]']
#
#  dropout_11 (Dropout)           (None, 10, 10, 128)  0           ['max_pooling2d_7[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 10, 10, 64)  36928       ['dropout_3[0][0]']
#  ose)
#
#  conv2d_transpose_8 (Conv2DTran  (None, 10, 10, 128)  147584     ['dropout_11[0][0]']
#  spose)
#
#  activation_8 (Activation)      (None, 10, 10, 64)   0           ['conv2d_transpose[0][0]']
#
#  activation_24 (Activation)     (None, 10, 10, 128)  0           ['conv2d_transpose_8[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 10, 10, 64)  36928       ['activation_8[0][0]']
#  spose)
#
#  conv2d_transpose_9 (Conv2DTran  (None, 10, 10, 128)  147584     ['activation_24[0][0]']
#  spose)
#
#  batch_normalization_4 (BatchNo  (None, 10, 10, 64)  256         ['conv2d_transpose_1[0][0]']
#  rmalization)
#
#  batch_normalization_12 (BatchN  (None, 10, 10, 128)  512        ['conv2d_transpose_9[0][0]']
#  ormalization)
#
#  activation_9 (Activation)      (None, 10, 10, 64)   0           ['batch_normalization_4[0][0]']
#
#  activation_25 (Activation)     (None, 10, 10, 128)  0           ['batch_normalization_12[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 20, 20, 64)   0           ['activation_9[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 20, 20, 128)  0          ['activation_25[0][0]']
#
#  dropout_4 (Dropout)            (None, 20, 20, 64)   0           ['up_sampling2d[0][0]']
#
#  dropout_12 (Dropout)           (None, 20, 20, 128)  0           ['up_sampling2d_4[0][0]']
#
#  concatenate (Concatenate)      (None, 20, 20, 128)  0           ['dropout_4[0][0]',
#                                                                   'activation_7[0][0]']
#
#  add (Add)                      (None, 20, 20, 128)  0           ['dropout_12[0][0]',
#                                                                   'activation_23[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 20, 20, 32)  36896       ['concatenate[0][0]']
#  spose)
#
#  conv2d_transpose_10 (Conv2DTra  (None, 20, 20, 64)  73792       ['add[0][0]']
#  nspose)
#
#  activation_10 (Activation)     (None, 20, 20, 32)   0           ['conv2d_transpose_2[0][0]']
#
#  activation_26 (Activation)     (None, 20, 20, 64)   0           ['conv2d_transpose_10[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 20, 20, 32)  9248        ['activation_10[0][0]']
#  spose)
#
#  conv2d_transpose_11 (Conv2DTra  (None, 20, 20, 64)  36928       ['activation_26[0][0]']
#  nspose)
#
#  batch_normalization_5 (BatchNo  (None, 20, 20, 32)  128         ['conv2d_transpose_3[0][0]']
#  rmalization)
#
#  batch_normalization_13 (BatchN  (None, 20, 20, 64)  256         ['conv2d_transpose_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 20, 20, 32)   0           ['batch_normalization_5[0][0]']
#
#  activation_27 (Activation)     (None, 20, 20, 64)   0           ['batch_normalization_13[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 40, 40, 32)  0           ['activation_11[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 40, 40, 64)  0           ['activation_27[0][0]']
#
#  dropout_5 (Dropout)            (None, 40, 40, 32)   0           ['up_sampling2d_1[0][0]']
#
#  dropout_13 (Dropout)           (None, 40, 40, 64)   0           ['up_sampling2d_5[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 40, 40, 64)   0           ['dropout_5[0][0]',
#                                                                   'activation_5[0][0]']
#
#  add_1 (Add)                    (None, 40, 40, 64)   0           ['dropout_13[0][0]',
#                                                                   'activation_21[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 40, 40, 16)  9232        ['concatenate_1[0][0]']
#  spose)
#
#  conv2d_transpose_12 (Conv2DTra  (None, 40, 40, 32)  18464       ['add_1[0][0]']
#  nspose)
#
#  activation_12 (Activation)     (None, 40, 40, 16)   0           ['conv2d_transpose_4[0][0]']
#
#  activation_28 (Activation)     (None, 40, 40, 32)   0           ['conv2d_transpose_12[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 40, 40, 16)  2320        ['activation_12[0][0]']
#  spose)
#
#  conv2d_transpose_13 (Conv2DTra  (None, 40, 40, 32)  9248        ['activation_28[0][0]']
#  nspose)
#
#  batch_normalization_6 (BatchNo  (None, 40, 40, 16)  64          ['conv2d_transpose_5[0][0]']
#  rmalization)
#
#  batch_normalization_14 (BatchN  (None, 40, 40, 32)  128         ['conv2d_transpose_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 40, 40, 16)   0           ['batch_normalization_6[0][0]']
#
#  activation_29 (Activation)     (None, 40, 40, 32)   0           ['batch_normalization_14[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 80, 80, 16)  0           ['activation_13[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 80, 80, 32)  0           ['activation_29[0][0]']
#
#  dropout_6 (Dropout)            (None, 80, 80, 16)   0           ['up_sampling2d_2[0][0]']
#
#  dropout_14 (Dropout)           (None, 80, 80, 32)   0           ['up_sampling2d_6[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 80, 80, 32)   0           ['dropout_6[0][0]',
#                                                                   'activation_3[0][0]']
#
#  add_2 (Add)                    (None, 80, 80, 32)   0           ['dropout_14[0][0]',
#                                                                   'activation_19[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 80, 80, 8)   2312        ['concatenate_2[0][0]']
#  spose)
#
#  conv2d_transpose_14 (Conv2DTra  (None, 80, 80, 16)  4624        ['add_2[0][0]']
#  nspose)
#
#  activation_14 (Activation)     (None, 80, 80, 8)    0           ['conv2d_transpose_6[0][0]']
#
#  activation_30 (Activation)     (None, 80, 80, 16)   0           ['conv2d_transpose_14[0][0]']
#
#  conv2d_transpose_7 (Conv2DTran  (None, 80, 80, 8)   584         ['activation_14[0][0]']
#  spose)
#
#  conv2d_transpose_15 (Conv2DTra  (None, 80, 80, 16)  2320        ['activation_30[0][0]']
#  nspose)
#
#  batch_normalization_7 (BatchNo  (None, 80, 80, 8)   32          ['conv2d_transpose_7[0][0]']
#  rmalization)
#
#  batch_normalization_15 (BatchN  (None, 80, 80, 16)  64          ['conv2d_transpose_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 80, 80, 8)    0           ['batch_normalization_7[0][0]']
#
#  activation_31 (Activation)     (None, 80, 80, 16)   0           ['batch_normalization_15[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 160, 160, 8)  0          ['activation_15[0][0]']
#
#  up_sampling2d_7 (UpSampling2D)  (None, 160, 160, 16  0          ['activation_31[0][0]']
#                                 )
#
#  dropout_7 (Dropout)            (None, 160, 160, 8)  0           ['up_sampling2d_3[0][0]']
#
#  dropout_15 (Dropout)           (None, 160, 160, 16  0           ['up_sampling2d_7[0][0]']
#                                 )
#
#  concatenate_3 (Concatenate)    (None, 160, 160, 16  0           ['dropout_7[0][0]',
#                                 )                                 'activation_1[0][0]']
#
#  add_3 (Add)                    (None, 160, 160, 16  0           ['dropout_15[0][0]',
#                                 )                                 'activation_17[0][0]']
#
#  add_4 (Add)                    (None, 160, 160, 16  0           ['concatenate_3[0][0]',
#                                 )                                 'add_3[0][0]']
#
#  tf.math.truediv (TFOpLambda)   (None, 160, 160, 16  0           ['add_4[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 160, 160, 1)  145         ['tf.math.truediv[0][0]']
#
# ==================================================================================================
# Total params: 945,145
# Trainable params: 943,705
# Non-trainable params: 1,440
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training and validation data
# ### split our img paths into a training and a validation set:

# %%
import time

# shuffle input images and corresponding masks to introduce randomness, but same random seed that shuffle keeps them aligned
random.Random(63).shuffle(all_images_normalized) #int(time.time())
random.Random(63).shuffle(all_masks_normalized)

random.Random(100).shuffle(val_all_images_normalized)
random.Random(100).shuffle(val_all_masks_normalized)

# assign training set
train_imgs = all_images_normalized
train_msks = all_masks_normalized

# assign validation set (take second half of validation set)
val_imgs = val_all_images_normalized[:len(val_all_images_normalized)//2]
val_msks = val_all_masks_normalized[:len(val_all_images_normalized)//2]

# assign test set (take second half of validation set)
test_imgs = val_all_images_normalized[len(val_all_images_normalized)//2:]
test_msks = val_all_masks_normalized[len(val_all_images_normalized)//2:]

train_gen = (train_imgs, train_msks)
val_gen = (val_imgs, val_msks)

test_gen = (test_imgs, test_msks)

# %% [markdown]
# ### check lengths and shapes

# %%
print("Lengths Train, Val, Test: ", len(train_imgs), len(val_imgs), len(test_imgs))


print("Train Shapes: ", train_imgs.shape, train_msks.shape)
print("Val Shapes: ", val_imgs.shape, val_msks.shape)
print("Test Shapes: ", test_imgs.shape, test_msks.shape)
# Out:
# Lengths Train, Val, Test:  810 100 100
# Train Shapes:  (810, 160, 160, 3) (810, 160, 160, 1)
# Val Shapes:  (100, 160, 160, 3) (100, 160, 160, 1)
# Test Shapes:  (100, 160, 160, 3) (100, 160, 160, 1)

# %% [markdown]
# ## Data augmentation:
# ### execute the next 4 cells only if data augmentation should be applied

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_imgs, train_msks))
val_dataset = tf.data.Dataset.from_tensor_slices((val_imgs, val_msks))

# %% [markdown]
# ### check if shapes are correct: for input: (img_size1, img_size2, 3), for mask: (img_size1, img_size2, 1)

# %%
for x,y in train_dataset:
    print(x.shape, y.shape)
    break
# Out:
# (160, 160, 3) (160, 160, 1)

# %% [markdown]
# ### Augmentations: Flippings and Rotations

# %%
class Augment(tf.keras.layers.Layer):
  def __init__(self, seed=42):
    super().__init__()
    # both use the same seed, so they'll make the same random changes.
    # augmentations that dont move the image can be added here
    self.augment_inputs = tf.keras.Sequential([
      layers.RandomFlip("horizontal_and_vertical", seed=seed),
      layers.RandomRotation(0.25, seed=seed+1),
    ])
    
    self.augment_labels = tf.keras.Sequential([
      layers.RandomFlip("horizontal_and_vertical", seed=seed),
      layers.RandomRotation(0.25, seed=seed+1),
    ])

  def call(self, inputs, labels):
    inputs = self.augment_inputs(inputs)
    labels = self.augment_labels(labels)
    return inputs, labels

# %% [markdown]
# ### map augmentations to training set

# %%
train_batches = (
    train_dataset
    .cache()
    .shuffle(1000)
    .batch(batch_size)
    .map(Augment())
    .prefetch(buffer_size=tf.data.AUTOTUNE))

val_batches = val_dataset.batch(batch_size)

# %% [markdown]
# ### Configure the model for training.
# ### We use the binary cross entropy as the model segments into 0 (black) or 1 (white)

# %%
import keras.backend as K

def dice_loss(y_true, y_pred):
    smooth = 1.0
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return 1.0 - (2.0 * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# different options for loss:

# 1. loss="binary_crossentropy"
# 2. loss="binary_focal_crossentropy"
# 3. loss=dice_loss

model.compile(optimizer="adam", loss="binary_crossentropy", # optimizer=opt for SGD optimizer
              metrics=['accuracy',
                       keras.metrics.Recall(), # is same as sensitivity
                       keras.metrics.FalseNegatives(), 
                       keras.metrics.FalsePositives(), 
                       keras.metrics.TrueNegatives(),
                       keras.metrics.TruePositives(),
                       keras.metrics.AUC()]) # area under roc curve

callbacks = [
    keras.callbacks.ModelCheckpoint("checkpoint_best_validation.h5", save_best_only=True)
]

# %% [markdown]
# ## Training phase (with data augmentation)
# ### Train the model, doing validation at the end of each epoch.

# %%
epochs = 200
model_history = model.fit(train_batches, epochs=epochs, validation_data=val_batches, callbacks=callbacks)
# Out:
# Epoch 1/200
# 26/26 [==============================] - 46s 1s/step - loss: 0.4110 - accuracy: 0.8399 - recall: 0.3254 - false_negatives: 180111.0000 - false_positives: 3139735.0000 - true_negatives: 17329292.0000 - true_positives: 86860.0000 - auc: 0.6753 - val_loss: 0.5947 - val_accuracy: 0.7199 - val_recall: 8.3302e-04 - val_false_negatives: 28787.0000 - val_false_positives: 688174.0000 - val_true_negatives: 1843015.0000 - val_true_positives: 24.0000 - val_auc: 0.3800
# Epoch 2/200
# 26/26 [==============================] - 23s 878ms/step - loss: 0.0974 - accuracy: 0.9885 - recall: 0.2057 - false_negatives: 212053.0000 - false_positives: 26457.0000 - true_negatives: 20442572.0000 - true_positives: 54918.0000 - auc: 0.9093 - val_loss: 0.2396 - val_accuracy: 0.9887 - val_recall: 0.0000e+00 - val_false_negatives: 28811.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 2531189.0000 - val_true_positives: 0.0000e+00 - val_auc: 0.7330
# Epoch 3/200
# 26/26 [==============================] - 23s 878ms/step - loss: 0.0563 - accuracy: 0.9902 - recall: 0.3512 - false_negatives: 173204.0000 - false_positives: 29328.0000 - true_negatives: 20439700.0000 - true_positives: 93767.0000 - auc: 0.9597 - val_loss: 0.1220 - val_accuracy: 0.9887 - val_recall: 0.0000e+00 - val_false_negatives: 28811.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 2531189.0000 - val_true_positives: 0.0000e+00 - val_auc: 0.6726
# Epoch 4/200
# 26/26 [==============================] - 23s 878ms/step - loss: 0.0424 - accuracy: 0.9911 - recall: 0.4088 - false_negatives: 157837.0000 - false_positives: 26432.0000 - true_negatives: 20442596.0000 - true_positives: 109134.0000 - auc: 0.9757 - val_loss: 0.1194 - val_accuracy: 0.9881 - val_recall: 0.0000e+00 - val_false_negatives: 28811.0000 - val_false_positives: 1550.0000 - val_true_negatives: 2529639.0000 - val_true_positives: 0.0000e+00 - val_auc: 0.7465
# Epoch 5/200
# 26/26 [==============================] - 23s 880ms/step - loss: 0.0352 - accuracy: 0.9916 - recall: 0.4614 - false_negatives: 143798.0000 - false_positives: 30147.0000 - true_negatives: 20438880.0000 - true_positives: 123173.0000 - auc: 0.9840 - val_loss: 0.0817 - val_accuracy: 0.9886 - val_recall: 0.0000e+00 - val_false_negatives: 28811.0000 - val_false_positives: 350.0000 - val_true_negatives: 2530839.0000 - val_true_positives: 0.0000e+00 - val_auc: 0.9317
# Epoch 6/200
# 26/26 [==============================] - 23s 877ms/step - loss: 0.0302 - accuracy: 0.9921 - recall: 0.5222 - false_negatives: 127570.0000 - false_positives: 36391.0000 - true_negatives: 20432640.0000 - true_positives: 139401.0000 - auc: 0.9895 - val_loss: 0.0620 - val_accuracy: 0.9887 - val_recall: 0.0000e+00 - val_false_negatives: 28811.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 2531189.0000 - val_true_positives: 0.0000e+00 - val_auc: 0.7714
# Epoch 7/200
# 26/26 [==============================] - 23s 880ms/step - loss: 0.0259 - accuracy: 0.9929 - recall: 0.5742 - false_negatives: 113684.0000 - false_positives: 34260.0000 - true_negatives: 20434768.0000 - true_positives: 153287.0000 - auc: 0.9919 - val_loss: 0.0530 - val_accuracy: 0.9887 - val_recall: 0.0000e+00 - val_false_negatives: 28811.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 2531189.0000 - val_true_positives: 0.0000e+00 - val_auc: 0.9136
# Epoch 8/200
# 26/26 [==============================] - 22s 866ms/step - loss: 0.0225 - accuracy: 0.9936 - recall: 0.6248 - false_negatives: 100162.0000 - false_positives: 33463.0000 - true_negatives: 20435566.0000 - true_positives: 166809.0000 - auc: 0.9940 - val_loss: 0.0592 - val_accuracy: 0.9887 - val_recall: 0.0000e+00 - val_false_negatives: 28811.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 2531189.0000 - val_true_positives: 0.0000e+00 - val_auc: 0.7170
# Epoch 9/200
# 26/26 [==============================] - 22s 865ms/step - loss: 0.0201 - accuracy: 0.9941 - recall: 0.6577 - false_negatives: 91384.0000 - false_positives: 30652.0000 - true_negatives: 20438380.0000 - true_positives: 175587.0000 - auc: 0.9947 - val_loss: 0.0633 - val_accuracy: 0.9887 - val_recall: 0.0000e+00 - val_false_negatives: 28811.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 2531189.0000 - val_true_positives: 0.0000e+00 - val_auc: 0.5115
# Epoch 10/200
# 26/26 [==============================] - 15s 568ms/step - loss: 0.0181 - accuracy: 0.9945 - recall: 0.6969 - false_negatives: 80931.0000 - false_positives: 32493.0000 - true_negatives: 20436536.0000 - true_positives: 186040.0000 - auc: 0.9954 - val_loss: 0.0595 - val_accuracy: 0.9887 - val_recall: 0.0000e+00 - val_false_negatives: 28811.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 2531189.0000 - val_true_positives: 0.0000e+00 - val_auc: 0.7299
# Epoch 11/200
# 26/26 [==============================] - 6s 231ms/step - loss: 0.0169 - accuracy: 0.9948 - recall: 0.7075 - false_negatives: 78102.0000 - false_positives: 29836.0000 - true_negatives: 20439192.0000 - true_positives: 188869.0000 - auc: 0.9964 - val_loss: 0.0621 - val_accuracy: 0.9887 - val_recall: 0.0000e+00 - val_false_negatives: 28811.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 2531189.0000 - val_true_positives: 0.0000e+00 - val_auc: 0.6376
# Epoch 12/200
# 26/26 [==============================] - 6s 232ms/step - loss: 0.0151 - accuracy: 0.9953 - recall: 0.7435 - false_negatives: 68489.0000 - false_positives: 28604.0000 - true_negatives: 20440424.0000 - true_positives: 198482.0000 - auc: 0.9970 - val_loss: 0.0551 - val_accuracy: 0.9887 - val_recall: 0.0000e+00 - val_false_negatives: 28811.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 2531189.0000 - val_true_positives: 0.0000e+00 - val_auc: 0.8550
# Epoch 13/200
# 26/26 [==============================] - 6s 232ms/step - loss: 0.0142 - accuracy: 0.9955 - recall: 0.7654 - false_negatives: 62627.0000 - false_positives: 30402.0000 - true_negatives: 20438628.0000 - true_positives: 204344.0000 - auc: 0.9971 - val_loss: 0.0606 - val_accuracy: 0.9887 - val_recall: 0.0000e+00 - val_false_negatives: 28811.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 2531189.0000 - val_true_positives: 0.0000e+00 - val_auc: 0.7783
# Epoch 14/200
# 26/26 [==============================] - 6s 234ms/step - loss: 0.0140 - accuracy: 0.9955 - recall: 0.7601 - false_negatives: 64051.0000 - false_positives: 29762.0000 - true_negatives: 20439268.0000 - true_positives: 202920.0000 - auc: 0.9972 - val_loss: 0.0537 - val_accuracy: 0.9887 - val_recall: 0.0044 - val_false_negatives: 28683.0000 - val_false_positives: 237.0000 - val_true_negatives: 2530952.0000 - val_true_positives: 128.0000 - val_auc: 0.8759
# Epoch 15/200
# 26/26 [==============================] - 6s 236ms/step - loss: 0.0060 - accuracy: 0.9978 - recall: 0.8962 - false_negatives: 27707.0000 - false_positives: 18445.0000 - true_negatives: 20450584.0000 - true_positives: 239264.0000 - auc: 0.9993 - val_loss: 0.0202 - val_accuracy: 0.9942 - val_recall: 0.6325 - val_false_negatives: 10589.0000 - val_false_positives: 4215.0000 - val_true_negatives: 2526974.0000 - val_true_positives: 18222.0000 - val_auc: 0.9532
# Epoch 35/200
# 26/26 [==============================] - 6s 236ms/step - loss: 0.0058 - accuracy: 0.9979 - recall: 0.9035 - false_negatives: 25761.0000 - false_positives: 18776.0000 - true_negatives: 20450254.0000 - true_positives: 241210.0000 - auc: 0.9993 - val_loss: 0.0203 - val_accuracy: 0.9943 - val_recall: 0.6474 - val_false_negatives: 10158.0000 - val_false_positives: 4469.0000 - val_true_negatives: 2526720.0000 - val_true_positives: 18653.0000 - val_auc: 0.9508
# Epoch 36/200
# 26/26 [==============================] - 6s 237ms/step - loss: 0.0058 - accuracy: 0.9979 - recall: 0.9035 - false_negatives: 25775.0000 - false_positives: 18700.0000 - true_negatives: 20450330.0000 - true_positives: 241196.0000 - auc: 0.9994 - val_loss: 0.0208 - val_accuracy: 0.9941 - val_recall: 0.6108 - val_false_negatives: 11213.0000 - val_false_positives: 3845.0000 - val_true_negatives: 2527344.0000 - val_true_positives: 17598.0000 - val_auc: 0.9490
# Epoch 37/200
# 26/26 [==============================] - 6s 236ms/step - loss: 0.0058 - accuracy: 0.9979 - recall: 0.9005 - false_negatives: 26565.0000 - false_positives: 17940.0000 - true_negatives: 20451088.0000 - true_positives: 240406.0000 - auc: 0.9993 - val_loss: 0.0196 - val_accuracy: 0.9942 - val_recall: 0.6143 - val_false_negatives: 11111.0000 - val_false_positives: 3673.0000 - val_true_negatives: 2527516.0000 - val_true_positives: 17700.0000 - val_auc: 0.9565
# Epoch 38/200
# 26/26 [==============================] - 6s 237ms/step - loss: 0.0056 - accuracy: 0.9979 - recall: 0.9075 - false_negatives: 24703.0000 - false_positives: 18940.0000 - true_negatives: 20450090.0000 - true_positives: 242268.0000 - auc: 0.9994 - val_loss: 0.0233 - val_accuracy: 0.9938 - val_recall: 0.5226 - val_false_negatives: 13755.0000 - val_false_positives: 2081.0000 - val_true_negatives: 2529108.0000 - val_true_positives: 15056.0000 - val_auc: 0.9349
# Epoch 39/200
# 26/26 [==============================] - 6s 236ms/step - loss: 0.0055 - accuracy: 0.9980 - recall: 0.9063 - false_negatives: 25027.0000 - false_positives: 17359.0000 - true_negatives: 20451668.0000 - true_positives: 241944.0000 - auc: 0.9993 - val_loss: 0.0245 - val_accuracy: 0.9932 - val_recall: 0.4550 - val_false_negatives: 15702.0000 - val_false_positives: 1620.0000 - val_true_negatives: 2529569.0000 - val_true_positives: 13109.0000 - val_auc: 0.9360
# Epoch 40/200
# 26/26 [==============================] - 6s 245ms/step - loss: 0.0054 - accuracy: 0.9980 - recall: 0.9083 - false_negatives: 24488.0000 - false_positives: 17604.0000 - true_negatives: 20451426.0000 - true_positives: 242483.0000 - auc: 0.9994 - val_loss: 0.0173 - val_accuracy: 0.9945 - val_recall: 0.6955 - val_false_negatives: 8773.0000 - val_false_positives: 5313.0000 - val_true_negatives: 2525876.0000 - val_true_positives: 20038.0000 - val_auc: 0.9690
# Epoch 41/200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.
200
# 26/26 [==============================] - 6s 237ms/step - loss: 0.0049 - accuracy: 0.9981 - recall: 0.9189 - false_negatives: 21647.0000 - false_positives: 17056.0000 - true_negatives: 20451976.0000 - true_positives: 245324.0000 - auc: 0.9994 - val_loss: 0.0198 - val_accuracy: 0.9946 - val_recall: 0.6808 - val_false_negatives: 9196.0000 - val_false_positives: 4606.0000 - val_true_negatives: 2526583.0000 - val_true_positives: 19615.0000 - val_auc: 0.9559
# Epoch 49/200
# 26/26 [==============================] - 6s 236ms/step - loss: 0.0052 - accuracy: 0.9980 - recall: 0.9119 - false_negatives: 23531.0000 - false_positives: 18230.0000 - true_negatives: 20450800.0000 - true_positives: 243440.0000 - auc: 0.9994 - val_loss: 0.0220 - val_accuracy: 0.9940 - val_recall: 0.6035 - val_false_negatives: 11423.0000 - val_false_positives: 3819.0000 - val_true_negatives: 2527370.0000 - val_true_positives: 17388.0000 - val_auc: 0.9424
# Epoch 50/200
# 26/26 [==============================] - 6s 236ms/step - loss: 0.0048 - accuracy: 0.9982 - recall: 0.9238 - false_negatives: 20331.0000 - false_positives: 17275.0000 - true_negatives: 20451756.0000 - true_positives: 246640.0000 - auc: 0.9995 - val_loss: 0.0249 - val_accuracy: 0.9942 - val_recall: 0.5479 - val_false_negatives: 13025.0000 - val_false_positives: 1695.0000 - val_true_negatives: 2529494.0000 - val_true_positives: 15786.0000 - val_auc: 0.9153
# Epoch 51/200
# 26/26 [==============================] - 6s 236ms/step - loss: 0.0044 - accuracy: 0.9983 - recall: 0.9250 - false_negatives: 20034.0000 - false_positives: 15464.0000 - true_negatives: 20453566.0000 - true_positives: 246937.0000 - auc: 0.9996 - val_loss: 0.0217 - val_accuracy: 0.9946 - val_recall: 0.6456 - val_false_negatives: 10212.0000 - val_false_positives: 3700.0000 - val_true_negatives: 2527489.0000 - val_true_positives: 18599.0000 - val_auc: 0.9372
# Epoch 52/200
# 26/26 [==============================] - 6s 237ms/step - loss: 0.0044 - accuracy: 0.9983 - recall: 0.9284 - false_negatives: 19113.0000 - false_positives: 15817.0000 - true_negatives: 20453212.0000 - true_positives: 247858.0000 - auc: 0.9996 - val_loss: 0.0218 - val_accuracy: 0.9946 - val_recall: 0.5972 - val_false_negatives: 11604.0000 - val_false_positives: 2270.0000 - val_true_negatives: 2528919.0000 - val_true_positives: 17207.0000 - val_auc: 0.9329
# Epoch 53/200
# 26/26 [==============================] - 6s 237ms/step - loss: 0.0043 - accuracy: 0.9983 - recall: 0.9289 - false_negatives: 18989.0000 - false_positives: 15541.0000 - true_negatives: 20453490.0000 - true_positives: 247982.0000 - auc: 0.9995 - val_loss: 0.0228 - val_accuracy: 0.9939 - val_recall: 0.5846 - val_false_negatives: 11968.0000 - val_false_positives: 3641.0000 - val_true_negatives: 2527548.0000 - val_true_positives: 16843.0000 - val_auc: 0.9378
# Epoch 54/200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0047 - accuracy: 0.9982 - recall: 0.9212 - false_negatives: 21035.0000 - false_positives: 16683.0000 - true_negatives: 20452348.0000 - true_positives: 245936.0000 - auc: 0.9994 - val_loss: 0.0205 - val_accuracy: 0.9943 - val_recall: 0.5991 - val_false_negatives: 11551.0000 - val_false_positives: 2960.0000 - val_true_negatives: 2528229.0000 - val_true_positives: 17260.0000 - val_auc: 0.9441
# Epoch 55/200
# 26/26 [==============================] - 6s 236ms/step - loss: 0.0044 - accuracy: 0.9983 - recall: 0.9227 - false_negatives: 20635.0000 - false_positives: 14892.0000 - true_negatives: 20454136.0000 - true_positives: 246336.0000 - auc: 0.9996 - val_loss: 0.0177 - val_accuracy: 0.9943 - val_recall: 0.7733 - val_false_negatives: 6531.0000 - val_false_positives: 8100.0000 - val_true_negatives: 2523089.0000 - val_true_positives: 22280.0000 - val_auc: 0.9732
# Epoch 56/200
# 26/26 [==============================] - 6s 247ms/step - loss: 0.0043 - accuracy: 0.9983 - recall: 0.9278 - false_negatives: 19282.0000 - false_positives: 15515.0000 - true_negatives: 20453516.0000 - true_positives: 247689.0000 - auc: 0.9996 - val_loss: 0.0167 - val_accuracy: 0.9950 - val_recall: 0.7492 - val_false_negatives: 7226.0000 - val_false_positives: 5586.0000 - val_true_negatives: 2525603.0000 - val_true_positives: 21585.0000 - val_auc: 0.9660
# Epoch 57/200
# 26/26 [==============================] - 6s 248ms/step - loss: 0.0044 - accuracy: 0.9983 - recall: 0.9289 - false_negatives: 18979.0000 - false_positives: 16426.0000 - true_negatives: 20452604.0000 - true_positives: 247992.0000 - auc: 0.9996 - val_loss: 0.0163 - val_accuracy: 0.9953 - val_recall: 0.7251 - val_false_negatives: 7919.0000 - val_false_positives: 4114.0000 - val_true_negatives: 2527075.0000 - val_true_positives: 20892.0000 - val_auc: 0.9626
# Epoch 58/200
# 26/26 [==============================] - 6s 236ms/step - loss: 0.0041 - accuracy: 0.9984 - recall: 0.9284 - false_negatives: 19104.0000 - false_positives: 14133.0000 - true_negatives: 20454896.0000 - true_positives: 247867.0000 - auc: 0.9996 - val_loss: 0.0216 - val_accuracy: 0.9944 - val_recall: 0.6254 - val_false_negatives: 10792.0000 - val_false_positives: 3454.0000 - val_true_negatives: 2527735.0000 - val_true_positives: 18019.0000 - val_auc: 0.9361
# Epoch 59/200
# 26/26 [==============================] - 6s 237ms/step - loss: 0.0040 - accuracy: 0.9984 - recall: 0.9321 - false_negatives: 18132.0000 - false_positives: 14666.0000 - true_negatives: 20454364.0000 - true_positives: 248839.0000 - auc: 0.9997 - val_loss: 0.0186 - val_accuracy: 0.9950 - val_recall: 0.6348 - val_false_negatives: 10521.0000 - val_false_positives: 2326.0000 - val_true_negatives: 2528863.0000 - val_true_positives: 18290.0000 - val_auc: 0.9487
# Epoch 60/200
# 26/26 [==============================] - 6s 237ms/step - loss: 0.0039 - accuracy: 0.9985 - recall: 0.9334 - false_negatives: 17787.0000 - false_positives: 14040.0000 - true_negatives: 20454992.0000 - true_positives: 249184.0000 - auc: 0.9997 - val_loss: 0.0203 - val_accuracy: 0.9947 - val_recall: 0.6621 - val_false_negatives: 9735.0000 - val_false_positives: 3734.0000 - val_true_negatives: 2527455.0000 - val_true_positives: 19076.0000 - val_auc: 0.9436
# Epoch 61/200
# 26/26 [==============================] - 6s 236ms/step - loss: 0.0039 - accuracy: 0.9985 - recall: 0.9345 - false_negatives: 17491.0000 - false_positives: 14106.0000 - true_negatives: 20454924.0000 - true_positives: 249480.0000 - auc: 0.9996 - val_loss: 0.0178 - val_accuracy: 0.9950 - val_recall: 0.6893 - val_false_negatives: 8953.0000 - val_false_positives: 3853.0000 - val_true_negatives: 2527336.0000 - val_true_positives: 19858.0000 - val_auc: 0.9556
# Epoch 62/200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.
200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0031 - accuracy: 0.9988 - recall: 0.9488 - false_negatives: 13664.0000 - false_positives: 12045.0000 - true_negatives: 20456988.0000 - true_positives: 253307.0000 - auc: 0.9997 - val_loss: 0.0248 - val_accuracy: 0.9945 - val_recall: 0.5825 - val_false_negatives: 12028.0000 - val_false_positives: 1977.0000 - val_true_negatives: 2529212.0000 - val_true_positives: 16783.0000 - val_auc: 0.9154
# Epoch 84/200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0031 - accuracy: 0.9988 - recall: 0.9473 - false_negatives: 14075.0000 - false_positives: 11648.0000 - true_negatives: 20457382.0000 - true_positives: 252896.0000 - auc: 0.9998 - val_loss: 0.0265 - val_accuracy: 0.9942 - val_recall: 0.5487 - val_false_negatives: 13001.0000 - val_false_positives: 1732.0000 - val_true_negatives: 2529457.0000 - val_true_positives: 15810.0000 - val_auc: 0.9044
# Epoch 85/200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0031 - accuracy: 0.9987 - recall: 0.9464 - false_negatives: 14299.0000 - false_positives: 11661.0000 - true_negatives: 20457368.0000 - true_positives: 252672.0000 - auc: 0.9997 - val_loss: 0.0215 - val_accuracy: 0.9948 - val_recall: 0.6218 - val_false_negatives: 10895.0000 - val_false_positives: 2308.0000 - val_true_negatives: 2528881.0000 - val_true_positives: 17916.0000 - val_auc: 0.9341
# Epoch 86/200
# 26/26 [==============================] - 6s 237ms/step - loss: 0.0032 - accuracy: 0.9987 - recall: 0.9454 - false_negatives: 14587.0000 - false_positives: 11946.0000 - true_negatives: 20457084.0000 - true_positives: 252384.0000 - auc: 0.9997 - val_loss: 0.0224 - val_accuracy: 0.9945 - val_recall: 0.7016 - val_false_negatives: 8597.0000 - val_false_positives: 5499.0000 - val_true_negatives: 2525690.0000 - val_true_positives: 20214.0000 - val_auc: 0.9415
# Epoch 87/200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0033 - accuracy: 0.9987 - recall: 0.9440 - false_negatives: 14944.0000 - false_positives: 12065.0000 - true_negatives: 20456964.0000 - true_positives: 252027.0000 - auc: 0.9996 - val_loss: 0.0189 - val_accuracy: 0.9951 - val_recall: 0.7103 - val_false_negatives: 8346.0000 - val_false_positives: 4213.0000 - val_true_negatives: 2526976.0000 - val_true_positives: 20465.0000 - val_auc: 0.9502
# Epoch 88/200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0034 - accuracy: 0.9986 - recall: 0.9451 - false_negatives: 14651.0000 - false_positives: 13525.0000 - true_negatives: 20455504.0000 - true_positives: 252320.0000 - auc: 0.9996 - val_loss: 0.0210 - val_accuracy: 0.9948 - val_recall: 0.6289 - val_false_negatives: 10693.0000 - val_false_positives: 2706.0000 - val_true_negatives: 2528483.0000 - val_true_positives: 18118.0000 - val_auc: 0.9396
# Epoch 89/200
# 26/26 [==============================] - 6s 237ms/step - loss: 0.0032 - accuracy: 0.9987 - recall: 0.9470 - false_negatives: 14140.0000 - false_positives: 12211.0000 - true_negatives: 20456818.0000 - true_positives: 252831.0000 - auc: 0.9997 - val_loss: 0.0253 - val_accuracy: 0.9944 - val_recall: 0.5849 - val_false_negatives: 11960.0000 - val_false_positives: 2412.0000 - val_true_negatives: 2528777.0000 - val_true_positives: 16851.0000 - val_auc: 0.9154
# Epoch 90/200
# 26/26 [==============================] - 6s 237ms/step - loss: 0.
200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0029 - accuracy: 0.9988 - recall: 0.9518 - false_negatives: 12878.0000 - false_positives: 11195.0000 - true_negatives: 20457836.0000 - true_positives: 254093.0000 - auc: 0.9998 - val_loss: 0.0224 - val_accuracy: 0.9950 - val_recall: 0.6518 - val_false_negatives: 10033.0000 - val_false_positives: 2780.0000 - val_true_negatives: 2528409.0000 - val_true_positives: 18778.0000 - val_auc: 0.9260
# Epoch 98/200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0029 - accuracy: 0.9988 - recall: 0.9513 - false_negatives: 13013.0000 - false_positives: 11253.0000 - true_negatives: 20457776.0000 - true_positives: 253958.0000 - auc: 0.9998 - val_loss: 0.0267 - val_accuracy: 0.9942 - val_recall: 0.5637 - val_false_negatives: 12569.0000 - val_false_positives: 2344.0000 - val_true_negatives: 2528845.0000 - val_true_positives: 16242.0000 - val_auc: 0.9125
# Epoch 99/200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0034 - accuracy: 0.9987 - recall: 0.9427 - false_negatives: 15295.0000 - false_positives: 12359.0000 - true_negatives: 20456668.0000 - true_positives: 251676.0000 - auc: 0.9997 - val_loss: 0.0277 - val_accuracy: 0.9941 - val_recall: 0.5574 - val_false_negatives: 12751.0000 - val_false_positives: 2444.0000 - val_true_negatives: 2528745.0000 - val_true_positives: 16060.0000 - val_auc: 0.9053
# Epoch 100/200
# 26/26 [==============================] - 6s 237ms/step - loss: 0.0036 - accuracy: 0.9986 - recall: 0.9377 - false_negatives: 16638.0000 - false_positives: 12872.0000 - true_negatives: 20456156.0000 - true_positives: 250333.0000 - auc: 0.9996 - val_loss: 0.0190 - val_accuracy: 0.9952 - val_recall: 0.7194 - val_false_negatives: 8083.0000 - val_false_positives: 4295.0000 - val_true_negatives: 2526894.0000 - val_true_positives: 20728.0000 - val_auc: 0.9539
# Epoch 101/200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0032 - accuracy: 0.9987 - recall: 0.9464 - false_negatives: 14312.0000 - false_positives: 12303.0000 - true_negatives: 20456728.0000 - true_positives: 252659.0000 - auc: 0.9997 - val_loss: 0.0195 - val_accuracy: 0.9951 - val_recall: 0.7028 - val_false_negatives: 8564.0000 - val_false_positives: 3990.0000 - val_true_negatives: 2527199.0000 - val_true_positives: 20247.0000 - val_auc: 0.9465
# Epoch 102/200
# ...
# Epoch 167/200
# 26/26 [==============================] - 6s 239ms/step - loss: 0.0057 - accuracy: 0.9978 - recall: 0.9063 - false_negatives: 25022.0000 - false_positives: 19870.0000 - true_negatives: 20449156.0000 - true_positives: 241949.0000 - auc: 0.9975 - val_loss: 0.0417 - val_accuracy: 0.9919 - val_recall: 0.4802 - val_false_negatives: 14976.0000 - val_false_positives: 5829.0000 - val_true_negatives: 2525360.0000 - val_true_positives: 13835.0000 - val_auc: 0.8573
# Epoch 168/200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0057 - accuracy: 0.9978 - recall: 0.9003 - false_negatives: 26627.0000 - false_positives: 18847.0000 - true_negatives: 20450184.0000 - true_positives: 240344.0000 - auc: 0.9980 - val_loss: 0.0369 - val_accuracy: 0.9926 - val_recall: 0.4663 - val_false_negatives: 15375.0000 - val_false_positives: 3652.0000 - val_true_negatives: 2527537.0000 - val_true_positives: 13436.0000 - val_auc: 0.8846
# Epoch 169/200
# 26/26 [==============================] - 6s 239ms/step - loss: 0.0045 - accuracy: 0.9983 - recall: 0.9230 - false_negatives: 20558.0000 - false_positives: 15298.0000 - true_negatives: 20453728.0000 - true_positives: 246413.0000 - auc: 0.9987 - val_loss: 0.0272 - val_accuracy: 0.9932 - val_recall: 0.6461 - val_false_negatives: 10195.0000 - val_false_positives: 7163.0000 - val_true_negatives: 2524026.0000 - val_true_positives: 18616.0000 - val_auc: 0.9440
# Epoch 170/200
# 26/26 [==============================] - 6s 237ms/step - loss: 0.0031 - accuracy: 0.9987 - recall: 0.9485 - false_negatives: 13743.0000 - false_positives: 12354.0000 - true_negatives: 20456676.0000 - true_positives: 253228.0000 - auc: 0.9996 - val_loss: 0.0204 - val_accuracy: 0.9951 - val_recall: 0.7079 - val_false_negatives: 8417.0000 - val_false_positives: 4007.0000 - val_true_negatives: 2527182.0000 - val_true_positives: 20394.0000 - val_auc: 0.9504
# Epoch 171/200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0026 - accuracy: 0.9989 - recall: 0.9563 - false_negatives: 11662.0000 - false_positives: 10834.0000 - true_negatives: 20458196.0000 - true_positives: 255309.0000 - auc: 0.9998 - val_loss: 0.0212 - val_accuracy: 0.9951 - val_recall: 0.6928 - val_false_negatives: 8850.0000 - val_false_positives: 3660.0000 - val_true_negatives: 2527529.0000 - val_true_positives: 19961.0000 - val_auc: 0.9424
# Epoch 172/200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0025 - accuracy: 0.9990 - recall: 0.9591 - false_negatives: 10929.0000 - false_positives: 9946.0000 - true_negatives: 20459080.0000 - true_positives: 256042.0000 - auc: 0.9998 - val_loss: 0.0215 - val_accuracy: 0.9950 - val_recall: 0.6907 - val_false_negatives: 8912.0000 - val_false_positives: 3941.0000 - val_true_negatives: 2527248.0000 - val_true_positives: 19899.0000 - val_auc: 0.9449
# Epoch 173/200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0023 - accuracy: 0.9991 - recall: 0.9618 - false_negatives: 10203.0000 - false_positives: 8999.0000 - true_negatives: 20460028.0000 - true_positives: 256768.0000 - auc: 0.9999 - val_loss: 0.0219 - val_accuracy: 0.9950 - val_recall: 0.6903 - val_false_negatives: 8922.0000 - val_false_positives: 3994.0000 - val_true_negatives: 2527195.0000 - val_true_positives: 19889.0000 - val_auc: 0.9385
# Epoch 174/200
# 26/26 [==============================] - 6s 237ms/step - loss: 0.0022 - accuracy: 0.9991 - recall: 0.9632 - false_negatives: 9814.0000 - false_positives: 8895.0000 - true_negatives: 20460132.0000 - true_positives: 257157.0000 - auc: 0.9998 - val_loss: 0.0219 - val_accuracy: 0.9950 - val_recall: 0.6924 - val_false_negatives: 8863.0000 - val_false_positives: 3945.0000 - val_true_negatives: 2527244.0000 - val_true_positives: 19948.0000 - val_auc: 0.9362
# Epoch 175/200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0022 - accuracy: 0.9991 - recall: 0.9630 - false_negatives: 9889.0000 - false_positives: 8834.0000 - true_negatives: 20460194.0000 - true_positives: 257082.0000 - auc: 0.9998 - val_loss: 0.0213 - val_accuracy: 0.9950 - val_recall: 0.6951 - val_false_negatives: 8784.0000 - val_false_positives: 3918.0000 - val_true_negatives: 2527271.0000 - val_true_positives: 20027.0000 - val_auc: 0.9405
# Epoch 176/200
# 26/26 [==============================] - 6s 237ms/step - loss: 0.0022 - accuracy: 0.9991 - recall: 0.9644 - false_negatives: 9517.0000 - false_positives: 8667.0000 - true_negatives: 20460360.0000 - true_positives: 257454.0000 - auc: 0.9998 - val_loss: 0.0214 - val_accuracy: 0.9951 - val_recall: 0.7074 - val_false_negatives: 8430.0000 - val_false_positives: 4029.0000 - val_true_negatives: 2527160.0000 - val_true_positives: 20381.0000 - val_auc: 0.9406
# Epoch 177/200
# 26/26 [==============================] - 6s 239ms/step - loss: 0.0024 - accuracy: 0.9990 - recall: 0.9613 - false_negatives: 10321.0000 - false_positives: 10163.0000 - true_negatives: 20458864.0000 - true_positives: 256650.0000 - auc: 0.9997 - val_loss: 0.0249 - val_accuracy: 0.9946 - val_recall: 0.6282 - val_false_negatives: 10713.0000 - val_false_positives: 3054.0000 - val_true_negatives: 2528135.0000 - val_true_positives: 18098.0000 - val_auc: 0.9253
# Epoch 178/200
# 26/26 [==============================] - 6s 237ms/step - loss: 0.0022 - accuracy: 0.9991 - recall: 0.9623 - false_negatives: 10069.0000 - false_positives: 8762.0000 - true_negatives: 20460266.0000 - true_positives: 256902.0000 - auc: 0.9998 - val_loss: 0.0200 - val_accuracy: 0.9952 - val_recall: 0.7061 - val_false_negatives: 8467.0000 - val_false_positives: 3724.0000 - val_true_negatives: 2527465.0000 - val_true_positives: 20344.0000 - val_auc: 0.9442
# Epoch 179/200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0022 - accuracy: 0.9991 - recall: 0.9636 - false_negatives: 9730.0000 - false_positives: 8959.0000 - true_negatives: 20460072.0000 - true_positives: 257241.0000 - auc: 0.9999 - val_loss: 0.0206 - val_accuracy: 0.9952 - val_recall: 0.6984 - val_false_negatives: 8688.0000 - val_false_positives: 3684.0000 - val_true_negatives: 2527505.0000 - val_true_positives: 20123.0000 - val_auc: 0.9416
# Epoch 180/200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0021 - accuracy: 0.9992 - recall: 0.9651 - false_negatives: 9305.0000 - false_positives: 8238.0000 - true_negatives: 20460788.0000 - true_positives: 257666.0000 - auc: 0.9999 - val_loss: 0.0218 - val_accuracy: 0.9952 - val_recall: 0.6968 - val_false_negatives: 8736.0000 - val_false_positives: 3505.0000 - val_true_negatives: 2527684.0000 - val_true_positives: 20075.0000 - val_auc: 0.9341
# Epoch 181/200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0021 - accuracy: 0.9992 - recall: 0.9662 - false_negatives: 9021.0000 - false_positives: 8433.0000 - true_negatives: 20460594.0000 - true_positives: 257950.0000 - auc: 0.9999 - val_loss: 0.0231 - val_accuracy: 0.9952 - val_recall: 0.7034 - val_false_negatives: 8546.0000 - val_false_positives: 3820.0000 - val_true_negatives: 2527369.0000 - val_true_positives: 20265.0000 - val_auc: 0.9306
# Epoch 182/200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0020 - accuracy: 0.9992 - recall: 0.9673 - false_negatives: 8718.0000 - false_positives: 8470.0000 - true_negatives: 20460558.0000 - true_positives: 258253.0000 - auc: 0.9999 - val_loss: 0.0225 - val_accuracy: 0.9953 - val_recall: 0.6917 - val_false_negatives: 8881.0000 - val_false_positives: 3148.0000 - val_true_negatives: 2528041.0000 - val_true_positives: 19930.0000 - val_auc: 0.9325
# Epoch 183/200
# 26/26 [==============================] - 6s 237ms/step - loss: 0.0020 - accuracy: 0.9992 - recall: 0.9663 - false_negatives: 8988.0000 - false_positives: 7891.0000 - true_negatives: 20461140.0000 - true_positives: 257983.0000 - auc: 0.9999 - val_loss: 0.0226 - val_accuracy: 0.9953 - val_recall: 0.7104 - val_false_negatives: 8345.0000 - val_false_positives: 3672.0000 - val_true_negatives: 2527517.0000 - val_true_positives: 20466.0000 - val_auc: 0.9330
# Epoch 184/200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0020 - accuracy: 0.9992 - recall: 0.9672 - false_negatives: 8746.0000 - false_positives: 8157.0000 - true_negatives: 20460872.0000 - true_positives: 258225.0000 - auc: 0.9998 - val_loss: 0.0255 - val_accuracy: 0.9950 - val_recall: 0.6666 - val_false_negatives: 9606.0000 - val_false_positives: 3122.0000 - val_true_negatives: 2528067.0000 - val_true_positives: 19205.0000 - val_auc: 0.9165
# Epoch 185/200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0020 - accuracy: 0.9992 - recall: 0.9659 - false_negatives: 9093.0000 - false_positives: 7973.0000 - true_negatives: 20461056.0000 - true_positives: 257878.0000 - auc: 0.9999 - val_loss: 0.0249 - val_accuracy: 0.9950 - val_recall: 0.6604 - val_false_negatives: 9784.0000 - val_false_positives: 2987.0000 - val_true_negatives: 2528202.0000 - val_true_positives: 19027.0000 - val_auc: 0.9188
# Epoch 186/200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0020 - accuracy: 0.9992 - recall: 0.9669 - false_negatives: 8850.0000 - false_positives: 8220.0000 - true_negatives: 20460808.0000 - true_positives: 258121.0000 - auc: 0.9999 - val_loss: 0.0242 - val_accuracy: 0.9952 - val_recall: 0.6789 - val_false_negatives: 9250.0000 - val_false_positives: 2916.0000 - val_true_negatives: 2528273.0000 - val_true_positives: 19561.0000 - val_auc: 0.9218
# Epoch 187/200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0019 - accuracy: 0.9992 - recall: 0.9677 - false_negatives: 8619.0000 - false_positives: 7836.0000 - true_negatives: 20461192.0000 - true_positives: 258352.0000 - auc: 0.9999 - val_loss: 0.0243 - val_accuracy: 0.9951 - val_recall: 0.6905 - val_false_negatives: 8917.0000 - val_false_positives: 3568.0000 - val_true_negatives: 2527621.0000 - val_true_positives: 19894.0000 - val_auc: 0.9243
# Epoch 188/200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0019 - accuracy: 0.9992 - recall: 0.9680 - false_negatives: 8542.0000 - false_positives: 7578.0000 - true_negatives: 20461452.0000 - true_positives: 258429.0000 - auc: 0.9999 - val_loss: 0.0234 - val_accuracy: 0.9951 - val_recall: 0.6802 - val_false_negatives: 9215.0000 - val_false_positives: 3205.0000 - val_true_negatives: 2527984.0000 - val_true_positives: 19596.0000 - val_auc: 0.9269
# Epoch 189/200
# 26/26 [==============================] - 6s 237ms/step - loss: 0.0019 - accuracy: 0.9992 - recall: 0.9694 - false_negatives: 8170.0000 - false_positives: 7824.0000 - true_negatives: 20461206.0000 - true_positives: 258801.0000 - auc: 0.9999 - val_loss: 0.0269 - val_accuracy: 0.9950 - val_recall: 0.6376 - val_false_negatives: 10442.0000 - val_false_positives: 2303.0000 - val_true_negatives: 2528886.0000 - val_true_positives: 18369.0000 - val_auc: 0.9099
# Epoch 190/200
# 26/26 [==============================] - 6s 239ms/step - loss: 0.0018 - accuracy: 0.9992 - recall: 0.9690 - false_negatives: 8263.0000 - false_positives: 7385.0000 - true_negatives: 20461644.0000 - true_positives: 258708.0000 - auc: 0.9999 - val_loss: 0.0257 - val_accuracy: 0.9952 - val_recall: 0.6663 - val_false_negatives: 9613.0000 - val_false_positives: 2779.0000 - val_true_negatives: 2528410.0000 - val_true_positives: 19198.0000 - val_auc: 0.9166
# Epoch 191/200
# 26/26 [==============================] - 6s 239ms/step - loss: 0.0019 - accuracy: 0.9992 - recall: 0.9689 - false_negatives: 8295.0000 - false_positives: 7668.0000 - true_negatives: 20461360.0000 - true_positives: 258676.0000 - auc: 0.9999 - val_loss: 0.0243 - val_accuracy: 0.9952 - val_recall: 0.6862 - val_false_negatives: 9040.0000 - val_false_positives: 3189.0000 - val_true_negatives: 2528000.0000 - val_true_positives: 19771.0000 - val_auc: 0.9244
# Epoch 192/200
# 26/26 [==============================] - 6s 237ms/step - loss: 0.0019 - accuracy: 0.9992 - recall: 0.9691 - false_negatives: 8245.0000 - false_positives: 7688.0000 - true_negatives: 20461340.0000 - true_positives: 258726.0000 - auc: 0.9999 - val_loss: 0.0239 - val_accuracy: 0.9954 - val_recall: 0.7010 - val_false_negatives: 8615.0000 - val_false_positives: 3280.0000 - val_true_negatives: 2527909.0000 - val_true_positives: 20196.0000 - val_auc: 0.9258
# Epoch 193/200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0021 - accuracy: 0.9991 - recall: 0.9653 - false_negatives: 9267.0000 - false_positives: 8510.0000 - true_negatives: 20460520.0000 - true_positives: 257704.0000 - auc: 0.9998 - val_loss: 0.0256 - val_accuracy: 0.9951 - val_recall: 0.7153 - val_false_negatives: 8202.0000 - val_false_positives: 4321.0000 - val_true_negatives: 2526868.0000 - val_true_positives: 20609.0000 - val_auc: 0.9294
# Epoch 194/200
# 26/26 [==============================] - 6s 237ms/step - loss: 0.0020 - accuracy: 0.9992 - recall: 0.9675 - false_negatives: 8682.0000 - false_positives: 8526.0000 - true_negatives: 20460500.0000 - true_positives: 258289.0000 - auc: 0.9999 - val_loss: 0.0259 - val_accuracy: 0.9950 - val_recall: 0.6635 - val_false_negatives: 9695.0000 - val_false_positives: 3026.0000 - val_true_negatives: 2528163.0000 - val_true_positives: 19116.0000 - val_auc: 0.9193
# Epoch 195/200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0019 - accuracy: 0.9992 - recall: 0.9674 - false_negatives: 8698.0000 - false_positives: 7563.0000 - true_negatives: 20461464.0000 - true_positives: 258273.0000 - auc: 0.9999 - val_loss: 0.0235 - val_accuracy: 0.9952 - val_recall: 0.7042 - val_false_negatives: 8522.0000 - val_false_positives: 3889.0000 - val_true_negatives: 2527300.0000 - val_true_positives: 20289.0000 - val_auc: 0.9292
# Epoch 196/200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0019 - accuracy: 0.9992 - recall: 0.9701 - false_negatives: 7972.0000 - false_positives: 8187.0000 - true_negatives: 20460844.0000 - true_positives: 258999.0000 - auc: 0.9999 - val_loss: 0.0289 - val_accuracy: 0.9948 - val_recall: 0.6313 - val_false_negatives: 10622.0000 - val_false_positives: 2656.0000 - val_true_negatives: 2528533.0000 - val_true_positives: 18189.0000 - val_auc: 0.9053
# Epoch 197/200
# 26/26 [==============================] - 6s 239ms/step - loss: 0.0020 - accuracy: 0.9992 - recall: 0.9654 - false_negatives: 9248.0000 - false_positives: 7698.0000 - true_negatives: 20461332.0000 - true_positives: 257723.0000 - auc: 0.9999 - val_loss: 0.0266 - val_accuracy: 0.9951 - val_recall: 0.6603 - val_false_negatives: 9787.0000 - val_false_positives: 2711.0000 - val_true_negatives: 2528478.0000 - val_true_positives: 19024.0000 - val_auc: 0.9145
# Epoch 198/200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0019 - accuracy: 0.9992 - recall: 0.9691 - false_negatives: 8237.0000 - false_positives: 7570.0000 - true_negatives: 20461458.0000 - true_positives: 258734.0000 - auc: 0.9999 - val_loss: 0.0270 - val_accuracy: 0.9950 - val_recall: 0.6494 - val_false_negatives: 10102.0000 - val_false_positives: 2676.0000 - val_true_negatives: 2528513.0000 - val_true_positives: 18709.0000 - val_auc: 0.9122
# Epoch 199/200
# 26/26 [==============================] - 6s 239ms/step - loss: 0.0019 - accuracy: 0.9992 - recall: 0.9678 - false_negatives: 8605.0000 - false_positives: 7452.0000 - true_negatives: 20461576.0000 - true_positives: 258366.0000 - auc: 0.9999 - val_loss: 0.0240 - val_accuracy: 0.9951 - val_recall: 0.7047 - val_false_negatives: 8508.0000 - val_false_positives: 4072.0000 - val_true_negatives: 2527117.0000 - val_true_positives: 20303.0000 - val_auc: 0.9314
# Epoch 200/200
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0019 - accuracy: 0.9992 - recall: 0.9700 - false_negatives: 8014.0000 - false_positives: 8067.0000 - true_negatives: 20460962.0000 - true_positives: 258957.0000 - auc: 0.9999 - val_loss: 0.0246 - val_accuracy: 0.9952 - val_recall: 0.6734 - val_false_negatives: 9409.0000 - val_false_positives: 2908.0000 - val_true_negatives: 2528281.0000 - val_true_positives: 19402.0000 - val_auc: 0.9264

# %% [markdown]
# ## Training and Validation Performance
# ### get the history of the model to access the metrics

# %%
history_dict = model_history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'recall', 'false_negatives', 'false_positives', 'true_negatives', 'true_positives', 'auc', 'val_loss', 'val_accuracy', 'val_recall', 'val_false_negatives', 'val_false_positives', 'val_true_negatives', 'val_true_positives', 'val_auc'])

# %%
ep = range(1, epochs + 1)

# %% [markdown]
# ### get training and validation loss

# %%
loss = history_dict['loss']
val_loss = history_dict['val_loss']

# %% [markdown]
# ### plot training and validation loss

# %%
# plot training loss
plt.plot(ep, loss, 'b', label='Training Loss')
# plot validation loss
plt.plot(ep, val_loss, 'r', label='Validation Loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# ### get accuracy scores

# %%
accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']

# %% [markdown]
# ### plot training and validation accuracy

# %%
# plot training accuracy
plt.plot(ep, accuracy, 'b', label='Training Accuracy')
# plot validation accuracy
plt.plot(ep, val_accuracy, 'r', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %% [markdown]
# ## compute and print all relevant metrics

# %%
# get "best" epoch
from operator import itemgetter
best_epoch, _ = max(enumerate(val_accuracy), key=itemgetter(1))

# compute all metrics (dict key names might need to be adapted)
val_TN = history_dict['val_true_negatives']

val_FP = history_dict['val_false_positives']

val_TP = history_dict['val_true_positives']

val_FN = history_dict['val_false_negatives']

val_sensitivity = history_dict['val_recall']

val_specificity = [x/(x+y) for x,y in zip(val_TN, val_FP)]

val_accuracy = history_dict['val_accuracy']

val_jaccard = [x/(x+y+z) for x,y,z in zip(val_TP, val_FP, val_FN)]

val_dice = [2*x/(2*x+y+z) for x,y,z in zip(val_TP, val_FP, val_FN)]

val_auc = history_dict['val_auc']

# print all relevant metrics for the best epoch of one model

print("Sensitivity: ", val_sensitivity[best_epoch])
print("Specificity: ", val_specificity[best_epoch])
print("Accuracy: ", val_accuracy[best_epoch])
print("Jaccard index: ", val_jaccard[best_epoch])
print("Dice coefficient: ", val_dice[best_epoch])
print("AUC: ", val_auc[best_epoch])

print(val_sensitivity[best_epoch], "&", val_specificity[best_epoch], "&", val_accuracy[best_epoch], "&", val_jaccard[best_epoch], "&", val_dice[best_epoch], "&", val_auc[best_epoch])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4648\2989810785.py in <cell line: 3>()
#       1 # get "best" epoch
#       2 from operator import itemgetter
# ----> 3 best_epoch, _ = max(enumerate(val_accuracy), key=itemgetter(1))
#       4
#       5 # compute all metrics
#
# NameError: name 'val_accuracy' is not defined

# %% [markdown]
# ### get values for ROC curve

# %%
from sklearn.metrics import roc_curve, auc

val_preds = model.predict(val_imgs)

fpr, tpr, _ = roc_curve(val_msks.ravel(), val_preds.ravel())
roc_auc = auc(fpr,tpr)
# Out:
# 4/4 [==============================] - 1s 58ms/step

# %% [markdown]
# ### plot ROC curve

# %%
# draw y = x 
plt.plot([0,1], [0,1], 'k--')
# draw roc curve
plt.plot(fpr, tpr, 'r', label='ROC curve (area = %0.2f)' % roc_auc)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.title('Receiver operating characteristic curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")

plt.show()

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### (if wanted) Save the weights of current model

# %%
model.save_weights('./checkpoints/current_model.h5')

# %% [markdown]
# ### Loads the weights of the model in epoch with best validation performance

# %%
checkpoint_path = "checkpoint_best_validation.h5"
model.load_weights(checkpoint_path)

# %% [markdown]
# ### evaluating the model based on its performance on the test set

# %%
# Evaluate the model on the test data using `evaluate`
model_performance = model.evaluate(test_imgs, test_msks, batch_size=batch_size)
print("test metrics:", model_performance)
# Out:
# 4/4 [==============================] - 3s 242ms/step - loss: 0.0168 - accuracy: 0.9952 - recall: 0.7379 - false_negatives: 7537.0000 - false_positives: 4736.0000 - true_negatives: 2526511.0000 - true_positives: 21216.0000 - auc: 0.9643
# test metrics: [0.016751281917095184, 0.9952058792114258, 0.7378708124160767, 7537.0, 4736.0, 2526511.0, 21216.0, 0.9642921090126038]

# %% [markdown]
# ## compute and print all relevant metrics

# %%
# compute all metrics
TN = model_performance[5]

FP = model_performance[4]

TP = model_performance[6]

FN = model_performance[3]

sensitivity = model_performance[2]

specificity = TN/(TN+FP)

accuracy = model_performance[1]

jaccard = TP/(TP + FP + FN)

dice = 2*TP/(2*TP + FP + FN)

auc = model_performance[7]

# print all relevant metrics for the best epoch of one model

print("Sensitivity: ", sensitivity)
print("Specificity: ", specificity)
print("Accuracy: ", accuracy)
print("Jaccard index: ", jaccard)
print("Dice coefficient: ", dice)
print("AUC: ", auc)

# for Latex 
print(sensitivity, "&", specificity, "&", accuracy, "&", jaccard, "&", dice, "&", auc)
# Out:
# Sensitivity:  0.7378708124160767
# Specificity:  0.9981289854368223
# Accuracy:  0.9952058792114258
# Jaccard index:  0.6335214548060557
# Dice coefficient:  0.7756512201809707
# AUC:  0.9642921090126038
# 0.7378708124160767 & 0.9981289854368223 & 0.9952058792114258 & 0.6335214548060557 & 0.7756512201809707 & 0.9642921090126038

# %% [markdown]
# ### get values for ROC curve

# %%
from sklearn.metrics import roc_curve, auc

test_preds = model.predict(test_imgs)

fpr, tpr, _ = roc_curve(test_msks.ravel(), test_preds.ravel())
roc_auc = auc(fpr,tpr)
# Out:
# 4/4 [==============================] - 1s 176ms/step

# %% [markdown]
# ### plot ROC curve

# %%
# draw y = x 
plt.plot([0,1], [0,1], 'k--')
# draw roc curve
plt.plot(fpr, tpr, 'r', label='ROC curve (area = %0.2f)' % roc_auc)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.title('Receiver operating characteristic curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")

plt.show()

# %% [markdown]
# ## Make predictions

# %% [markdown]
# ### Load unlabeled test data (only used for random predictions)

# %%
# path to validation data and ground truth
unlabeled_test_input_dir = "wound-segmentation/data/Foot Ulcer Segmentation Challenge/test/images/"

# sort input images by name
unlabeled_test_input_img_paths = sorted(
    [
        os.path.join(unlabeled_test_input_dir, fname)
        for fname in os.listdir(unlabeled_test_input_dir)
        if fname.endswith(".png")
    ]
)

# print number of total images
print("Number of samples:", len(unlabeled_test_input_img_paths))

# verify for the first 5 images that they are correctly aligned with their segmentation masks
for input_path in unlabeled_test_input_img_paths[:5]:
    print(input_path)
# Out:
# Number of samples: 200
# wound-segmentation/data/Foot Ulcer Segmentation Challenge/test/images/1011.png
# wound-segmentation/data/Foot Ulcer Segmentation Challenge/test/images/1014.png
# wound-segmentation/data/Foot Ulcer Segmentation Challenge/test/images/1016.png
# wound-segmentation/data/Foot Ulcer Segmentation Challenge/test/images/1018.png
# wound-segmentation/data/Foot Ulcer Segmentation Challenge/test/images/1020.png

# %% [markdown]
# ### Preprocessing

# %%
unlabeled_test_all_images = [load_img(i_path, target_size=img_size) for i_path in unlabeled_test_input_img_paths]

unlabeled_test_all_images_normalized = [np.array(image, dtype='float32')/255 for image in unlabeled_test_all_images]

unlabeled_test_all_images_normalized = np.array(unlabeled_test_all_images_normalized)

#test_all_images_normalized = test_all_images_normalized[..., np.newaxis]

print(unlabeled_test_all_images_normalized.shape)

unlabeled_test_imgs = unlabeled_test_all_images_normalized
# Out:
# (200, 160, 160, 3)

# %% [markdown]
# ### Generate prediction for one image
# As can be seen, the prediction mask is already very good

# %%
# specify image here
pred = model.predict(unlabeled_test_imgs[0:1])

# Display input image
display(keras.preprocessing.image.array_to_img(unlabeled_test_imgs[0]))

# Display prediction mask
display(ImageOps.autocontrast(keras.preprocessing.image.array_to_img(pred[0])))
# Out:
# 1/1 [==============================] - 0s 37ms/step
# <PIL.Image.Image image mode=RGB size=160x160 at 0x1ABFAE6AA30>
# <PIL.Image.Image image mode=L size=160x160 at 0x1ABFAE1EA00>
